# %%
secrets_file = open("privateinfo.txt","r")

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'cid:5d4f33bfe3ba4a30a9f258f3f2566c74\ncsecret:65fa69bb28ee457e9a3f5cb31de31d05'

# %%
string.split('\n')
# Out:
# ['cid:5d4f33bfe3ba4a30a9f258f3f2566c74',
#  'csecret:65fa69bb28ee457e9a3f5cb31de31d05']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': '5d4f33bfe3ba4a30a9f258f3f2566c74',
#  'csecret': '65fa69bb28ee457e9a3f5cb31de31d05'}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
# Reusable functions

def get_name_artists_from_track(track):
    return [(track["name"], artist["name"], track["uri"]) for artist in track["artists"]]

def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

#first we need to get a list of individual tracks from the playlist
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

def get_name_artists_from_playlist_items(playlist_items):
    return flatten(list(map(get_name_artist_from_playlist_item,playlist_items)))

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks =  results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000/1000))
    return tracks

# %%
all_tracks = get_playlist_tracks("6yPiKpy7evrwvZodByKvM9")

# %%
my_data = get_name_artists_from_playlist_items(all_tracks)

# %%
my_data
# Out:
# [('2K', 'Nosaj Thing', 'spotify:track:33xMbeHzmWd6Od0BmLZEUs'),
#  ('4 Billion Souls', 'The Doors', 'spotify:track:3UnyplmZaq547hwsfOR5yy'),
#  ('4 Minute Warning', 'Radiohead', 'spotify:track:1w8QCSDH4QobcQeT4uMKLm'),
#  ('7 Element', 'Vitas', 'spotify:track:7J9mBHG4J2eIfDAv5BehKA'),
#  ('#9 Dream', 'R.E.M.', 'spotify:track:1VZedwJj1gyi88WFRhfThb'),
#  ('#9 Dream', 'a-ha', 'spotify:track:3DSmOF7ETJHAQEqqgoSJao'),
#  ('10 Lovers', 'The Black Keys', 'spotify:track:5HPnumlogzZtpLEaORZjz1'),
#  ('11th Dimension',
#   'Julian Casablancas',
#   'spotify:track:6i99ThziImjuFABb8rUQvy'),
#  ('12:51', 'The Strokes', 'spotify:track:0nkLI0pdyTRpq7BsTFBufZ'),
#  ('12:51', 'The Strokes', 'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK'),
#  ('12 Bar Original - Anthology 2 Version',
#   'The Beatles',
#   'spotify:track:2HvTGx5fzFGpHSyRNvXd9T'),
#  ('15 Minutes', 'The Strokes', 'spotify:track:2XS4lIQ1bl9KSNsYtkqK46'),
#  ('15 Step', 'Radiohead', 'spotify:track:6dsq7Nt5mIFzvm5kIYNORy'),
#  ('17', 'Perfume Genius', 'spotify:track:1wKGGfnznnXIvupuEZt9mM'),
#  ('21 Gun Salute', 'Half Moon Run', 'spotify:track:7Jjqx75QRHaYsxF5WnHovC'),
#  ('22h22', 'Ariane Moffatt', 'spotify:track:7BIPYQPHbPVDE9UsA0eT72'),
#  ('28 Jours', 'Karkwa', 'spotify:track:4KEw5m7CZXVbpWbHVK4OrV'),
#  ("Brad Pitt's Cousin (feat. Xperience)",
#   'Macklemore',
#   'spotify:track:3zg0RVk6GcXFvJG6BWVFre'),
#  ("Brad Pitt's Cousin (feat. Xperience)",
#   'Ryan Lewis',
#   'spotify:track:3zg0RVk6GcXFvJG6BWVFre'),
#  ("Brad Pitt's Cousin (feat. Xperience)",
#   'Xperience',
#   'spotify:track:3zg0RVk6GcXFvJG6BWVFre'),
#  ('Brain Damage', 'Pink Floyd', 'spotify:track:05uGBKRCuePsf43Hfm0JwX'),
#  ('Bravado', 'Lorde', 'spotify:track:02ZorlDGq0uTnMobHNh4EL'),
#  ('Brave For You', 'The xx', 'spotify:track:53e5O0USYgSCv4md0CXpMY'),
#  ('Break Forth O Beauteous Heavenly Light',
#   'Sufjan Stevens',
#   'spotify:track:7quuHVfah2nh53Iu3HFyzg'),
#  ('Breakdown', 'Jack Johnson', 'spotify:track:3cnRYoW4nYzIuVPCp7k5iG'),
#  ('Breathe (In the Air)',
#   'Pink Floyd',
#   'spotify:track:2ctvdKmETyOzPb2GiJJT53'),
#  ('Breathing Underwater', 'Metric', 'spotify:track:1KZjU7csKHOLRiRPBWZIJS'),
#  ('Breathing Underwater - Acoustic',
#   'Metric',
#   'spotify:track:4LDA1docg7FG8EG2vNyFdN'),
#  ('Breed', 'Nirvana', 'spotify:track:5mJGLBNJM0GULqAoL5mb9C'),
#  ('Breezeblocks', 'alt-J', 'spotify:track:3n69hLUdIsSa1WlRmjMZlW'),
#  ('Breezeblocks - Live at Lido Berlin, Berlin, Germany, 10/1/2014',
#   'alt-J',
#   'spotify:track:0JY2OUnAI0szZFzmLVZ9G0'),
#  ('Brian Was A Beautiful Guy...He Presented Us Well - Anthology 1 Version',
#   'John Lennon',
#   'spotify:track:56F9TjvH8JdGftpoHW0pHC'),
#  ('Brick By Brick - Live At MTV Unplugged, 2009',
#   'Katy Perry',
#   'spotify:track:6Hup9P0Ggb3ff5tneUdWeM'),
#  ('Bright Shiny Lights',
#   'Patrick Watson',
#   'spotify:track:4iAVdRDvfOY24LCGxWRkE1'),
#  ('Bright Shiny Lights',
#   'Patrick Watson',
#   'spotify:track:6qbaKnNzAaQ7DUr2L498ug'),
#  ('Brighter', 'Beach Fossils', 'spotify:track:11osW4wLaOqjhAevTdzrXr'),
#  ('Bring Me Simple Men',
#   'Timber Timbre',
#   'spotify:track:79un0CqO3gpsTOXCsIUelj'),
#  ('Bring Out The Gimp - Dialogue Excerpt From "Pulp Fiction"',
#   'Peter Greene',
#   'spotify:track:67CXCPhxgzmt978x3drzIS'),
#  ('Bring Out The Gimp - Dialogue Excerpt From "Pulp Fiction"',
#   'Duane Whitaker',
#   'spotify:track:67CXCPhxgzmt978x3drzIS'),
#  ('Bring the Boys Back Home',
#   'Pink Floyd',
#   'spotify:track:4TUStFzBGQqn0GrkzVWFV4'),
#  ('Bring Your Adz',
#   'Jake Shimabukuro',
#   'spotify:track:2Nlf7AK42lhTTrzdNsXQBd'),
#   'spotify:track:5WbmgRh4WP3dfmcrPUDY4O'),
#  ('Everlasting Light',
#   'The Black Keys',
#   'spotify:track:6dU5RxthbuaN31bRbEDlNw'),
#  ('Every Little Thing - Remastered 2009',
#   'The Beatles',
#   'spotify:track:2CxTkdvhDuQrOxl8xXkdJS'),
#  ('Every Minute Alone', 'WhoMadeWho', 'spotify:track:6aMbfj0Noj6tuyOJnTGPbi'),
#  ('Every Other Freckle', 'alt-J', 'spotify:track:6BVBkKpZK09NmifUMZqj1z'),
#  ('Every Other Freckle - Take a Daytrip Remix',
#   'alt-J',
#   'spotify:track:6obHItHLe5WlhFoTalxsoY'),
#  ('Every Other Freckle - Take a Daytrip Remix',
#   'Take A Daytrip',
#   'spotify:track:6obHItHLe5WlhFoTalxsoY'),
#  ('Every Other Freckle - Live at Lido Berlin, Berlin, Germany, 10/1/2014',
#   'alt-J',
#   'spotify:track:3Sp1DNwzhWZFa4NLw6alJE'),
#  ("Everybody's Got Something To Hide Except Me And My Monkey - Remastered 2009",
#   'The Beatles',
#   'spotify:track:64P3zpRsDHIk7YTpRtaKYL'),
#  ("Everybody's Trying To Be My Baby - Live From Shea Stadium, New York, USA/1965 / Anthology 2 Version",
#   'The Beatles',
#   'spotify:track:6JEfKSfRnACibeFgpfecfi'),
#  ('Everybody’s Trying To Be My Baby - Live / Bonus Track',
#   'The Beatles',
#   'spotify:track:1WoLOPeSqaijOuhi9Wm7V1'),
#  ("Everybody's Trying To Be My Baby - Remastered 2009",
#   'The Beatles',
#   'spotify:track:4DZAH8eiqSAkMIE9l5D71U'),
#  ('Everyday Robots', 'Damon Albarn', 'spotify:track:2dLL8ikM6GXMhKX39c12zN'),
#  ('Everyone Requires A Plan',
#   'The Lumineers',
#   'spotify:track:3jlUexlkB435W822vfipNk'),
#  ('Everything Goes My Way',
#   'Metronomy',
#   'spotify:track:7r3oumwvHjsnh5IPtGrfNB'),
#  ('Everything Will Be Alright',
#   'The Killers',
#   'spotify:track:5UimLzrkc72ST1fQRuwQKs'),
#  ("Everything's Not Lost - Includes Hidden Track 'Life Is For Living'",
#   'Coldplay',
#   'spotify:track:1RNtm45kw0hPMBz7gKiIYu'),
#  ('Evil', 'Interpol', 'spotify:track:6B182GP3TvEfmgUoIMVUSJ'),
#  ('Excuse', 'C418', 'spotify:track:2FD2StPTst6uMJF7cHBbP0'),
#  ('Exit Music (For a Film)',
#   'Radiohead',
#   'spotify:track:4Na0siMtWOW9pJoWJ1Ponv'),
#  ('Expectation', 'Tame Impala', 'spotify:track:4m3GHOgCNZMv0we7H9j8Y8'),
#  ('Exquisite Leisure Time', 'SIMON I', 'spotify:track:6ASMwetD6RW7FDLQxx2lHn'),
#  ('Extreme Wealth and Casual Cruelty',
#   'Unknown Mortal Orchestra',
#   'spotify:track:2nqqIatHUVkw9S342HZKTz'),
#  ('Eyes On You', 'Kings of Leon', 'spotify:track:03qKJWqX0I2tlMJiU72P1Y'),
#  ('Ezekiel 25:17',
#   'Samuel L. Jackson',
#   'spotify:track:1bbX8eMgNGKtE9hDUmC35Y'),
#  ('Flowers On The Wall',
#   'The Statler Brothers',
#   'spotify:track:6oIOkcU6u5iPlQBHXGJwzN'),
#  ...]

# %%
all_tracks[0]['track']['name']
# Out:
# '2K'

# %%
import pandas as pd

playlist1 = pd.DataFrame(my_data, columns = ['track_name', 'artist_name', 'uri'])
print(playlist1.shape)
playlist1.head(10)
# Out:
# (11827, 3)
#          track_name         artist_name                                   uri
# 0                2K         Nosaj Thing  spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1   4 Billion Souls           The Doors  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2  4 Minute Warning           Radiohead  spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3         7 Element               Vitas  spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4          #9 Dream              R.E.M.  spotify:track:1VZedwJj1gyi88WFRhfThb
# 5          #9 Dream                a-ha  spotify:track:3DSmOF7ETJHAQEqqgoSJao
# 6         10 Lovers      The Black Keys  spotify:track:5HPnumlogzZtpLEaORZjz1
# 7    11th Dimension  Julian Casablancas  spotify:track:6i99ThziImjuFABb8rUQvy
# 8             12:51         The Strokes  spotify:track:0nkLI0pdyTRpq7BsTFBufZ
# 9             12:51         The Strokes  spotify:track:6Yu1OL8I0D4vjOzYdsXYGK

# %%
audio_f = []

for x in playlist1['uri']:
    audio_f.append(sp.audio_features(x))
# Out:
# Expected id of type track but found type 100+Amazing+Bass+Lines spotify:local:::100+Amazing+Bass+Lines:785
# Expected id of type track but found type Alabama+Shakes+performing+Don%27t+Wanna+Fight+Live+on+KCRW spotify:local:::Alabama+Shakes+performing+Don%27t+Wanna+Fight+Live+on+KCRW:251
# Expected id of type track but found type Anderson+East+-+Satisfy+Me+-+3_15_2015+-+Riverview+Bungalow%2C+Austin%2C+TX spotify:local:::Anderson+East+-+Satisfy+Me+-+3_15_2015+-+Riverview+Bungalow%2C+Austin%2C+TX:164
# Expected id of type track but found type Art+Of+Sleeping+cover+Drake+%27Hotline+Bling%27+for+Like+A+Version spotify:local:::Art+Of+Sleeping+cover+Drake+%27Hotline+Bling%27+for+Like+A+Version:281
# Expected id of type track but found type Bahamas+-+Stronger+Than+That+%28Buzzsession%29 spotify:local:::Bahamas+-+Stronger+Than+That+%28Buzzsession%29:172
# Expected id of type track but found type CHANSON+_+RE%CC%81PLIQUES+DE+FILMS+%28AVEC+MIRO+BELZIL%29 spotify:local:::CHANSON+_+RE%CC%81PLIQUES+DE+FILMS+%28AVEC+MIRO+BELZIL%29:168
# Expected id of type track but found type Chanson+du+250e+anniversaire+du+Colle%CC%80ge+de+Montre%CC%81al. spotify:local:::Chanson+du+250e+anniversaire+du+Colle%CC%80ge+de+Montre%CC%81al.:278
# Expected id of type track but found type Chvrches+cover+Arctic+Monkeys%27+%27Do+I+Wanna+Know_%27+for+Like+A+Version spotify:local:::Chvrches+cover+Arctic+Monkeys%27+%27Do+I+Wanna+Know_%27+for+Like+A+Version:313
# Expected id of type track but found type Soran+Dussaigne+-+Take+Me+To+Church+%28Acoustic+Cover%29 spotify:local:::Soran+Dussaigne+-+Take+Me+To+Church+%28Acoustic+Cover%29:163
# Expected id of type track but found type Tame+Impala+-+The+Less+I+Know+The+Better+%28live%29 spotify:local:::Tame+Impala+-+The+Less+I+Know+The+Better+%28live%29:298
# Expected id of type track but found type Taylor+Swift+covers+Vance+Joy%27s+Riptide+in+the+Live+Lounge spotify:local:::Taylor+Swift+covers+Vance+Joy%27s+Riptide+in+the+Live+Lounge:209
# Expected id of type track but found type Twenty+One+Pilots+-+Stressed+Out+%28Ukulele+Version%29 spotify:local:::Twenty+One+Pilots+-+Stressed+Out+%28Ukulele+Version%29:268
# Expected id of type track but found type Who+Made+Who+-+Keep+Me+In+My+Plane spotify:local:::Who+Made+Who+-+Keep+Me+In+My+Plane:221
# Expected id of type track but found type Who+Made+Who+-+Rose spotify:local:::Who+Made+Who+-+Rose:256
# Expected id of type track but found type Who+Made+Who+-+Space+For+Rent spotify:local:::Who+Made+Who+-+Space+For+Rent:360
# Expected id of type track but found type Xavier+Cafeine+-+Gise%CC%80le spotify:local:::Xavier+Cafeine+-+Gise%CC%80le:261
# Expected id of type track but found type Xavier+Cafe%CC%81ine+-+La+fin+du+monde spotify:local:::Xavier+Cafe%CC%81ine+-+La+fin+du+monde:292
# Expected id of type track but found type Xavier+Cafeine+-+Montreal+%28Cette+ville%29 spotify:local:::Xavier+Cafeine+-+Montreal+%28Cette+ville%29:305
# Expected id of type track but found type Wii+Shop+Channel+Music spotify:local:::Wii+Shop+Channel+Music:559
# Expected id of type track but found type All+You+Need+Is+Love spotify:local:The+Beatles:1967-1970+%5BDisc+1%5D:All+You+Need+Is+Love:228
# Expected id of type track but found type Gathering+All+the+Lost+Loves spotify:local:General+Elektriks:Good+City+for+Dreamers:Gathering+All+the+Lost+Loves:168
# Expected id of type track but found type Love+You+To spotify:local:The+Beatles:Revolver:Love+You+To:181
# Expected id of type track but found type All+You+Need+Is+Love spotify:local:The+Beatles:Magical+Mystery+Tour:All+You+Need+Is+Love:230
# Expected id of type track but found type twenty+_+one+_+pilots_+Can%27t+Help+Falling+In+Love spotify:local:::twenty+_+one+_+pilots_+Can%27t+Help+Falling+In+Love:177
# Expected id of type track but found type Crown+Of+Love spotify:local:Arcade+Fire:Funeral:Crown+Of+Love:282
# Expected id of type track but found type 03+You+Got+Yr.+Cherry+Bomb spotify:local:::03+You+Got+Yr.+Cherry+Bomb:188
# Expected id of type track but found type 04+Don%27t+You+Evah spotify:local:::04+Don%27t+You+Evah:216
# Expected id of type track but found type Your+Mother+Should+Know spotify:local:The+Beatles:Magical+Mystery+Tour:Your+Mother+Should+Know:148
# Expected id of type track but found type Baby+You%27re+A+Rich+Man spotify:local:The+Beatles:Magical+Mystery+Tour:Baby+You%27re+A+Rich+Man:181
# Expected id of type track but found type And+Your+Bird+Can+Sing spotify:local:The+Beatles:Revolver:And+Your+Bird+Can+Sing:121
# Expected id of type track but found type I+Want+To+Tell+You spotify:local:The+Beatles:Revolver:I+Want+To+Tell+You:149
# Expected id of type track but found type Got+To+Get+You+Into+My+Life spotify:local:The+Beatles:Revolver:Got+To+Get+You+Into+My+Life:150
# Expected id of type track but found type You%27re+So+Right spotify:local:The+Strokes:Angles:You%27re+So+Right:153
# Expected id of type track but found type 01+I+Give+You+Power+%28feat.+Mavis+Staples%29 spotify:local:::01+I+Give+You+Power+%28feat.+Mavis+Staples%29:225
# Expected id of type track but found type Run+For+Your+Life spotify:local:The+Beatles:Rubber+Soul:Run+For+Your+Life:138
# Expected id of type track but found type I+Want+You+%28She%27s+So+Heavy%29 spotify:local:The+Beatles:Abbey+Road:I+Want+You+%28She%27s+So+Heavy%29:467
# Expected id of type track but found type Neighborhood+%231+%28Tunnels%29 spotify:local:Arcade+Fire:Funeral:Neighborhood+%231+%28Tunnels%29:288
# Expected id of type track but found type Bullet+In+the+Brain spotify:local:The+Black+Keys:Turn+Blue:Bullet+In+the+Brain:256
# Expected id of type track but found type Fever spotify:local:The+Black+Keys:Turn+Blue:Fever:246
# Expected id of type track but found type Gotta+Get+Away spotify:local:The+Black+Keys:Turn+Blue:Gotta+Get+Away:182
# Expected id of type track but found type In+Our+Prime spotify:local:The+Black+Keys:Turn+Blue:In+Our+Prime:278
# Expected id of type track but found type Good+Day+Sunshine spotify:local:The+Beatles:Revolver:Good+Day+Sunshine:129
# Expected id of type track but found type A+Day+In+The+Life spotify:local:The+Beatles:1967-1970+%5BDisc+1%5D:A+Day+In+The+Life:307
# Expected id of type track but found type Another+Day spotify:local:WhoMadeWho:Dreams:Another+Day:258

# %%
audio_f
# Out:
# [[{'danceability': 0.31,
#    'energy': 0.445,
#    'key': 7,
#    'loudness': -13.355,
#    'mode': 0,
#    'speechiness': 0.0863,
#    'acousticness': 0.094,
#    'instrumentalness': 0.0678,
#    'liveness': 0.113,
#    'valence': 0.122,
#    'tempo': 95.36,
#    'type': 'audio_features',
#    'id': '33xMbeHzmWd6Od0BmLZEUs',
#    'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#    'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#    'duration_ms': 152560,
#    'time_signature': 3}],
#  [{'danceability': 0.419,
#    'energy': 0.565,
#    'key': 5,
#    'loudness': -11.565,
#    'mode': 1,
#    'speechiness': 0.0347,
#    'acousticness': 0.137,
#    'instrumentalness': 0.337,
#    'liveness': 0.128,
#    'valence': 0.648,
#    'tempo': 151.277,
#    'type': 'audio_features',
#    'id': '3UnyplmZaq547hwsfOR5yy',
#    'uri': 'spotify:track:3UnyplmZaq547hwsfOR5yy',
#    'track_href': 'https://api.spotify.com/v1/tracks/3UnyplmZaq547hwsfOR5yy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UnyplmZaq547hwsfOR5yy',
#    'duration_ms': 197707,
#    'time_signature': 4}],
#  [{'danceability': 0.354,
#    'energy': 0.302,
#    'key': 9,
#    'loudness': -13.078,
#    'mode': 1,
#    'speechiness': 0.0326,
#    'acousticness': 0.59,
#    'instrumentalness': 0.0709,
#    'liveness': 0.111,
#    'valence': 0.223,
#    'tempo': 123.753,
#    'type': 'audio_features',
#    'id': '1w8QCSDH4QobcQeT4uMKLm',
#    'uri': 'spotify:track:1w8QCSDH4QobcQeT4uMKLm',
#    'track_href': 'https://api.spotify.com/v1/tracks/1w8QCSDH4QobcQeT4uMKLm',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1w8QCSDH4QobcQeT4uMKLm',
#    'duration_ms': 244285,
#    'time_signature': 4}],
#  [{'danceability': 0.727,
#    'energy': 0.785,
#    'key': 5,
#    'loudness': -6.707,
#    'mode': 0,
#    'speechiness': 0.0603,
#    'acousticness': 0.325,
#    'instrumentalness': 0.126,
#    'liveness': 0.31,
#    'valence': 0.96,
#    'tempo': 129.649,
#    'type': 'audio_features',
#    'id': '7J9mBHG4J2eIfDAv5BehKA',
#    'uri': 'spotify:track:7J9mBHG4J2eIfDAv5BehKA',
#    'track_href': 'https://api.spotify.com/v1/tracks/7J9mBHG4J2eIfDAv5BehKA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J9mBHG4J2eIfDAv5BehKA',
#    'duration_ms': 249940,
#    'time_signature': 4}],
#  [{'danceability': 0.571,
#    'energy': 0.724,
#    'key': 0,
#    'loudness': -5.967,
#    'mode': 1,
#    'speechiness': 0.026,
#    'acousticness': 0.0231,
#    'instrumentalness': 0.00311,
#    'liveness': 0.0919,
#    'valence': 0.385,
#    'tempo': 116.755,
#    'type': 'audio_features',
#    'id': '1VZedwJj1gyi88WFRhfThb',
#    'uri': 'spotify:track:1VZedwJj1gyi88WFRhfThb',
#    'track_href': 'https://api.spotify.com/v1/tracks/1VZedwJj1gyi88WFRhfThb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1VZedwJj1gyi88WFRhfThb',
#    'duration_ms': 278320,
#    'time_signature': 4}],
#  [{'danceability': 0.579,
#    'energy': 0.777,
#    'key': 4,
#    'loudness': -7.505,
#    'mode': 1,
#    'speechiness': 0.0304,
#    'acousticness': 0.0177,
#    'instrumentalness': 0.000248,
#    'liveness': 0.422,
#    'valence': 0.481,
#    'tempo': 109.994,
#    'type': 'audio_features',
#    'id': '3DSmOF7ETJHAQEqqgoSJao',
#    'uri': 'spotify:track:3DSmOF7ETJHAQEqqgoSJao',
#    'track_href': 'https://api.spotify.com/v1/tracks/3DSmOF7ETJHAQEqqgoSJao',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DSmOF7ETJHAQEqqgoSJao',
#    'duration_ms': 247067,
#    'time_signature': 4}],
#  [{'danceability': 0.606,
#    'energy': 0.638,
#    'key': 3,
#    'loudness': -6.994,
#    'mode': 0,
#    'speechiness': 0.0339,
#    'acousticness': 0.0434,
#    'instrumentalness': 0.000247,
#    'liveness': 0.0887,
#    'valence': 0.817,
#    'tempo': 97.992,
#    'type': 'audio_features',
#    'id': '5HPnumlogzZtpLEaORZjz1',
#    'uri': 'spotify:track:5HPnumlogzZtpLEaORZjz1',
#    'track_href': 'https://api.spotify.com/v1/tracks/5HPnumlogzZtpLEaORZjz1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HPnumlogzZtpLEaORZjz1',
#    'duration_ms': 213227,
#    'time_signature': 4}],
#  [{'danceability': 0.574,
#    'energy': 0.925,
#    'key': 6,
#    'loudness': -2.766,
#    'mode': 0,
#    'speechiness': 0.0463,
#    'acousticness': 0.00164,
#    'instrumentalness': 0.0243,
#    'liveness': 0.115,
#    'valence': 0.369,
#    'tempo': 125.501,
#    'type': 'audio_features',
#    'id': '6i99ThziImjuFABb8rUQvy',
#    'uri': 'spotify:track:6i99ThziImjuFABb8rUQvy',
#    'track_href': 'https://api.spotify.com/v1/tracks/6i99ThziImjuFABb8rUQvy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6i99ThziImjuFABb8rUQvy',
#    'duration_ms': 243333,
#    'time_signature': 4}],
#  [{'danceability': 0.452,
#    'energy': 0.889,
#    'key': 4,
#    'loudness': -3.838,
#    'mode': 1,
#    'speechiness': 0.0379,
#    'acousticness': 0.312,
#    'instrumentalness': 0.8,
#    'liveness': 0.558,
#    'valence': 0.591,
#    'tempo': 145.056,
#    'type': 'audio_features',
#    'id': '0nkLI0pdyTRpq7BsTFBufZ',
#    'uri': 'spotify:track:0nkLI0pdyTRpq7BsTFBufZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/0nkLI0pdyTRpq7BsTFBufZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nkLI0pdyTRpq7BsTFBufZ',
#    'duration_ms': 153133,
#    'time_signature': 4}],
#  [{'danceability': 0.451,
#    'energy': 0.889,
#    'key': 4,
#    'loudness': -3.838,
#    'mode': 1,
#    'speechiness': 0.0379,
#    'acousticness': 0.312,
#    'instrumentalness': 0.8,
#    'liveness': 0.558,
#    'valence': 0.592,
#    'tempo': 145.056,
#    'type': 'audio_features',
#    'id': '6Yu1OL8I0D4vjOzYdsXYGK',
#    'uri': 'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK',
#    'track_href': 'https://api.spotify.com/v1/tracks/6Yu1OL8I0D4vjOzYdsXYGK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Yu1OL8I0D4vjOzYdsXYGK',
#    'duration_ms': 153133,
#    'time_signature': 4}],
#  [{'danceability': 0.6,
#    'energy': 0.535,
#    'key': 9,
#    'loudness': -8.178,
#    'mode': 1,
#    'speechiness': 0.0298,
#    'acousticness': 0.00154,
#    'instrumentalness': 0.102,
#    'liveness': 0.123,
#    'valence': 0.566,
#    'tempo': 122.678,
#    'type': 'audio_features',
#    'id': '2HvTGx5fzFGpHSyRNvXd9T',
#    'uri': 'spotify:track:2HvTGx5fzFGpHSyRNvXd9T',
#    'track_href': 'https://api.spotify.com/v1/tracks/2HvTGx5fzFGpHSyRNvXd9T',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HvTGx5fzFGpHSyRNvXd9T',
#    'duration_ms': 175080,
#    'time_signature': 4}],
#  [{'danceability': 0.337,
#    'energy': 0.885,
#    'key': 2,
#    'loudness': -3.566,
#    'mode': 1,
#    'speechiness': 0.0419,
#    'acousticness': 0.004,
#    'instrumentalness': 0.0378,
#    'liveness': 0.141,
#    'valence': 0.389,
#    'tempo': 83.001,
#    'type': 'audio_features',
#    'id': '2XS4lIQ1bl9KSNsYtkqK46',
#    'uri': 'spotify:track:2XS4lIQ1bl9KSNsYtkqK46',
#    'track_href': 'https://api.spotify.com/v1/tracks/2XS4lIQ1bl9KSNsYtkqK46',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XS4lIQ1bl9KSNsYtkqK46',
#    'duration_ms': 273133,
#    'time_signature': 3}],
#  [{'danceability': 0.6,
#    'energy': 0.853,
#    'key': 1,
#    'loudness': -7.584,
#    'mode': 1,
#    'speechiness': 0.0423,
#    'acousticness': 0.0489,
#    'instrumentalness': 0.346,
#    'liveness': 0.0934,
#    'valence': 0.847,
#    'tempo': 94.457,
#    'type': 'audio_features',
#    'id': '6dsq7Nt5mIFzvm5kIYNORy',
#    'uri': 'spotify:track:6dsq7Nt5mIFzvm5kIYNORy',
#    'track_href': 'https://api.spotify.com/v1/tracks/6dsq7Nt5mIFzvm5kIYNORy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dsq7Nt5mIFzvm5kIYNORy',
#    'duration_ms': 237293,
#    'time_signature': 4}],
#  [{'danceability': 0.396,
#    'energy': 0.141,
#    'key': 6,
#    'loudness': -16.115,
#    'mode': 1,
#    'speechiness': 0.0294,
#    'acousticness': 0.919,
#    'instrumentalness': 0.434,
#    'liveness': 0.339,
#    'valence': 0.0443,
#    'tempo': 68.03,
#    'type': 'audio_features',
#    'id': '1wKGGfnznnXIvupuEZt9mM',
#    'uri': 'spotify:track:1wKGGfnznnXIvupuEZt9mM',
#    'track_href': 'https://api.spotify.com/v1/tracks/1wKGGfnznnXIvupuEZt9mM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wKGGfnznnXIvupuEZt9mM',
#    'duration_ms': 150013,
#    'time_signature': 4}],
#  [{'danceability': 0.594,
#    'energy': 0.61,
#    'key': 11,
#    'loudness': -10.57,
#    'mode': 0,
#    'speechiness': 0.0388,
#    'acousticness': 0.829,
#    'instrumentalness': 0.208,
#    'liveness': 0.077,
#    'valence': 0.289,
#    'tempo': 129.963,
#    'type': 'audio_features',
#    'id': '7Jjqx75QRHaYsxF5WnHovC',
#    'uri': 'spotify:track:7Jjqx75QRHaYsxF5WnHovC',
#    'track_href': 'https://api.spotify.com/v1/tracks/7Jjqx75QRHaYsxF5WnHovC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Jjqx75QRHaYsxF5WnHovC',
#    'duration_ms': 292409,
#    'time_signature': 4}],
#  [{'danceability': 0.35,
#    'energy': 0.0959,
#    'key': 10,
#    'loudness': -17.471,
#    'mode': 1,
#    'speechiness': 0.0439,
#    'acousticness': 0.964,
#    'instrumentalness': 0.0024,
#    'liveness': 0.106,
#    'valence': 0.108,
#    'tempo': 143.861,
#    'type': 'audio_features',
#    'id': '7BIPYQPHbPVDE9UsA0eT72',
#    'uri': 'spotify:track:7BIPYQPHbPVDE9UsA0eT72',
#    'track_href': 'https://api.spotify.com/v1/tracks/7BIPYQPHbPVDE9UsA0eT72',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BIPYQPHbPVDE9UsA0eT72',
#    'duration_ms': 200907,
#    'time_signature': 4}],
#  [{'danceability': 0.15,
#    'energy': 0.237,
#    'key': 3,
#    'loudness': -10.799,
#    'mode': 0,
#    'speechiness': 0.0323,
#    'acousticness': 0.778,
#    'instrumentalness': 0.0977,
#    'liveness': 0.0897,
#    'valence': 0.0733,
#    'tempo': 67.276,
#    'type': 'audio_features',
#    'id': '4KEw5m7CZXVbpWbHVK4OrV',
#    'uri': 'spotify:track:4KEw5m7CZXVbpWbHVK4OrV',
#    'track_href': 'https://api.spotify.com/v1/tracks/4KEw5m7CZXVbpWbHVK4OrV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KEw5m7CZXVbpWbHVK4OrV',
#    'duration_ms': 292120,
#    'time_signature': 4}],
#  [{'danceability': 0.733,
#    'energy': 0.719,
#    'key': 5,
#    'loudness': -8.776,
#    'mode': 0,
#    'speechiness': 0.0462,
#    'acousticness': 0.0609,
#    'instrumentalness': 0.108,
#    'liveness': 0.0807,
#    'valence': 0.327,
#    'tempo': 114.959,
#    'type': 'audio_features',
#    'id': '2YTRLoG5jdzCp4yg3B6OnH',
#    'uri': 'spotify:track:2YTRLoG5jdzCp4yg3B6OnH',
#    'track_href': 'https://api.spotify.com/v1/tracks/2YTRLoG5jdzCp4yg3B6OnH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YTRLoG5jdzCp4yg3B6OnH',
#    'duration_ms': 309787,
#    'time_signature': 4}],
#  [{'danceability': 0.491,
#    'energy': 0.93,
#    'key': 11,
#    'loudness': -6.412,
#    'mode': 0,
#    'speechiness': 0.0347,
#    'acousticness': 4.23e-05,
#    'instrumentalness': 0.612,
#    'liveness': 0.219,
#    'valence': 0.623,
#    'tempo': 99.924,
#    'type': 'audio_features',
#    'id': '5MPryR3oJGmWnSYM7X2GGE',
#    'uri': 'spotify:track:5MPryR3oJGmWnSYM7X2GGE',
#    'track_href': 'https://api.spotify.com/v1/tracks/5MPryR3oJGmWnSYM7X2GGE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MPryR3oJGmWnSYM7X2GGE',
#    'duration_ms': 163227,
#    'time_signature': 4}],
#  [{'danceability': 0.703,
#    'energy': 0.7,
#    'key': 2,
#    'loudness': -6.152,
#    'mode': 1,
#    'speechiness': 0.135,
#    'acousticness': 0.049,
#    'instrumentalness': 0,
#    'liveness': 0.365,
#    'valence': 0.512,
#    'tempo': 119.966,
#    'type': 'audio_features',
#    'id': '4ymUtICOpIlyvFf3URM7XZ',
#    'uri': 'spotify:track:4ymUtICOpIlyvFf3URM7XZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/4ymUtICOpIlyvFf3URM7XZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ymUtICOpIlyvFf3URM7XZ',
#    'duration_ms': 208248,
#    'time_signature': 4}],
#  [{'danceability': 0.488,
#    'energy': 0.503,
#    'key': 0,
#    'loudness': -8.89,
#    'mode': 1,
#    'speechiness': 0.0326,
#    'acousticness': 0.00583,
#    'instrumentalness': 0.809,
#    'liveness': 0.101,
#    'valence': 0.38,
#    'tempo': 144.035,
#    'type': 'audio_features',
#    'id': '2lffRiAET2Xt6BNb4EmkS2',
#    'uri': 'spotify:track:2lffRiAET2Xt6BNb4EmkS2',
#    'track_href': 'https://api.spotify.com/v1/tracks/2lffRiAET2Xt6BNb4EmkS2',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lffRiAET2Xt6BNb4EmkS2',
#    'duration_ms': 298613,
#    'time_signature': 4}],
#  [{'danceability': 0.583,
#    'energy': 0.917,
#    'key': 6,
#    'loudness': -8.96,
#    'mode': 0,
#    'speechiness': 0.567,
#    'acousticness': 0.493,
#    'instrumentalness': 0.0608,
#    'liveness': 0.296,
#    'valence': 0.44,
#    'tempo': 171.157,
#    'type': 'audio_features',
#    'id': '3oQ52Mqz2ih8KjligVoQrG',
#    'uri': 'spotify:track:3oQ52Mqz2ih8KjligVoQrG',
#    'track_href': 'https://api.spotify.com/v1/tracks/3oQ52Mqz2ih8KjligVoQrG',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3oQ52Mqz2ih8KjligVoQrG',
#    'duration_ms': 34014,
#    'time_signature': 4}],
#  [None],
#  [{'danceability': 0.487,
#    'energy': 0.753,
#    'key': 6,
#    'loudness': -10.533,
#    'mode': 0,
#    'speechiness': 0.306,
#    'acousticness': 0.665,
#    'instrumentalness': 0.00144,
#    'liveness': 0.231,
#    'valence': 0.847,
#    'tempo': 112.907,
#    'type': 'audio_features',
#    'id': '5h8G81Ls00kyf1UEen0gBB',
#    'uri': 'spotify:track:5h8G81Ls00kyf1UEen0gBB',
#    'track_href': 'https://api.spotify.com/v1/tracks/5h8G81Ls00kyf1UEen0gBB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5h8G81Ls00kyf1UEen0gBB',
#    'duration_ms': 60642,
#    'time_signature': 4}],
#  [{'danceability': 0.37,
#    'energy': 0.361,
#    'key': 9,
#    'loudness': -12.271,
#    'mode': 1,
#    'speechiness': 0.0321,
#    'acousticness': 0.81,
#    'instrumentalness': 0.87,
#    'liveness': 0.113,
#    'valence': 0.479,
#    'tempo': 66.409,
#    'type': 'audio_features',
#    'id': '6Tq4LginUMBOgZrUs8M40h',
#    'uri': 'spotify:track:6Tq4LginUMBOgZrUs8M40h',
#    'track_href': 'https://api.spotify.com/v1/tracks/6Tq4LginUMBOgZrUs8M40h',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tq4LginUMBOgZrUs8M40h',
#    'duration_ms': 266066,
#    'time_signature': 4}],
#  [{'danceability': 0.512,
#    'energy': 0.474,
#    'key': 2,
#    'loudness': -8.36,
#    'mode': 1,
#    'speechiness': 0.0371,
#    'acousticness': 0.0787,
#    'instrumentalness': 0.00345,
#    'liveness': 0.134,
#    'valence': 0.194,
#    'tempo': 183.991,
#    'type': 'audio_features',
#    'id': '7ynvnjTj1XI8ByUq3F8MUw',
#    'uri': 'spotify:track:7ynvnjTj1XI8ByUq3F8MUw',
#    'track_href': 'https://api.spotify.com/v1/tracks/7ynvnjTj1XI8ByUq3F8MUw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ynvnjTj1XI8ByUq3F8MUw',
#    'duration_ms': 234286,
#    'time_signature': 4}],
#  [{'danceability': 0.784,
#    'energy': 0.539,
#    'key': 11,
#    'loudness': -7.676,
#    'mode': 0,
#    'speechiness': 0.0406,
#    'acousticness': 0.317,
#    'instrumentalness': 0.377,
#    'liveness': 0.0989,
#    'valence': 0.962,
#    'tempo': 122.53,
#    'type': 'audio_features',
#    'id': '4wHh4AljzbSGMJvynLgK1q',
#    'uri': 'spotify:track:4wHh4AljzbSGMJvynLgK1q',
#    'track_href': 'https://api.spotify.com/v1/tracks/4wHh4AljzbSGMJvynLgK1q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wHh4AljzbSGMJvynLgK1q',
#    'duration_ms': 221227,
#    'time_signature': 4}],
#  [{'danceability': 0.599,
#    'energy': 0.939,
#    'key': 2,
#    'loudness': -5.714,
#    'mode': 1,
#    'speechiness': 0.0746,
#    'acousticness': 0.000555,
#    'instrumentalness': 0,
#    'liveness': 0.0947,
#    'valence': 0.648,
#    'tempo': 121.853,
#    'type': 'audio_features',
#    'id': '2UFEbNhbk9GsxCigXPq3XI',
#    'uri': 'spotify:track:2UFEbNhbk9GsxCigXPq3XI',
#    'track_href': 'https://api.spotify.com/v1/tracks/2UFEbNhbk9GsxCigXPq3XI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UFEbNhbk9GsxCigXPq3XI',
#    'duration_ms': 308427,
#    'time_signature': 4}],
#  [{'danceability': 0.243,
#    'energy': 0.984,
#    'key': 10,
#    'loudness': -3.384,
#    'mode': 0,
#    'speechiness': 0.323,
#    'acousticness': 2.32e-05,
#    'instrumentalness': 0.00938,
#    'liveness': 0.131,
#    'valence': 0.239,
#    'tempo': 180.979,
#    'type': 'audio_features',
#    'id': '7IcXkPWjwqUCCkI2mUf02h',
#    'uri': 'spotify:track:7IcXkPWjwqUCCkI2mUf02h',
#    'track_href': 'https://api.spotify.com/v1/tracks/7IcXkPWjwqUCCkI2mUf02h',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7IcXkPWjwqUCCkI2mUf02h',
#    'duration_ms': 190333,
#    'time_signature': 4}],
#  [{'danceability': 0.548,
#    'energy': 0.816,
#    'key': 2,
#    'loudness': -4.478,
#    'mode': 1,
#    'speechiness': 0.0499,
#    'acousticness': 0.0104,
#    'instrumentalness': 0.0543,
#    'liveness': 0.152,
#    'valence': 0.857,
#    'tempo': 174.993,
#    'type': 'audio_features',
#    'id': '1595LW73XBxkRk2ciQOHfr',
#    'uri': 'spotify:track:1595LW73XBxkRk2ciQOHfr',
#    'track_href': 'https://api.spotify.com/v1/tracks/1595LW73XBxkRk2ciQOHfr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1595LW73XBxkRk2ciQOHfr',
#    'duration_ms': 137760,
#    'time_signature': 4}],
#  [{'danceability': 0.159,
#    'energy': 0.23,
#    'key': 2,
#    'loudness': -15.441,
#    'mode': 0,
#    'speechiness': 0.033,
#    'acousticness': 0.672,
#    'instrumentalness': 0.848,
#    'liveness': 0.0951,
#    'valence': 0.0632,
#    'tempo': 84.933,
#    'type': 'audio_features',
#    'id': '2vEkF5UazjaBL6CpG2BZgq',
#    'uri': 'spotify:track:2vEkF5UazjaBL6CpG2BZgq',
#    'track_href': 'https://api.spotify.com/v1/tracks/2vEkF5UazjaBL6CpG2BZgq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vEkF5UazjaBL6CpG2BZgq',
#    'duration_ms': 145293,
#    'time_signature': 4}],
#  [{'danceability': 0.154,
#    'energy': 0.972,
#    'key': 7,
#    'loudness': -3.626,
#    'mode': 1,
#    'speechiness': 0.111,
#    'acousticness': 0.000913,
#    'instrumentalness': 0.247,
#    'liveness': 0.368,
#    'valence': 0.213,
#    'tempo': 205.467,
#    'type': 'audio_features',
#    'id': '6GWS0Nb3ybf3tQXZ0FlfZf',
#    'uri': 'spotify:track:6GWS0Nb3ybf3tQXZ0FlfZf',
#    'track_href': 'https://api.spotify.com/v1/tracks/6GWS0Nb3ybf3tQXZ0FlfZf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GWS0Nb3ybf3tQXZ0FlfZf',
#    'duration_ms': 192920,
#    'time_signature': 4}],
#  [{'danceability': 0.725,
#    'energy': 0.774,
#    'key': 4,
#    'loudness': -6.402,
#    'mode': 0,
#    'speechiness': 0.174,
#    'acousticness': 0.135,
#    'instrumentalness': 0.126,
#    'liveness': 0.0844,
#    'valence': 0.72,
#    'tempo': 78.976,
#    'type': 'audio_features',
#    'id': '5FcjGGKpQx6dvuGcbAcFtC',
#    'uri': 'spotify:track:5FcjGGKpQx6dvuGcbAcFtC',
#    'track_href': 'https://api.spotify.com/v1/tracks/5FcjGGKpQx6dvuGcbAcFtC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FcjGGKpQx6dvuGcbAcFtC',
#    'duration_ms': 194960,
#    'time_signature': 4}],
#  [{'danceability': 0.365,
#    'energy': 0.0299,
#    'key': 6,
#    'loudness': -20.546,
#    'mode': 1,
#    'speechiness': 0.0709,
#    'acousticness': 0.946,
#    'instrumentalness': 0.49,
#    'liveness': 0.111,
#    'valence': 0.255,
#    'tempo': 80.762,
#    'type': 'audio_features',
#    'id': '4YpfqCRwb3ttShlTNaB2jU',
#    'uri': 'spotify:track:4YpfqCRwb3ttShlTNaB2jU',
#    'track_href': 'https://api.spotify.com/v1/tracks/4YpfqCRwb3ttShlTNaB2jU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YpfqCRwb3ttShlTNaB2jU',
#    'duration_ms': 153693,
#    'time_signature': 4}],
#  [{'danceability': 0.488,
#    'energy': 0.341,
#    'key': 2,
#    'loudness': -11.907,
#    'mode': 1,
#    'speechiness': 0.0256,
#    'acousticness': 0.681,
#    'instrumentalness': 0,
#    'liveness': 0.0844,
#    'valence': 0.463,
#    'tempo': 79.377,
#    'type': 'audio_features',
#    'id': '00fyPXxe2SCBHnFwEO9Eh1',
#    'uri': 'spotify:track:00fyPXxe2SCBHnFwEO9Eh1',
#    'track_href': 'https://api.spotify.com/v1/tracks/00fyPXxe2SCBHnFwEO9Eh1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00fyPXxe2SCBHnFwEO9Eh1',
#    'duration_ms': 212120,
#    'time_signature': 4}],
#  [{'danceability': 0.461,
#    'energy': 0.575,
#    'key': 10,
#    'loudness': -10.709,
#    'mode': 1,
#    'speechiness': 0.0538,
#    'acousticness': 0.517,
#    'instrumentalness': 0,
#    'liveness': 0.138,
#    'valence': 0.549,
#    'tempo': 82.634,
#    'type': 'audio_features',
#    'id': '691jw4auDZjaTOwUJmtoSy',
#    'uri': 'spotify:track:691jw4auDZjaTOwUJmtoSy',
#    'track_href': 'https://api.spotify.com/v1/tracks/691jw4auDZjaTOwUJmtoSy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/691jw4auDZjaTOwUJmtoSy',
#    'duration_ms': 229173,
#    'time_signature': 4}],
#  [{'danceability': 0.257,
#    'energy': 0.412,
#    'key': 1,
#    'loudness': -11.788,
#    'mode': 1,
#    'speechiness': 0.0287,
#    'acousticness': 0.361,
#    'instrumentalness': 8.68e-05,
#    'liveness': 0.0702,
#    'valence': 0.858,
#    'tempo': 152.126,
#    'type': 'audio_features',
#    'id': '4dkoqJrP0L8FXftrMZongF',
#    'uri': 'spotify:track:4dkoqJrP0L8FXftrMZongF',
#    'track_href': 'https://api.spotify.com/v1/tracks/4dkoqJrP0L8FXftrMZongF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dkoqJrP0L8FXftrMZongF',
#    'duration_ms': 228133,
#    'time_signature': 4}],
#  [{'danceability': 0.252,
#    'energy': 0.395,
#    'key': 1,
#    'loudness': -12.323,
#    'mode': 1,
#    'speechiness': 0.0283,
#    'acousticness': 0.405,
#    'instrumentalness': 0.000119,
#    'liveness': 0.0635,
#    'valence': 0.84,
#    'tempo': 154.06,
#    'type': 'audio_features',
#    'id': '2Yh0H2OXI2UItG9GGfQzlK',
#    'uri': 'spotify:track:2Yh0H2OXI2UItG9GGfQzlK',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Yh0H2OXI2UItG9GGfQzlK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Yh0H2OXI2UItG9GGfQzlK',
#    'duration_ms': 229787,
#    'time_signature': 4}],
#  [{'danceability': 0.702,
#    'energy': 0.447,
#    'key': 7,
#    'loudness': -10.122,
#    'mode': 1,
#    'speechiness': 0.0308,
#    'acousticness': 0.366,
#    'instrumentalness': 0,
#    'liveness': 0.153,
#    'valence': 0.944,
#    'tempo': 93.02,
#    'type': 'audio_features',
#    'id': '0IxxqsYBcCHEQ1HqLYJnwx',
#    'uri': 'spotify:track:0IxxqsYBcCHEQ1HqLYJnwx',
#    'track_href': 'https://api.spotify.com/v1/tracks/0IxxqsYBcCHEQ1HqLYJnwx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0IxxqsYBcCHEQ1HqLYJnwx',
#    'duration_ms': 150373,
#    'time_signature': 4}],
#  [{'danceability': 0.704,
#    'energy': 0.317,
#    'key': 0,
#    'loudness': -13.127,
#    'mode': 1,
#    'speechiness': 0.0551,
#    'acousticness': 0.956,
#    'instrumentalness': 0.499,
#    'liveness': 0.139,
#    'valence': 0.783,
#    'tempo': 108.165,
#    'type': 'audio_features',
#    'id': '1aQmitUScES0kpdge6BtF4',
#    'uri': 'spotify:track:1aQmitUScES0kpdge6BtF4',
#    'track_href': 'https://api.spotify.com/v1/tracks/1aQmitUScES0kpdge6BtF4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aQmitUScES0kpdge6BtF4',
#    'duration_ms': 354333,
#    'time_signature': 4}],
#  [{'danceability': 0.704,
#    'energy': 0.317,
#    'key': 0,
#    'loudness': -13.127,
#    'mode': 1,
#    'speechiness': 0.0551,
#    'acousticness': 0.956,
#    'instrumentalness': 0.499,
#    'liveness': 0.139,
#    'valence': 0.783,
#    'tempo': 108.165,
#    'type': 'audio_features',
#    'id': '1aQmitUScES0kpdge6BtF4',
#    'uri': 'spotify:track:1aQmitUScES0kpdge6BtF4',
#    'track_href': 'https://api.spotify.com/v1/tracks/1aQmitUScES0kpdge6BtF4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aQmitUScES0kpdge6BtF4',
#    'duration_ms': 354333,
#    'time_signature': 4}],
#  [{'danceability': 0.786,
#    'energy': 0.846,
#    'key': 8,
#    'loudness': -3.752,
#    'mode': 1,
#    'speechiness': 0.0391,
#    'acousticness': 0.00144,
#    'instrumentalness': 0.0172,
#    'liveness': 0.101,
#    'valence': 0.695,
#    'tempo': 107.976,
#    'type': 'audio_features',
#    'id': '7or26qS3BfpTtWO3BFw5GE',
#    'uri': 'spotify:track:7or26qS3BfpTtWO3BFw5GE',
#    'track_href': 'https://api.spotify.com/v1/tracks/7or26qS3BfpTtWO3BFw5GE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or26qS3BfpTtWO3BFw5GE',
#    'duration_ms': 165120,
#    'time_signature': 4}],
#  [{'danceability': 0.327,
#    'energy': 0.948,
#    'key': 8,
#    'loudness': -4.355,
#    'mode': 1,
#    'speechiness': 0.0711,
#    'acousticness': 0.0355,
#    'instrumentalness': 0.515,
#    'liveness': 0.126,
#    'valence': 0.469,
#    'tempo': 177.328,
#    'type': 'audio_features',
#    'id': '22cDldSuj9rgIMXwn4Ofn0',
#    'uri': 'spotify:track:22cDldSuj9rgIMXwn4Ofn0',
#    'track_href': 'https://api.spotify.com/v1/tracks/22cDldSuj9rgIMXwn4Ofn0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22cDldSuj9rgIMXwn4Ofn0',
#    'duration_ms': 207640,
#    'time_signature': 4}],
#  [{'danceability': 0.353,
#    'energy': 0.547,
#    'key': 5,
#    'loudness': -9.793,
#    'mode': 0,
#    'speechiness': 0.0364,
#    'acousticness': 0.126,
#    'instrumentalness': 0.116,
#    'liveness': 0.323,
#    'valence': 0.213,
#    'tempo': 146.043,
#    'type': 'audio_features',
#    'id': '5MbRyPfgokD3c6nxCV7TFG',
#    'uri': 'spotify:track:5MbRyPfgokD3c6nxCV7TFG',
#    'track_href': 'https://api.spotify.com/v1/tracks/5MbRyPfgokD3c6nxCV7TFG',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MbRyPfgokD3c6nxCV7TFG',
#    'duration_ms': 291440,
#    'time_signature': 3}],
#  [{'danceability': 0.624,
#    'energy': 0.911,
#    'key': 7,
#    'loudness': -7.482,
#    'mode': 1,
#    'speechiness': 0.0524,
#    'acousticness': 0.329,
#    'instrumentalness': 0.861,
#    'liveness': 0.0727,
#    'valence': 0.135,
#    'tempo': 122.902,
#    'type': 'audio_features',
#    'id': '3H3cOQ6LBLSvmcaV7QkZEu',
#    'uri': 'spotify:track:3H3cOQ6LBLSvmcaV7QkZEu',
#    'track_href': 'https://api.spotify.com/v1/tracks/3H3cOQ6LBLSvmcaV7QkZEu',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3H3cOQ6LBLSvmcaV7QkZEu',
#    'duration_ms': 212547,
#    'time_signature': 4}],
#  [{'danceability': 0.251,
#    'energy': 0.00342,
#    'key': 9,
#    'loudness': -38.794,
#    'mode': 0,
#    'speechiness': 0.0433,
#    'acousticness': 0.919,
#    'instrumentalness': 0.0255,
#    'liveness': 0.117,
#    'valence': 0.0504,
#    'tempo': 119.997,
#    'type': 'audio_features',
#    'id': '3Vef8GlFWEzrP23UwHjWWl',
#    'uri': 'spotify:track:3Vef8GlFWEzrP23UwHjWWl',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Vef8GlFWEzrP23UwHjWWl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Vef8GlFWEzrP23UwHjWWl',
#    'duration_ms': 152673,
#    'time_signature': 3}],
#  [{'danceability': 0.638,
#    'energy': 0.873,
#    'key': 11,
#    'loudness': -5.545,
#    'mode': 1,
#    'speechiness': 0.0363,
#    'acousticness': 0.0943,
#    'instrumentalness': 0.0395,
#    'liveness': 0.226,
#    'valence': 0.682,
#    'tempo': 115.95,
#    'type': 'audio_features',
#    'id': '6D43oUO6nImERk2psfXdNY',
#    'uri': 'spotify:track:6D43oUO6nImERk2psfXdNY',
#    'track_href': 'https://api.spotify.com/v1/tracks/6D43oUO6nImERk2psfXdNY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6D43oUO6nImERk2psfXdNY',
#    'duration_ms': 352755,
#    'time_signature': 4}],
#  [{'danceability': 0.161,
#    'energy': 0.176,
#    'key': 8,
#    'loudness': -14.604,
#    'mode': 1,
#    'speechiness': 0.0446,
#    'acousticness': 0.986,
#    'instrumentalness': 0.000232,
#    'liveness': 0.178,
#    'valence': 0.0808,
#    'tempo': 67.503,
#    'type': 'audio_features',
#    'id': '7H819kvtogxVpKDFplUFKc',
#    'uri': 'spotify:track:7H819kvtogxVpKDFplUFKc',
#    'track_href': 'https://api.spotify.com/v1/tracks/7H819kvtogxVpKDFplUFKc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7H819kvtogxVpKDFplUFKc',
#    'duration_ms': 161653,
#    'time_signature': 4}],
#  [{'danceability': 0.16,
#    'energy': 0.17,
#    'key': 8,
#    'loudness': -20.478,
#    'mode': 1,
#    'speechiness': 0.0376,
#    'acousticness': 0.994,
#    'instrumentalness': 0.763,
#    'liveness': 0.0941,
#    'valence': 0.0399,
#    'tempo': 134.526,
#    'type': 'audio_features',
#    'id': '67kwRadxmmURPuWIpEyymY',
#    'uri': 'spotify:track:67kwRadxmmURPuWIpEyymY',
#    'track_href': 'https://api.spotify.com/v1/tracks/67kwRadxmmURPuWIpEyymY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67kwRadxmmURPuWIpEyymY',
#    'duration_ms': 59880,
#    'time_signature': 4}],
#  [{'danceability': 0.296,
#    'energy': 0.164,
#    'key': 5,
#    'loudness': -12.602,
#    'mode': 0,
#    'speechiness': 0.0348,
#    'acousticness': 0.959,
#    'instrumentalness': 0,
#    'liveness': 0.201,
#    'valence': 0.253,
#    'tempo': 85.346,
#    'type': 'audio_features',
#    'id': '1FEYWXG23hr3m2vXHpbZeq',
#    'uri': 'spotify:track:1FEYWXG23hr3m2vXHpbZeq',
#    'track_href': 'https://api.spotify.com/v1/tracks/1FEYWXG23hr3m2vXHpbZeq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FEYWXG23hr3m2vXHpbZeq',
#    'duration_ms': 88800,
#    'time_signature': 4}],
#  [{'danceability': 0.639,
#    'energy': 0.908,
#    'key': 0,
#    'loudness': -5.575,
#    'mode': 1,
#    'speechiness': 0.138,
#    'acousticness': 0.0735,
#    'instrumentalness': 0,
#    'liveness': 0.553,
#    'valence': 0.926,
#    'tempo': 156.029,
#    'type': 'audio_features',
#    'id': '1SfOQKZv0c9FqNXd2Kjt6P',
#    'uri': 'spotify:track:1SfOQKZv0c9FqNXd2Kjt6P',
#    'track_href': 'https://api.spotify.com/v1/tracks/1SfOQKZv0c9FqNXd2Kjt6P',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SfOQKZv0c9FqNXd2Kjt6P',
#    'duration_ms': 175467,
#    'time_signature': 4}],
#  [{'danceability': 0.495,
#    'energy': 0.854,
#    'key': 4,
#    'loudness': -5.699,
#    'mode': 1,
#    'speechiness': 0.0434,
#    'acousticness': 0.208,
#    'instrumentalness': 0,
#    'liveness': 0.0371,
#    'valence': 0.819,
#    'tempo': 77.967,
#    'type': 'audio_features',
#    'id': '3OUpVpFeNx5jeInhHqiNfs',
#    'uri': 'spotify:track:3OUpVpFeNx5jeInhHqiNfs',
#    'track_href': 'https://api.spotify.com/v1/tracks/3OUpVpFeNx5jeInhHqiNfs',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OUpVpFeNx5jeInhHqiNfs',
#    'duration_ms': 133347,
#    'time_signature': 4}],
#  [{'danceability': 0.81,
#    'energy': 0.502,
#    'key': 4,
#    'loudness': -10.399,
#    'mode': 1,
#    'speechiness': 0.0541,
#    'acousticness': 0.0805,
#    'instrumentalness': 0.0564,
#    'liveness': 0.177,
#    'valence': 0.685,
#    'tempo': 121.466,
#    'type': 'audio_features',
#    'id': '2zsz6dip4W83IlAgp2zP4Y',
#    'uri': 'spotify:track:2zsz6dip4W83IlAgp2zP4Y',
#    'track_href': 'https://api.spotify.com/v1/tracks/2zsz6dip4W83IlAgp2zP4Y',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zsz6dip4W83IlAgp2zP4Y',
#    'duration_ms': 128480,
#    'time_signature': 4}],
#  [{'danceability': 0.306,
#    'energy': 0.872,
#    'key': 2,
#    'loudness': -7.313,
#    'mode': 1,
#    'speechiness': 0.05,
#    'acousticness': 0.00792,
#    'instrumentalness': 0.8,
#    'liveness': 0.261,
#    'valence': 0.648,
#    'tempo': 167.946,
#    'type': 'audio_features',
#    'id': '3OsUjkcv1C1v5udFhgRSFg',
#    'uri': 'spotify:track:3OsUjkcv1C1v5udFhgRSFg',
#    'track_href': 'https://api.spotify.com/v1/tracks/3OsUjkcv1C1v5udFhgRSFg',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OsUjkcv1C1v5udFhgRSFg',
#    'duration_ms': 287880,
#    'time_signature': 4}],
#  [None],
#  [{'danceability': 0.314,
#    'energy': 0.874,
#    'key': 9,
#    'loudness': -6.33,
#    'mode': 1,
#    'speechiness': 0.0398,
#    'acousticness': 0.05,
#    'instrumentalness': 0.0784,
#    'liveness': 0.411,
#    'valence': 0.398,
#    'tempo': 159.829,
#    'type': 'audio_features',
#    'id': '2Ol6GoKiAvPOyk52QIQvf7',
#    'uri': 'spotify:track:2Ol6GoKiAvPOyk52QIQvf7',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Ol6GoKiAvPOyk52QIQvf7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Ol6GoKiAvPOyk52QIQvf7',
#    'duration_ms': 265573,
#    'time_signature': 4}],
#  [{'danceability': 0.216,
#    'energy': 0.517,
#    'key': 2,
#    'loudness': -8.211,
#    'mode': 0,
#    'speechiness': 0.0325,
#    'acousticness': 0.0366,
#    'instrumentalness': 0.318,
#    'liveness': 0.35,
#    'valence': 0.129,
#    'tempo': 99.434,
#    'type': 'audio_features',
#    'id': '1mYPdmzGjsYpWnFF2XO3MJ',
#    'uri': 'spotify:track:1mYPdmzGjsYpWnFF2XO3MJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/1mYPdmzGjsYpWnFF2XO3MJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mYPdmzGjsYpWnFF2XO3MJ',
#    'duration_ms': 322547,
#    'time_signature': 3}],
#  [{'danceability': 0.792,
#    'energy': 0.892,
#    'key': 7,
#    'loudness': -5.626,
#    'mode': 1,
#    'speechiness': 0.171,
#    'acousticness': 0.109,
#    'instrumentalness': 0,
#    'liveness': 0.0695,
#    'valence': 0.816,
#    'tempo': 108.305,
#    'type': 'audio_features',
#    'id': '4knSB7lhQAtO6UqUeaGox8',
#    'uri': 'spotify:track:4knSB7lhQAtO6UqUeaGox8',
#    'track_href': 'https://api.spotify.com/v1/tracks/4knSB7lhQAtO6UqUeaGox8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4knSB7lhQAtO6UqUeaGox8',
#    'duration_ms': 208787,
#    'time_signature': 4}],
#  [{'danceability': 0.426,
#    'energy': 0.502,
#    'key': 1,
#    'loudness': -11.085,
#    'mode': 0,
#    'speechiness': 0.0296,
#    'acousticness': 0.582,
#    'instrumentalness': 0.206,
#    'liveness': 0.123,
#    'valence': 0.153,
#    'tempo': 130.018,
#    'type': 'audio_features',
#    'id': '27U2Idl2Jl63dltNrgP6rm',
#    'uri': 'spotify:track:27U2Idl2Jl63dltNrgP6rm',
#    'track_href': 'https://api.spotify.com/v1/tracks/27U2Idl2Jl63dltNrgP6rm',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27U2Idl2Jl63dltNrgP6rm',
#    'duration_ms': 254852,
#    'time_signature': 3}],
#  [{'danceability': 0.723,
#    'energy': 0.716,
#    'key': 3,
#    'loudness': -6.407,
#    'mode': 0,
#    'speechiness': 0.0437,
#    'acousticness': 5.42e-05,
#    'instrumentalness': 0.905,
#    'liveness': 0.072,
#    'valence': 0.0748,
#    'tempo': 128.701,
#    'type': 'audio_features',
#    'id': '0HadrlP2mwJidGF3pyBX4H',
#    'uri': 'spotify:track:0HadrlP2mwJidGF3pyBX4H',
#    'track_href': 'https://api.spotify.com/v1/tracks/0HadrlP2mwJidGF3pyBX4H',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HadrlP2mwJidGF3pyBX4H',
#    'duration_ms': 316253,
#    'time_signature': 4}],
#  [{'danceability': 0.723,
#    'energy': 0.716,
#    'key': 3,
#    'loudness': -6.407,
#    'mode': 0,
#    'speechiness': 0.0437,
#    'acousticness': 5.42e-05,
#    'instrumentalness': 0.905,
#    'liveness': 0.072,
#    'valence': 0.0748,
#    'tempo': 128.701,
#    'type': 'audio_features',
#    'id': '1PH5Es89c1cENU8WVuWwbp',
#    'uri': 'spotify:track:1PH5Es89c1cENU8WVuWwbp',
#    'track_href': 'https://api.spotify.com/v1/tracks/1PH5Es89c1cENU8WVuWwbp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PH5Es89c1cENU8WVuWwbp',
#    'duration_ms': 316253,
#    'time_signature': 4}],
#  [{'danceability': 0.729,
#    'energy': 0.767,
#    'key': 3,
#    'loudness': -6.809,
#    'mode': 0,
#    'speechiness': 0.0621,
#    'acousticness': 0.121,
#    'instrumentalness': 0.0294,
#    'liveness': 0.0839,
#    'valence': 0.748,
#    'tempo': 119.965,
#    'type': 'audio_features',
#    'id': '22ZIa4vKhUFzb4YZqp7g94',
#    'uri': 'spotify:track:22ZIa4vKhUFzb4YZqp7g94',
#    'track_href': 'https://api.spotify.com/v1/tracks/22ZIa4vKhUFzb4YZqp7g94',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22ZIa4vKhUFzb4YZqp7g94',
#    'duration_ms': 240360,
#    'time_signature': 4}],
#  [{'danceability': 0.432,
#    'energy': 0.796,
#    'key': 0,
#    'loudness': -9.39,
#    'mode': 1,
#    'speechiness': 0.0546,
#    'acousticness': 0.000613,
#    'instrumentalness': 1.79e-05,
#    'liveness': 0.239,
#    'valence': 0.183,
#    'tempo': 119.997,
#    'type': 'audio_features',
#    'id': '5GRhjCK4XgTajZvcP8FsRw',
#    'uri': 'spotify:track:5GRhjCK4XgTajZvcP8FsRw',
#    'track_href': 'https://api.spotify.com/v1/tracks/5GRhjCK4XgTajZvcP8FsRw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GRhjCK4XgTajZvcP8FsRw',
#    'duration_ms': 216911,
#    'time_signature': 4}],
#  [{'danceability': 0.457,
#    'energy': 0.0952,
#    'key': 2,
#    'loudness': -15.476,
#    'mode': 1,
#    'speechiness': 0.0413,
#    'acousticness': 0.693,
#    'instrumentalness': 0.032,
#    'liveness': 0.113,
#    'valence': 0.138,
#    'tempo': 139.432,
#    'type': 'audio_features',
#    'id': '2hkfe7ug1Wabzapt5HQec4',
#    'uri': 'spotify:track:2hkfe7ug1Wabzapt5HQec4',
#    'track_href': 'https://api.spotify.com/v1/tracks/2hkfe7ug1Wabzapt5HQec4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2hkfe7ug1Wabzapt5HQec4',
#    'duration_ms': 199760,
#    'time_signature': 5}],
#  [{'danceability': 0.665,
#    'energy': 0.809,
#    'key': 9,
#    'loudness': -8.263,
#    'mode': 1,
#    'speechiness': 0.0391,
#    'acousticness': 0.0382,
#    'instrumentalness': 0.855,
#    'liveness': 0.378,
#    'valence': 0.472,
#    'tempo': 120.009,
#    'type': 'audio_features',
#    'id': '1Lwux3cAXrUG3UWjUEGteT',
#    'uri': 'spotify:track:1Lwux3cAXrUG3UWjUEGteT',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Lwux3cAXrUG3UWjUEGteT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Lwux3cAXrUG3UWjUEGteT',
#    'duration_ms': 482223,
#    'time_signature': 4}],
#  [{'danceability': 0.518,
#    'energy': 0.624,
#    'key': 0,
#    'loudness': -6.134,
#    'mode': 1,
#    'speechiness': 0.0256,
#    'acousticness': 0.0312,
#    'instrumentalness': 0.000171,
#    'liveness': 0.131,
#    'valence': 0.241,
#    'tempo': 87.565,
#    'type': 'audio_features',
#    'id': '62nFeTispaiYq1KzGrONsl',
#    'uri': 'spotify:track:62nFeTispaiYq1KzGrONsl',
#    'track_href': 'https://api.spotify.com/v1/tracks/62nFeTispaiYq1KzGrONsl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62nFeTispaiYq1KzGrONsl',
#    'duration_ms': 216880,
#    'time_signature': 4}],
#  [{'danceability': 0.668,
#    'energy': 0.477,
#    'key': 4,
#    'loudness': -8.709,
#    'mode': 0,
#    'speechiness': 0.0358,
#    'acousticness': 0.517,
#    'instrumentalness': 0.446,
#    'liveness': 0.139,
#    'valence': 0.0966,
#    'tempo': 88.005,
#    'type': 'audio_features',
#    'id': '51ygW389BW4Dut3B69pSwc',
#    'uri': 'spotify:track:51ygW389BW4Dut3B69pSwc',
#    'track_href': 'https://api.spotify.com/v1/tracks/51ygW389BW4Dut3B69pSwc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51ygW389BW4Dut3B69pSwc',
#    'duration_ms': 228747,
#    'time_signature': 4}],
#  [{'danceability': 0.669,
#    'energy': 0.203,
#    'key': 5,
#    'loudness': -11.059,
#    'mode': 1,
#    'speechiness': 0.0317,
#    'acousticness': 0.706,
#    'instrumentalness': 0.221,
#    'liveness': 0.107,
#    'valence': 0.265,
#    'tempo': 125.864,
#    'type': 'audio_features',
#    'id': '0MOMLuhHqNgJ7uAceOPmfj',
#    'uri': 'spotify:track:0MOMLuhHqNgJ7uAceOPmfj',
#    'track_href': 'https://api.spotify.com/v1/tracks/0MOMLuhHqNgJ7uAceOPmfj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MOMLuhHqNgJ7uAceOPmfj',
#    'duration_ms': 375973,
#    'time_signature': 4}],
#  [{'danceability': 0.49,
#    'energy': 0.579,
#    'key': 1,
#    'loudness': -10.301,
#    'mode': 0,
#    'speechiness': 0.0344,
#    'acousticness': 0.217,
#    'instrumentalness': 0,
#    'liveness': 0.0644,
#    'valence': 0.879,
#    'tempo': 119.403,
#    'type': 'audio_features',
#    'id': '5tztLBvTlNC15Np2tnQ5Ll',
#    'uri': 'spotify:track:5tztLBvTlNC15Np2tnQ5Ll',
#    'track_href': 'https://api.spotify.com/v1/tracks/5tztLBvTlNC15Np2tnQ5Ll',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5tztLBvTlNC15Np2tnQ5Ll',
#    'duration_ms': 122573,
#    'time_signature': 4}],
#  [{'danceability': 0.481,
#    'energy': 0.49,
#    'key': 6,
#    'loudness': -10.098,
#    'mode': 1,
#    'speechiness': 0.0271,
#    'acousticness': 0.0536,
#    'instrumentalness': 0.123,
#    'liveness': 0.0915,
#    'valence': 0.0378,
#    'tempo': 152.04,
#    'type': 'audio_features',
#    'id': '3rrtbnOBDzKQfyYKTezEFe',
#    'uri': 'spotify:track:3rrtbnOBDzKQfyYKTezEFe',
#    'track_href': 'https://api.spotify.com/v1/tracks/3rrtbnOBDzKQfyYKTezEFe',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rrtbnOBDzKQfyYKTezEFe',
#    'duration_ms': 287000,
#    'time_signature': 4}],
#  [{'danceability': 0.701,
#    'energy': 0.182,
#    'key': 2,
#    'loudness': -17.068,
#    'mode': 1,
#    'speechiness': 0.0381,
#    'acousticness': 0.835,
#    'instrumentalness': 0.0276,
#    'liveness': 0.109,
#    'valence': 0.125,
#    'tempo': 117.885,
#    'type': 'audio_features',
#    'id': '5dIZa3pwSn1vDenZpSBEFO',
#    'uri': 'spotify:track:5dIZa3pwSn1vDenZpSBEFO',
#    'track_href': 'https://api.spotify.com/v1/tracks/5dIZa3pwSn1vDenZpSBEFO',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dIZa3pwSn1vDenZpSBEFO',
#    'duration_ms': 185733,
#    'time_signature': 4}],
#  [{'danceability': 0.261,
#    'energy': 0.805,
#    'key': 0,
#    'loudness': -5.722,
#    'mode': 0,
#    'speechiness': 0.0408,
#    'acousticness': 0.0436,
#    'instrumentalness': 0,
#    'liveness': 0.375,
#    'valence': 0.858,
#    'tempo': 155.586,
#    'type': 'audio_features',
#    'id': '2vCsB0tzKlAtsSwB4NBprX',
#    'uri': 'spotify:track:2vCsB0tzKlAtsSwB4NBprX',
#    'track_href': 'https://api.spotify.com/v1/tracks/2vCsB0tzKlAtsSwB4NBprX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vCsB0tzKlAtsSwB4NBprX',
#    'duration_ms': 139333,
#    'time_signature': 4}],
#  [{'danceability': 0.203,
#    'energy': 0.663,
#    'key': 1,
#    'loudness': -8.037,
#    'mode': 0,
#    'speechiness': 0.0349,
#    'acousticness': 0.0203,
#    'instrumentalness': 0,
#    'liveness': 0.899,
#    'valence': 0.725,
#    'tempo': 169.994,
#    'type': 'audio_features',
#    'id': '7j021TxcicWprdXpCcMBeH',
#    'uri': 'spotify:track:7j021TxcicWprdXpCcMBeH',
#    'track_href': 'https://api.spotify.com/v1/tracks/7j021TxcicWprdXpCcMBeH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7j021TxcicWprdXpCcMBeH',
#    'duration_ms': 135253,
#    'time_signature': 5}],
#  [{'danceability': 0.416,
#    'energy': 0.563,
#    'key': 1,
#    'loudness': -8.724,
#    'mode': 0,
#    'speechiness': 0.0298,
#    'acousticness': 0.207,
#    'instrumentalness': 0,
#    'liveness': 0.343,
#    'valence': 0.9,
#    'tempo': 77.56,
#    'type': 'audio_features',
#    'id': '4joiWvli4qJVEW6qZV2i2J',
#    'uri': 'spotify:track:4joiWvli4qJVEW6qZV2i2J',
#    'track_href': 'https://api.spotify.com/v1/tracks/4joiWvli4qJVEW6qZV2i2J',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4joiWvli4qJVEW6qZV2i2J',
#    'duration_ms': 127853,
#    'time_signature': 4}],
#  [{'danceability': 0.652,
#    'energy': 0.829,
#    'key': 5,
#    'loudness': -4.982,
#    'mode': 0,
#    'speechiness': 0.0499,
#    'acousticness': 0.141,
#    'instrumentalness': 0,
#    'liveness': 0.0971,
#    'valence': 0.438,
#    'tempo': 130.915,
#    'type': 'audio_features',
#    'id': '2NsQgzcCEy9hZbHaBG4Xfy',
#    'uri': 'spotify:track:2NsQgzcCEy9hZbHaBG4Xfy',
#    'track_href': 'https://api.spotify.com/v1/tracks/2NsQgzcCEy9hZbHaBG4Xfy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NsQgzcCEy9hZbHaBG4Xfy',
#    'duration_ms': 227067,
#    'time_signature': 4}],
#  [{'danceability': 0.652,
#    'energy': 0.829,
#    'key': 5,
#    'loudness': -4.982,
#    'mode': 0,
#    'speechiness': 0.0499,
#    'acousticness': 0.141,
#    'instrumentalness': 0,
#    'liveness': 0.0971,
#    'valence': 0.438,
#    'tempo': 130.915,
#    'type': 'audio_features',
#    'id': '2NsQgzcCEy9hZbHaBG4Xfy',
#    'uri': 'spotify:track:2NsQgzcCEy9hZbHaBG4Xfy',
#    'track_href': 'https://api.spotify.com/v1/tracks/2NsQgzcCEy9hZbHaBG4Xfy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NsQgzcCEy9hZbHaBG4Xfy',
#    'duration_ms': 227067,
#    'time_signature': 4}],
#  [{'danceability': 0.739,
#    'energy': 0.576,
#    'key': 1,
#    'loudness': -12.024,
#    'mode': 1,
#    'speechiness': 0.0472,
#    'acousticness': 0.122,
#    'instrumentalness': 0.00206,
#    'liveness': 0.0482,
#    'valence': 0.78,
#    'tempo': 108.81,
#    'type': 'audio_features',
#    'id': '2Wb9ejnmy27DUTUe9YF5Ew',
#    'uri': 'spotify:track:2Wb9ejnmy27DUTUe9YF5Ew',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Wb9ejnmy27DUTUe9YF5Ew',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wb9ejnmy27DUTUe9YF5Ew',
#    'duration_ms': 260427,
#    'time_signature': 4}],
#  [{'danceability': 0.55,
#    'energy': 0.751,
#    'key': 11,
#    'loudness': -7.818,
#    'mode': 0,
#    'speechiness': 0.0754,
#    'acousticness': 0.225,
#    'instrumentalness': 0.345,
#    'liveness': 0.133,
#    'valence': 0.347,
#    'tempo': 144.296,
#    'type': 'audio_features',
#    'id': '1zwB5h9WqvAlOTOUapSNSe',
#    'uri': 'spotify:track:1zwB5h9WqvAlOTOUapSNSe',
#    'track_href': 'https://api.spotify.com/v1/tracks/1zwB5h9WqvAlOTOUapSNSe',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zwB5h9WqvAlOTOUapSNSe',
#    'duration_ms': 219618,
#    'time_signature': 4}],
#  [{'danceability': 0.607,
#    'energy': 0.811,
#    'key': 0,
#    'loudness': -6.618,
#    'mode': 1,
#    'speechiness': 0.0443,
#    'acousticness': 0.033,
#    'instrumentalness': 0.354,
#    'liveness': 0.376,
#    'valence': 0.339,
#    'tempo': 118.987,
#    'type': 'audio_features',
#    'id': '6g4jkJItHpKs8Ljwt0EEMx',
#    'uri': 'spotify:track:6g4jkJItHpKs8Ljwt0EEMx',
#    'track_href': 'https://api.spotify.com/v1/tracks/6g4jkJItHpKs8Ljwt0EEMx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6g4jkJItHpKs8Ljwt0EEMx',
#    'duration_ms': 331507,
#    'time_signature': 4}],
#  [{'danceability': 0.711,
#    'energy': 0.468,
#    'key': 4,
#    'loudness': -4.797,
#    'mode': 0,
#    'speechiness': 0.0515,
#    'acousticness': 0.63,
#    'instrumentalness': 0.00427,
#    'liveness': 0.087,
#    'valence': 0.533,
#    'tempo': 127.458,
#    'type': 'audio_features',
#    'id': '40WXqoyOLAAugGmJWZU1FY',
#    'uri': 'spotify:track:40WXqoyOLAAugGmJWZU1FY',
#    'track_href': 'https://api.spotify.com/v1/tracks/40WXqoyOLAAugGmJWZU1FY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/40WXqoyOLAAugGmJWZU1FY',
#    'duration_ms': 234973,
#    'time_signature': 4}],
#  [{'danceability': 0.403,
#    'energy': 0.883,
#    'key': 2,
#    'loudness': -6.054,
#    'mode': 1,
#    'speechiness': 0.0745,
#    'acousticness': 8.44e-05,
#    'instrumentalness': 0.65,
#    'liveness': 0.126,
#    'valence': 0.078,
#    'tempo': 141.945,
#    'type': 'audio_features',
#    'id': '7uFZNMEZzAGOwQ6EZID1K4',
#    'uri': 'spotify:track:7uFZNMEZzAGOwQ6EZID1K4',
#    'track_href': 'https://api.spotify.com/v1/tracks/7uFZNMEZzAGOwQ6EZID1K4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uFZNMEZzAGOwQ6EZID1K4',
#    'duration_ms': 181373,
#    'time_signature': 4}],
#  [{'danceability': 0.632,
#    'energy': 0.225,
#    'key': 4,
#    'loudness': -13.423,
#    'mode': 1,
#    'speechiness': 0.0296,
#    'acousticness': 0.984,
#    'instrumentalness': 0.74,
#    'liveness': 0.112,
#    'valence': 0.683,
#    'tempo': 144.641,
#    'type': 'audio_features',
#    'id': '5OojmQ36TXkfL2JfoFJcaq',
#    'uri': 'spotify:track:5OojmQ36TXkfL2JfoFJcaq',
#    'track_href': 'https://api.spotify.com/v1/tracks/5OojmQ36TXkfL2JfoFJcaq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OojmQ36TXkfL2JfoFJcaq',
#    'duration_ms': 254053,
#    'time_signature': 4}],
#  [{'danceability': 0.557,
#    'energy': 0.728,
#    'key': 6,
#    'loudness': -6.181,
#    'mode': 1,
#    'speechiness': 0.0405,
#    'acousticness': 0.00156,
#    'instrumentalness': 5.13e-06,
#    'liveness': 0.118,
#    'valence': 0.216,
#    'tempo': 118.241,
#    'type': 'audio_features',
#    'id': '0kYUrLVQOfx21xuXu7OGrT',
#    'uri': 'spotify:track:0kYUrLVQOfx21xuXu7OGrT',
#    'track_href': 'https://api.spotify.com/v1/tracks/0kYUrLVQOfx21xuXu7OGrT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0kYUrLVQOfx21xuXu7OGrT',
#    'duration_ms': 301573,
#    'time_signature': 4}],
#  [{'danceability': 0.492,
#    'energy': 0.231,
#    'key': 9,
#    'loudness': -13.476,
#    'mode': 1,
#    'speechiness': 0.0368,
#    'acousticness': 0.972,
#    'instrumentalness': 6.16e-06,
#    'liveness': 0.229,
#    'valence': 0.61,
#    'tempo': 93.232,
#    'type': 'audio_features',
#    'id': '25RYJGPnetSkV8le7TeJnR',
#    'uri': 'spotify:track:25RYJGPnetSkV8le7TeJnR',
#    'track_href': 'https://api.spotify.com/v1/tracks/25RYJGPnetSkV8le7TeJnR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25RYJGPnetSkV8le7TeJnR',
#    'duration_ms': 184987,
#    'time_signature': 3}],
#  [{'danceability': 0.378,
#    'energy': 0.254,
#    'key': 7,
#    'loudness': -12.694,
#    'mode': 1,
#    'speechiness': 0.0399,
#    'acousticness': 0.891,
#    'instrumentalness': 0.00489,
#    'liveness': 0.109,
#    'valence': 0.19,
#    'tempo': 123.885,
#    'type': 'audio_features',
#    'id': '7hneDPwMWHSDxFZTaiGbaT',
#    'uri': 'spotify:track:7hneDPwMWHSDxFZTaiGbaT',
#    'track_href': 'https://api.spotify.com/v1/tracks/7hneDPwMWHSDxFZTaiGbaT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hneDPwMWHSDxFZTaiGbaT',
#    'duration_ms': 249320,
#    'time_signature': 4}],
#  [{'danceability': 0.587,
#    'energy': 0.431,
#    'key': 2,
#    'loudness': -9.495,
#    'mode': 1,
#    'speechiness': 0.0686,
#    'acousticness': 0.0722,
#    'instrumentalness': 0,
#    'liveness': 0.561,
#    'valence': 0.778,
#    'tempo': 95.937,
#    'type': 'audio_features',
#    'id': '2ck8lFrYAch2GPtdhpTHe3',
#    'uri': 'spotify:track:2ck8lFrYAch2GPtdhpTHe3',
#    'track_href': 'https://api.spotify.com/v1/tracks/2ck8lFrYAch2GPtdhpTHe3',
# ...
#    'key': 2,
#    'loudness': -4.015,
#    'mode': 1,
#    'speechiness': 0.0295,
#    'acousticness': 0.0202,
#    'instrumentalness': 2.39e-06,
#    'liveness': 0.523,
#    'valence': 0.561,
#    'tempo': 78.009,
#    'type': 'audio_features',
#    'id': '2ZE6D6ySdIjWpb6GObprV8',
#    'uri': 'spotify:track:2ZE6D6ySdIjWpb6GObprV8',
#    'track_href': 'https://api.spotify.com/v1/tracks/2ZE6D6ySdIjWpb6GObprV8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ZE6D6ySdIjWpb6GObprV8',
#    'duration_ms': 200360,
#    'time_signature': 4}],
#  [{'danceability': 0,
#    'energy': 0.223,
#    'key': 6,
#    'loudness': -18.325,
#    'mode': 1,
#    'speechiness': 0,
#    'acousticness': 0.995,
#    'instrumentalness': 0.0103,
#    'liveness': 0,
#    'valence': 0,
#    'tempo': 0,
#    'type': 'audio_features',
#    'id': '2PRmNoN16eUer6bJomStcf',
#    'uri': 'spotify:track:2PRmNoN16eUer6bJomStcf',
#    'track_href': 'https://api.spotify.com/v1/tracks/2PRmNoN16eUer6bJomStcf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PRmNoN16eUer6bJomStcf',
#    'duration_ms': 7240,
#    'time_signature': 0}],
#  [{'danceability': 0.639,
#    'energy': 0.894,
#    'key': 0,
#    'loudness': -7.184,
#    'mode': 1,
#    'speechiness': 0.142,
#    'acousticness': 0.313,
#    'instrumentalness': 4.3e-06,
#    'liveness': 0.168,
#    'valence': 0.39,
#    'tempo': 116.009,
#    'type': 'audio_features',
#    'id': '6OFKVE2HZdK3n2tbTDMhn3',
#    'uri': 'spotify:track:6OFKVE2HZdK3n2tbTDMhn3',
#    'track_href': 'https://api.spotify.com/v1/tracks/6OFKVE2HZdK3n2tbTDMhn3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OFKVE2HZdK3n2tbTDMhn3',
#    'duration_ms': 224627,
#    'time_signature': 4}],
#  [{'danceability': 0.432,
#    'energy': 0.391,
#    'key': 9,
#    'loudness': -14.99,
#    'mode': 1,
#    'speechiness': 0.242,
#    'acousticness': 0.813,
#    'instrumentalness': 0.00363,
#    'liveness': 0.155,
#    'valence': 0.744,
#    'tempo': 123.538,
#    'type': 'audio_features',
#    'id': '53aFGAl0Vebwp2bo8wtdWR',
#    'uri': 'spotify:track:53aFGAl0Vebwp2bo8wtdWR',
#    'track_href': 'https://api.spotify.com/v1/tracks/53aFGAl0Vebwp2bo8wtdWR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53aFGAl0Vebwp2bo8wtdWR',
#    'duration_ms': 117333,
#    'time_signature': 4}],
#  [{'danceability': 0.584,
#    'energy': 0.594,
#    'key': 9,
#    'loudness': -6.935,
#    'mode': 1,
#    'speechiness': 0.0487,
#    'acousticness': 0.142,
#    'instrumentalness': 0.00117,
#    'liveness': 0.105,
#    'valence': 0.36,
#    'tempo': 143.935,
#    'type': 'audio_features',
#    'id': '7DdXf9x75iEVCHWfoRwRuR',
#    'uri': 'spotify:track:7DdXf9x75iEVCHWfoRwRuR',
#    'track_href': 'https://api.spotify.com/v1/tracks/7DdXf9x75iEVCHWfoRwRuR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DdXf9x75iEVCHWfoRwRuR',
#    'duration_ms': 219400,
#    'time_signature': 4}],
#  [{'danceability': 0.646,
#    'energy': 0.825,
#    'key': 11,
#    'loudness': -8.302,
#    'mode': 0,
#    'speechiness': 0.0507,
#    'acousticness': 0.0388,
#    'instrumentalness': 0.00101,
#    'liveness': 0.26,
#    'valence': 0.378,
#    'tempo': 143.958,
#    'type': 'audio_features',
#    'id': '3v9fhN8ttoeH9AvpCi3IVM',
#    'uri': 'spotify:track:3v9fhN8ttoeH9AvpCi3IVM',
#    'track_href': 'https://api.spotify.com/v1/tracks/3v9fhN8ttoeH9AvpCi3IVM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v9fhN8ttoeH9AvpCi3IVM',
#    'duration_ms': 198210,
#    'time_signature': 4}],
#  [{'danceability': 0.646,
#    'energy': 0.825,
#    'key': 11,
#    'loudness': -8.302,
#    'mode': 0,
#    'speechiness': 0.0507,
#    'acousticness': 0.0388,
#    'instrumentalness': 0.00101,
#    'liveness': 0.26,
#    'valence': 0.378,
#    'tempo': 143.958,
#    'type': 'audio_features',
#    'id': '3v9fhN8ttoeH9AvpCi3IVM',
#    'uri': 'spotify:track:3v9fhN8ttoeH9AvpCi3IVM',
#    'track_href': 'https://api.spotify.com/v1/tracks/3v9fhN8ttoeH9AvpCi3IVM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v9fhN8ttoeH9AvpCi3IVM',
#    'duration_ms': 198210,
#    'time_signature': 4}],
#  [{'danceability': 0.432,
#    'energy': 0.585,
#    'key': 11,
#    'loudness': -8.861,
#    'mode': 0,
#    'speechiness': 0.033,
#    'acousticness': 0.00775,
#    'instrumentalness': 0.00294,
#    'liveness': 0.101,
#    'valence': 0.533,
#    'tempo': 152.458,
#    'type': 'audio_features',
#    'id': '7or8ysyNfJIDsr0vC7aqpQ',
#    'uri': 'spotify:track:7or8ysyNfJIDsr0vC7aqpQ',
#    'track_href': 'https://api.spotify.com/v1/tracks/7or8ysyNfJIDsr0vC7aqpQ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or8ysyNfJIDsr0vC7aqpQ',
#    'duration_ms': 260215,
#    'time_signature': 4}],
#  [{'danceability': 0.432,
#    'energy': 0.585,
#    'key': 11,
#    'loudness': -8.861,
#    'mode': 0,
#    'speechiness': 0.033,
#    'acousticness': 0.00775,
#    'instrumentalness': 0.00294,
#    'liveness': 0.101,
#    'valence': 0.533,
#    'tempo': 152.458,
#    'type': 'audio_features',
#    'id': '7or8ysyNfJIDsr0vC7aqpQ',
#    'uri': 'spotify:track:7or8ysyNfJIDsr0vC7aqpQ',
#    'track_href': 'https://api.spotify.com/v1/tracks/7or8ysyNfJIDsr0vC7aqpQ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or8ysyNfJIDsr0vC7aqpQ',
#    'duration_ms': 260215,
#    'time_signature': 4}],
#  [{'danceability': 0.655,
#    'energy': 0.729,
#    'key': 9,
#    'loudness': -4.862,
#    'mode': 1,
#    'speechiness': 0.0373,
#    'acousticness': 0.0785,
#    'instrumentalness': 0.00121,
#    'liveness': 0.728,
#    'valence': 0.534,
#    'tempo': 144.043,
#    'type': 'audio_features',
#    'id': '4S1rRmc82hWL9C5VBtxMKA',
#    'uri': 'spotify:track:4S1rRmc82hWL9C5VBtxMKA',
#    'track_href': 'https://api.spotify.com/v1/tracks/4S1rRmc82hWL9C5VBtxMKA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4S1rRmc82hWL9C5VBtxMKA',
#    'duration_ms': 215670,
#    'time_signature': 4}],
#  [{'danceability': 0.571,
#    'energy': 0.831,
#    'key': 11,
#    'loudness': -7.169,
#    'mode': 0,
#    'speechiness': 0.0291,
#    'acousticness': 0.0034,
#    'instrumentalness': 0.0273,
#    'liveness': 0.125,
#    'valence': 0.249,
#    'tempo': 136.993,
#    'type': 'audio_features',
#    'id': '0Na10nHw7B30hmjkxNK9WB',
#    'uri': 'spotify:track:0Na10nHw7B30hmjkxNK9WB',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Na10nHw7B30hmjkxNK9WB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Na10nHw7B30hmjkxNK9WB',
#    'duration_ms': 270571,
#    'time_signature': 4}],
#  [{'danceability': 0.571,
#    'energy': 0.831,
#    'key': 11,
#    'loudness': -7.169,
#    'mode': 0,
#    'speechiness': 0.0291,
#    'acousticness': 0.0034,
#    'instrumentalness': 0.0273,
#    'liveness': 0.125,
#    'valence': 0.249,
#    'tempo': 136.993,
#    'type': 'audio_features',
#    'id': '0Na10nHw7B30hmjkxNK9WB',
#    'uri': 'spotify:track:0Na10nHw7B30hmjkxNK9WB',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Na10nHw7B30hmjkxNK9WB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Na10nHw7B30hmjkxNK9WB',
#    'duration_ms': 270571,
#    'time_signature': 4}],
#  [{'danceability': 0.775,
#    'energy': 0.395,
#    'key': 0,
#    'loudness': -11.636,
#    'mode': 1,
#    'speechiness': 0.0364,
#    'acousticness': 0.714,
#    'instrumentalness': 0.939,
#    'liveness': 0.0778,
#    'valence': 0.707,
#    'tempo': 104.486,
#    'type': 'audio_features',
#    'id': '7vJvU9djy2i1lJOqMvj1fb',
#    'uri': 'spotify:track:7vJvU9djy2i1lJOqMvj1fb',
#    'track_href': 'https://api.spotify.com/v1/tracks/7vJvU9djy2i1lJOqMvj1fb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vJvU9djy2i1lJOqMvj1fb',
#    'duration_ms': 209640,
#    'time_signature': 3}],
#  [{'danceability': 0.469,
#    'energy': 0.507,
#    'key': 0,
#    'loudness': -8.917,
#    'mode': 0,
#    'speechiness': 0.0451,
#    'acousticness': 0.382,
#    'instrumentalness': 0,
#    'liveness': 0.0783,
#    'valence': 0.619,
#    'tempo': 112.984,
#    'type': 'audio_features',
#    'id': '3pKKxkeB1pOUMHwWBmKc3Y',
#    'uri': 'spotify:track:3pKKxkeB1pOUMHwWBmKc3Y',
#    'track_href': 'https://api.spotify.com/v1/tracks/3pKKxkeB1pOUMHwWBmKc3Y',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pKKxkeB1pOUMHwWBmKc3Y',
#    'duration_ms': 156827,
#    'time_signature': 4}],
#  [{'danceability': 0.75,
#    'energy': 0.319,
#    'key': 0,
#    'loudness': -12.141,
#    'mode': 1,
#    'speechiness': 0.0357,
#    'acousticness': 0.861,
#    'instrumentalness': 0.0254,
#    'liveness': 0.0615,
#    'valence': 0.275,
#    'tempo': 117.085,
#    'type': 'audio_features',
#    'id': '4WBpJC6ByANHehsZUW07Vd',
#    'uri': 'spotify:track:4WBpJC6ByANHehsZUW07Vd',
#    'track_href': 'https://api.spotify.com/v1/tracks/4WBpJC6ByANHehsZUW07Vd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WBpJC6ByANHehsZUW07Vd',
#    'duration_ms': 195160,
#    'time_signature': 4}],
#  [{'danceability': 0.452,
#    'energy': 0.915,
#    'key': 7,
#    'loudness': -6.516,
#    'mode': 1,
#    'speechiness': 0.0701,
#    'acousticness': 0.00201,
#    'instrumentalness': 0.126,
#    'liveness': 0.704,
#    'valence': 0.8,
#    'tempo': 171.37,
#    'type': 'audio_features',
#    'id': '3raHRmDxUhjQo0EKrWFTV0',
#    'uri': 'spotify:track:3raHRmDxUhjQo0EKrWFTV0',
#    'track_href': 'https://api.spotify.com/v1/tracks/3raHRmDxUhjQo0EKrWFTV0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3raHRmDxUhjQo0EKrWFTV0',
#    'duration_ms': 162203,
#    'time_signature': 4}],
#  [{'danceability': 0.701,
#    'energy': 0.306,
#    'key': 11,
#    'loudness': -16.647,
#    'mode': 1,
#    'speechiness': 0.0519,
#    'acousticness': 0.987,
#    'instrumentalness': 0.939,
#    'liveness': 0.111,
#    'valence': 0.325,
#    'tempo': 118.002,
#    'type': 'audio_features',
#    'id': '61cKlqGQuuk9tqvfTD2t39',
#    'uri': 'spotify:track:61cKlqGQuuk9tqvfTD2t39',
#    'track_href': 'https://api.spotify.com/v1/tracks/61cKlqGQuuk9tqvfTD2t39',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61cKlqGQuuk9tqvfTD2t39',
#    'duration_ms': 243667,
#    'time_signature': 4}],
#  [{'danceability': 0.839,
#    'energy': 0.84,
#    'key': 11,
#    'loudness': -8.721,
#    'mode': 1,
#    'speechiness': 0.0474,
#    'acousticness': 0.389,
#    'instrumentalness': 0.0319,
#    'liveness': 0.114,
#    'valence': 0.904,
#    'tempo': 117.98,
#    'type': 'audio_features',
#    'id': '5mpLcXEsk3jjzLFGuNKk5I',
#    'uri': 'spotify:track:5mpLcXEsk3jjzLFGuNKk5I',
#    'track_href': 'https://api.spotify.com/v1/tracks/5mpLcXEsk3jjzLFGuNKk5I',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mpLcXEsk3jjzLFGuNKk5I',
#    'duration_ms': 262000,
#    'time_signature': 4}],
#  [{'danceability': 0.729,
#    'energy': 0.662,
#    'key': 11,
#    'loudness': -12.919,
#    'mode': 1,
#    'speechiness': 0.0574,
#    'acousticness': 0.564,
#    'instrumentalness': 0.000651,
#    'liveness': 0.686,
#    'valence': 0.803,
#    'tempo': 118.014,
#    'type': 'audio_features',
#    'id': '7b829PewSJYvL0MaUoNfNY',
#    'uri': 'spotify:track:7b829PewSJYvL0MaUoNfNY',
#    'track_href': 'https://api.spotify.com/v1/tracks/7b829PewSJYvL0MaUoNfNY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7b829PewSJYvL0MaUoNfNY',
#    'duration_ms': 267776,
#    'time_signature': 4}],
#  [{'danceability': 0.728,
#    'energy': 0.659,
#    'key': 11,
#    'loudness': -12.919,
#    'mode': 1,
#    'speechiness': 0.059,
#    'acousticness': 0.563,
#    'instrumentalness': 0.000504,
#    'liveness': 0.687,
#    'valence': 0.821,
#    'tempo': 118.015,
#    'type': 'audio_features',
#    'id': '07yKQCRBUdUTSv6y3mbZ1e',
#    'uri': 'spotify:track:07yKQCRBUdUTSv6y3mbZ1e',
#    'track_href': 'https://api.spotify.com/v1/tracks/07yKQCRBUdUTSv6y3mbZ1e',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07yKQCRBUdUTSv6y3mbZ1e',
#    'duration_ms': 267776,
#    'time_signature': 4}],
#  [{'danceability': 0.64,
#    'energy': 0.728,
#    'key': 2,
#    'loudness': -6.189,
#    'mode': 1,
#    'speechiness': 0.0758,
#    'acousticness': 0.0561,
#    'instrumentalness': 6.73e-05,
#    'liveness': 0.174,
#    'valence': 0.52,
#    'tempo': 141.953,
#    'type': 'audio_features',
#    'id': '6SszAhtfZZ0iY8Od3YHxhX',
#    'uri': 'spotify:track:6SszAhtfZZ0iY8Od3YHxhX',
#    'track_href': 'https://api.spotify.com/v1/tracks/6SszAhtfZZ0iY8Od3YHxhX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SszAhtfZZ0iY8Od3YHxhX',
#    'duration_ms': 187095,
#    'time_signature': 4}],
#  [{'danceability': 0.664,
#    'energy': 0.525,
#    'key': 0,
#    'loudness': -8.448,
#    'mode': 0,
#    'speechiness': 0.0309,
#    'acousticness': 0.0917,
#    'instrumentalness': 0.526,
#    'liveness': 0.162,
#    'valence': 0.503,
#    'tempo': 120.068,
#    'type': 'audio_features',
#    'id': '55TrsYFuwiFsdrgchaeXW7',
#    'uri': 'spotify:track:55TrsYFuwiFsdrgchaeXW7',
#    'track_href': 'https://api.spotify.com/v1/tracks/55TrsYFuwiFsdrgchaeXW7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/55TrsYFuwiFsdrgchaeXW7',
#    'duration_ms': 177000,
#    'time_signature': 4}],
#  [{'danceability': 0.438,
#    'energy': 0.462,
#    'key': 3,
#    'loudness': -13.638,
#    'mode': 1,
#    'speechiness': 0.033,
#    'acousticness': 0.869,
#    'instrumentalness': 0.915,
#    'liveness': 0.0968,
#    'valence': 0.452,
#    'tempo': 144.025,
#    'type': 'audio_features',
#    'id': '4C7F5zCFfppYauKHjKpC34',
#    'uri': 'spotify:track:4C7F5zCFfppYauKHjKpC34',
#    'track_href': 'https://api.spotify.com/v1/tracks/4C7F5zCFfppYauKHjKpC34',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4C7F5zCFfppYauKHjKpC34',
#    'duration_ms': 194693,
#    'time_signature': 4}],
#  [{'danceability': 0.44,
#    'energy': 0.63,
#    'key': 7,
#    'loudness': -8.319,
#    'mode': 1,
#    'speechiness': 0.0512,
#    'acousticness': 0.241,
#    'instrumentalness': 7.95e-05,
#    'liveness': 0.137,
#    'valence': 0.0387,
#    'tempo': 125.557,
#    'type': 'audio_features',
#    'id': '6ZlolHAQKomJuKg4n5qOAP',
#    'uri': 'spotify:track:6ZlolHAQKomJuKg4n5qOAP',
#    'track_href': 'https://api.spotify.com/v1/tracks/6ZlolHAQKomJuKg4n5qOAP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZlolHAQKomJuKg4n5qOAP',
#    'duration_ms': 463520,
#    'time_signature': 4}],
#  [{'danceability': 0.591,
#    'energy': 0.622,
#    'key': 7,
#    'loudness': -7.454,
#    'mode': 0,
#    'speechiness': 0.0258,
#    'acousticness': 0.107,
#    'instrumentalness': 0.00174,
#    'liveness': 0.101,
#    'valence': 0.728,
#    'tempo': 112.519,
#    'type': 'audio_features',
#    'id': '4Rctx86F2SvaL2LgQRz1ww',
#    'uri': 'spotify:track:4Rctx86F2SvaL2LgQRz1ww',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Rctx86F2SvaL2LgQRz1ww',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Rctx86F2SvaL2LgQRz1ww',
#    'duration_ms': 184192,
#    'time_signature': 4}],
#  [{'danceability': 0.561,
#    'energy': 0.688,
#    'key': 9,
#    'loudness': -5.625,
#    'mode': 1,
#    'speechiness': 0.102,
#    'acousticness': 0.638,
#    'instrumentalness': 0,
#    'liveness': 0.2,
#    'valence': 0.747,
#    'tempo': 75.307,
#    'type': 'audio_features',
#    'id': '1s0uk3LmYulYhdiLlpxqzF',
#    'uri': 'spotify:track:1s0uk3LmYulYhdiLlpxqzF',
#    'track_href': 'https://api.spotify.com/v1/tracks/1s0uk3LmYulYhdiLlpxqzF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1s0uk3LmYulYhdiLlpxqzF',
#    'duration_ms': 176880,
#    'time_signature': 4}],
#  [{'danceability': 0.677,
#    'energy': 0.61,
#    'key': 7,
#    'loudness': -10.067,
#    'mode': 1,
#    'speechiness': 0.0317,
#    'acousticness': 0.737,
#    'instrumentalness': 5.12e-05,
#    'liveness': 0.233,
#    'valence': 0.578,
#    'tempo': 127.435,
#    'type': 'audio_features',
#    'id': '1bbX8eMgNGKtE9hDUmC35Y',
#    'uri': 'spotify:track:1bbX8eMgNGKtE9hDUmC35Y',
#    'track_href': 'https://api.spotify.com/v1/tracks/1bbX8eMgNGKtE9hDUmC35Y',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bbX8eMgNGKtE9hDUmC35Y',
#    'duration_ms': 110653,
#    'time_signature': 4}],
#  [{'danceability': 0.502,
#    'energy': 0.56,
#    'key': 6,
#    'loudness': -12.642,
#    'mode': 1,
#    'speechiness': 0.1,
#    'acousticness': 0.642,
#    'instrumentalness': 0,
#    'liveness': 0.038,
#    'valence': 0.945,
#    'tempo': 196.051,
#    'type': 'audio_features',
#    'id': '6oIOkcU6u5iPlQBHXGJwzN',
#    'uri': 'spotify:track:6oIOkcU6u5iPlQBHXGJwzN',
#    'track_href': 'https://api.spotify.com/v1/tracks/6oIOkcU6u5iPlQBHXGJwzN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6oIOkcU6u5iPlQBHXGJwzN',
#    'duration_ms': 143560,
#    'time_signature': 4}],
#  ...]

# %%
#  audio_f2=pd.DataFrame(audio_f[1], index= [0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\IronHack\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\IronHack\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\IronHack\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 audio_f2=pd.DataFrame(audio_f[1], index= [0])
#
# File C:\IronHack\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\IronHack\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 1

# %%
# audio_f2
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.419   0.565    5   -11.565     1       0.0347         0.137
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0             0.337     0.128    0.648  151.277  audio_features
#
#                        id                                   uri  \
# 0  3UnyplmZaq547hwsfOR5yy  spotify:track:3UnyplmZaq547hwsfOR5yy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3UnyplmZaq54...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3Uny...       197707
#
#    time_signature
# 0               4

# %%
audio_f2 = flatten(audio_f)

# %%
audio_f2
# Out:
# [{'danceability': 0.31,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -13.355,
#   'mode': 0,
#   'speechiness': 0.0863,
#   'acousticness': 0.094,
#   'instrumentalness': 0.0678,
#   'liveness': 0.113,
#   'valence': 0.122,
#   'tempo': 95.36,
#   'type': 'audio_features',
#   'id': '33xMbeHzmWd6Od0BmLZEUs',
#   'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#   'duration_ms': 152560,
#   'time_signature': 3},
#  {'danceability': 0.419,
#   'energy': 0.565,
#   'key': 5,
#   'loudness': -11.565,
#   'mode': 1,
#   'speechiness': 0.0347,
#   'acousticness': 0.137,
#   'instrumentalness': 0.337,
#   'liveness': 0.128,
#   'valence': 0.648,
#   'tempo': 151.277,
#   'type': 'audio_features',
#   'id': '3UnyplmZaq547hwsfOR5yy',
#   'uri': 'spotify:track:3UnyplmZaq547hwsfOR5yy',
#   'track_href': 'https://api.spotify.com/v1/tracks/3UnyplmZaq547hwsfOR5yy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3UnyplmZaq547hwsfOR5yy',
#   'duration_ms': 197707,
#   'time_signature': 4},
#  {'danceability': 0.354,
#   'energy': 0.302,
#   'key': 9,
#   'loudness': -13.078,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.59,
#   'instrumentalness': 0.0709,
#   'liveness': 0.111,
#   'valence': 0.223,
#   'tempo': 123.753,
#   'type': 'audio_features',
#   'id': '1w8QCSDH4QobcQeT4uMKLm',
#   'uri': 'spotify:track:1w8QCSDH4QobcQeT4uMKLm',
#   'track_href': 'https://api.spotify.com/v1/tracks/1w8QCSDH4QobcQeT4uMKLm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1w8QCSDH4QobcQeT4uMKLm',
#   'duration_ms': 244285,
#   'time_signature': 4},
#  {'danceability': 0.727,
#   'energy': 0.785,
#   'key': 5,
#   'loudness': -6.707,
#   'mode': 0,
#   'speechiness': 0.0603,
#   'acousticness': 0.325,
#   'instrumentalness': 0.126,
#   'liveness': 0.31,
#   'valence': 0.96,
#   'tempo': 129.649,
#   'type': 'audio_features',
#   'id': '7J9mBHG4J2eIfDAv5BehKA',
#   'uri': 'spotify:track:7J9mBHG4J2eIfDAv5BehKA',
#   'track_href': 'https://api.spotify.com/v1/tracks/7J9mBHG4J2eIfDAv5BehKA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7J9mBHG4J2eIfDAv5BehKA',
#   'duration_ms': 249940,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.724,
#   'key': 0,
#   'loudness': -5.967,
#   'mode': 1,
#   'speechiness': 0.026,
#   'acousticness': 0.0231,
#   'instrumentalness': 0.00311,
#   'liveness': 0.0919,
#   'valence': 0.385,
#   'tempo': 116.755,
#   'type': 'audio_features',
#   'id': '1VZedwJj1gyi88WFRhfThb',
#   'uri': 'spotify:track:1VZedwJj1gyi88WFRhfThb',
#   'track_href': 'https://api.spotify.com/v1/tracks/1VZedwJj1gyi88WFRhfThb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1VZedwJj1gyi88WFRhfThb',
#   'duration_ms': 278320,
#   'time_signature': 4},
#  {'danceability': 0.579,
#   'energy': 0.777,
#   'key': 4,
#   'loudness': -7.505,
#   'mode': 1,
#   'speechiness': 0.0304,
#   'acousticness': 0.0177,
#   'instrumentalness': 0.000248,
#   'liveness': 0.422,
#   'valence': 0.481,
#   'tempo': 109.994,
#   'type': 'audio_features',
#   'id': '3DSmOF7ETJHAQEqqgoSJao',
#   'uri': 'spotify:track:3DSmOF7ETJHAQEqqgoSJao',
#   'track_href': 'https://api.spotify.com/v1/tracks/3DSmOF7ETJHAQEqqgoSJao',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3DSmOF7ETJHAQEqqgoSJao',
#   'duration_ms': 247067,
#   'time_signature': 4},
#  {'danceability': 0.606,
#   'energy': 0.638,
#   'key': 3,
#   'loudness': -6.994,
#   'mode': 0,
#   'speechiness': 0.0339,
#   'acousticness': 0.0434,
#   'instrumentalness': 0.000247,
#   'liveness': 0.0887,
#   'valence': 0.817,
#   'tempo': 97.992,
#   'type': 'audio_features',
#   'id': '5HPnumlogzZtpLEaORZjz1',
#   'uri': 'spotify:track:5HPnumlogzZtpLEaORZjz1',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HPnumlogzZtpLEaORZjz1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HPnumlogzZtpLEaORZjz1',
#   'duration_ms': 213227,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.925,
#   'key': 6,
#   'loudness': -2.766,
#   'mode': 0,
#   'speechiness': 0.0463,
#   'acousticness': 0.00164,
#   'instrumentalness': 0.0243,
#   'liveness': 0.115,
#   'valence': 0.369,
#   'tempo': 125.501,
#   'type': 'audio_features',
#   'id': '6i99ThziImjuFABb8rUQvy',
#   'uri': 'spotify:track:6i99ThziImjuFABb8rUQvy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6i99ThziImjuFABb8rUQvy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6i99ThziImjuFABb8rUQvy',
#   'duration_ms': 243333,
#   'time_signature': 4},
#  {'danceability': 0.452,
#   'energy': 0.889,
#   'key': 4,
#   'loudness': -3.838,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.312,
#   'instrumentalness': 0.8,
#   'liveness': 0.558,
#   'valence': 0.591,
#   'tempo': 145.056,
#   'type': 'audio_features',
#   'id': '0nkLI0pdyTRpq7BsTFBufZ',
#   'uri': 'spotify:track:0nkLI0pdyTRpq7BsTFBufZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nkLI0pdyTRpq7BsTFBufZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nkLI0pdyTRpq7BsTFBufZ',
#   'duration_ms': 153133,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.889,
#   'key': 4,
#   'loudness': -3.838,
#   'mode': 1,
#   'speechiness': 0.0379,
#   'acousticness': 0.312,
#   'instrumentalness': 0.8,
#   'liveness': 0.558,
#   'valence': 0.592,
#   'tempo': 145.056,
#   'type': 'audio_features',
#   'id': '6Yu1OL8I0D4vjOzYdsXYGK',
#   'uri': 'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Yu1OL8I0D4vjOzYdsXYGK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Yu1OL8I0D4vjOzYdsXYGK',
#   'duration_ms': 153133,
#   'time_signature': 4},
#  {'danceability': 0.6,
#   'energy': 0.535,
#   'key': 9,
#   'loudness': -8.178,
#   'mode': 1,
#   'speechiness': 0.0298,
#   'acousticness': 0.00154,
#   'instrumentalness': 0.102,
#   'liveness': 0.123,
#   'valence': 0.566,
#   'tempo': 122.678,
#   'type': 'audio_features',
#   'id': '2HvTGx5fzFGpHSyRNvXd9T',
#   'uri': 'spotify:track:2HvTGx5fzFGpHSyRNvXd9T',
#   'track_href': 'https://api.spotify.com/v1/tracks/2HvTGx5fzFGpHSyRNvXd9T',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HvTGx5fzFGpHSyRNvXd9T',
#   'duration_ms': 175080,
#   'time_signature': 4},
#  {'danceability': 0.337,
#   'energy': 0.885,
#   'key': 2,
#   'loudness': -3.566,
#   'mode': 1,
#   'speechiness': 0.0419,
#   'acousticness': 0.004,
#   'instrumentalness': 0.0378,
#   'liveness': 0.141,
#   'valence': 0.389,
#   'tempo': 83.001,
#   'type': 'audio_features',
#   'id': '2XS4lIQ1bl9KSNsYtkqK46',
#   'uri': 'spotify:track:2XS4lIQ1bl9KSNsYtkqK46',
#   'track_href': 'https://api.spotify.com/v1/tracks/2XS4lIQ1bl9KSNsYtkqK46',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2XS4lIQ1bl9KSNsYtkqK46',
#   'duration_ms': 273133,
#   'time_signature': 3},
#  {'danceability': 0.6,
#   'energy': 0.853,
#   'key': 1,
#   'loudness': -7.584,
#   'mode': 1,
#   'speechiness': 0.0423,
#   'acousticness': 0.0489,
#   'instrumentalness': 0.346,
#   'liveness': 0.0934,
#   'valence': 0.847,
#   'tempo': 94.457,
#   'type': 'audio_features',
#   'id': '6dsq7Nt5mIFzvm5kIYNORy',
#   'uri': 'spotify:track:6dsq7Nt5mIFzvm5kIYNORy',
#   'track_href': 'https://api.spotify.com/v1/tracks/6dsq7Nt5mIFzvm5kIYNORy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6dsq7Nt5mIFzvm5kIYNORy',
#   'duration_ms': 237293,
#   'time_signature': 4},
#  {'danceability': 0.396,
#   'energy': 0.141,
#   'key': 6,
#   'loudness': -16.115,
#   'mode': 1,
#   'speechiness': 0.0294,
#   'acousticness': 0.919,
#   'instrumentalness': 0.434,
#   'liveness': 0.339,
#   'valence': 0.0443,
#   'tempo': 68.03,
#   'type': 'audio_features',
#   'id': '1wKGGfnznnXIvupuEZt9mM',
#   'uri': 'spotify:track:1wKGGfnznnXIvupuEZt9mM',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wKGGfnznnXIvupuEZt9mM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wKGGfnznnXIvupuEZt9mM',
#   'duration_ms': 150013,
#   'time_signature': 4},
#  {'danceability': 0.594,
#   'energy': 0.61,
#   'key': 11,
#   'loudness': -10.57,
#   'mode': 0,
#   'speechiness': 0.0388,
#   'acousticness': 0.829,
#   'instrumentalness': 0.208,
#   'liveness': 0.077,
#   'valence': 0.289,
#   'tempo': 129.963,
#   'type': 'audio_features',
#   'id': '7Jjqx75QRHaYsxF5WnHovC',
#   'uri': 'spotify:track:7Jjqx75QRHaYsxF5WnHovC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Jjqx75QRHaYsxF5WnHovC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Jjqx75QRHaYsxF5WnHovC',
#   'duration_ms': 292409,
#   'time_signature': 4},
#  {'danceability': 0.35,
#   'energy': 0.0959,
#   'key': 10,
#   'loudness': -17.471,
#   'mode': 1,
#   'speechiness': 0.0439,
#   'acousticness': 0.964,
#   'instrumentalness': 0.0024,
#   'liveness': 0.106,
#   'valence': 0.108,
#   'tempo': 143.861,
#   'type': 'audio_features',
#   'id': '7BIPYQPHbPVDE9UsA0eT72',
#   'uri': 'spotify:track:7BIPYQPHbPVDE9UsA0eT72',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BIPYQPHbPVDE9UsA0eT72',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BIPYQPHbPVDE9UsA0eT72',
#   'duration_ms': 200907,
#   'time_signature': 4},
#  {'danceability': 0.15,
#   'energy': 0.237,
#   'key': 3,
#   'loudness': -10.799,
#   'mode': 0,
#   'speechiness': 0.0323,
#   'acousticness': 0.778,
#   'instrumentalness': 0.0977,
#   'liveness': 0.0897,
#   'valence': 0.0733,
#   'tempo': 67.276,
#   'type': 'audio_features',
#   'id': '4KEw5m7CZXVbpWbHVK4OrV',
#   'uri': 'spotify:track:4KEw5m7CZXVbpWbHVK4OrV',
#   'track_href': 'https://api.spotify.com/v1/tracks/4KEw5m7CZXVbpWbHVK4OrV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4KEw5m7CZXVbpWbHVK4OrV',
#   'duration_ms': 292120,
#   'time_signature': 4},
#  {'danceability': 0.733,
#   'energy': 0.719,
#   'key': 5,
#   'loudness': -8.776,
#   'mode': 0,
#   'speechiness': 0.0462,
#   'acousticness': 0.0609,
#   'instrumentalness': 0.108,
#   'liveness': 0.0807,
#   'valence': 0.327,
#   'tempo': 114.959,
#   'type': 'audio_features',
#   'id': '2YTRLoG5jdzCp4yg3B6OnH',
#   'uri': 'spotify:track:2YTRLoG5jdzCp4yg3B6OnH',
#   'track_href': 'https://api.spotify.com/v1/tracks/2YTRLoG5jdzCp4yg3B6OnH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YTRLoG5jdzCp4yg3B6OnH',
#   'duration_ms': 309787,
#   'time_signature': 4},
#  {'danceability': 0.491,
#   'energy': 0.93,
#   'key': 11,
#   'loudness': -6.412,
#   'mode': 0,
#   'speechiness': 0.0347,
#   'acousticness': 4.23e-05,
#   'instrumentalness': 0.612,
#   'liveness': 0.219,
#   'valence': 0.623,
#   'tempo': 99.924,
#   'type': 'audio_features',
#   'id': '5MPryR3oJGmWnSYM7X2GGE',
#   'uri': 'spotify:track:5MPryR3oJGmWnSYM7X2GGE',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MPryR3oJGmWnSYM7X2GGE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MPryR3oJGmWnSYM7X2GGE',
#   'duration_ms': 163227,
#   'time_signature': 4},
#  {'danceability': 0.703,
#   'energy': 0.7,
#   'key': 2,
#   'loudness': -6.152,
#   'mode': 1,
#   'speechiness': 0.135,
#   'acousticness': 0.049,
#   'instrumentalness': 0,
#   'liveness': 0.365,
#   'valence': 0.512,
#   'tempo': 119.966,
#   'type': 'audio_features',
#   'id': '4ymUtICOpIlyvFf3URM7XZ',
#   'uri': 'spotify:track:4ymUtICOpIlyvFf3URM7XZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/4ymUtICOpIlyvFf3URM7XZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4ymUtICOpIlyvFf3URM7XZ',
#   'duration_ms': 208248,
#   'time_signature': 4},
#  {'danceability': 0.488,
#   'energy': 0.503,
#   'key': 0,
#   'loudness': -8.89,
#   'mode': 1,
#   'speechiness': 0.0326,
#   'acousticness': 0.00583,
#   'instrumentalness': 0.809,
#   'liveness': 0.101,
#   'valence': 0.38,
#   'tempo': 144.035,
#   'type': 'audio_features',
#   'id': '2lffRiAET2Xt6BNb4EmkS2',
#   'uri': 'spotify:track:2lffRiAET2Xt6BNb4EmkS2',
#   'track_href': 'https://api.spotify.com/v1/tracks/2lffRiAET2Xt6BNb4EmkS2',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lffRiAET2Xt6BNb4EmkS2',
#   'duration_ms': 298613,
#   'time_signature': 4},
#  {'danceability': 0.583,
#   'energy': 0.917,
#   'key': 6,
#   'loudness': -8.96,
#   'mode': 0,
#   'speechiness': 0.567,
#   'acousticness': 0.493,
#   'instrumentalness': 0.0608,
#   'liveness': 0.296,
#   'valence': 0.44,
#   'tempo': 171.157,
#   'type': 'audio_features',
#   'id': '3oQ52Mqz2ih8KjligVoQrG',
#   'uri': 'spotify:track:3oQ52Mqz2ih8KjligVoQrG',
#   'track_href': 'https://api.spotify.com/v1/tracks/3oQ52Mqz2ih8KjligVoQrG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3oQ52Mqz2ih8KjligVoQrG',
#   'duration_ms': 34014,
#   'time_signature': 4},
#  None,
#  {'danceability': 0.487,
#   'energy': 0.753,
#   'key': 6,
#   'loudness': -10.533,
#   'mode': 0,
#   'speechiness': 0.306,
#   'acousticness': 0.665,
#   'instrumentalness': 0.00144,
#   'liveness': 0.231,
#   'valence': 0.847,
#   'tempo': 112.907,
#   'type': 'audio_features',
#   'id': '5h8G81Ls00kyf1UEen0gBB',
#   'uri': 'spotify:track:5h8G81Ls00kyf1UEen0gBB',
#   'track_href': 'https://api.spotify.com/v1/tracks/5h8G81Ls00kyf1UEen0gBB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5h8G81Ls00kyf1UEen0gBB',
#   'duration_ms': 60642,
#   'time_signature': 4},
#  {'danceability': 0.37,
#   'energy': 0.361,
#   'key': 9,
#   'loudness': -12.271,
#   'mode': 1,
#   'speechiness': 0.0321,
#   'acousticness': 0.81,
#   'instrumentalness': 0.87,
#   'liveness': 0.113,
#   'valence': 0.479,
#   'tempo': 66.409,
#   'type': 'audio_features',
#   'id': '6Tq4LginUMBOgZrUs8M40h',
#   'uri': 'spotify:track:6Tq4LginUMBOgZrUs8M40h',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Tq4LginUMBOgZrUs8M40h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tq4LginUMBOgZrUs8M40h',
#   'duration_ms': 266066,
#   'time_signature': 4},
#  {'danceability': 0.512,
#   'energy': 0.474,
#   'key': 2,
#   'loudness': -8.36,
#   'mode': 1,
#   'speechiness': 0.0371,
#   'acousticness': 0.0787,
#   'instrumentalness': 0.00345,
#   'liveness': 0.134,
#   'valence': 0.194,
#   'tempo': 183.991,
#   'type': 'audio_features',
#   'id': '7ynvnjTj1XI8ByUq3F8MUw',
#   'uri': 'spotify:track:7ynvnjTj1XI8ByUq3F8MUw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7ynvnjTj1XI8ByUq3F8MUw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ynvnjTj1XI8ByUq3F8MUw',
#   'duration_ms': 234286,
#   'time_signature': 4},
#  {'danceability': 0.784,
#   'energy': 0.539,
#   'key': 11,
#   'loudness': -7.676,
#   'mode': 0,
#   'speechiness': 0.0406,
#   'acousticness': 0.317,
#   'instrumentalness': 0.377,
#   'liveness': 0.0989,
#   'valence': 0.962,
#   'tempo': 122.53,
#   'type': 'audio_features',
#   'id': '4wHh4AljzbSGMJvynLgK1q',
#   'uri': 'spotify:track:4wHh4AljzbSGMJvynLgK1q',
#   'track_href': 'https://api.spotify.com/v1/tracks/4wHh4AljzbSGMJvynLgK1q',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4wHh4AljzbSGMJvynLgK1q',
#   'duration_ms': 221227,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.939,
#   'key': 2,
#   'loudness': -5.714,
#   'mode': 1,
#   'speechiness': 0.0746,
#   'acousticness': 0.000555,
#   'instrumentalness': 0,
#   'liveness': 0.0947,
#   'valence': 0.648,
#   'tempo': 121.853,
#   'type': 'audio_features',
#   'id': '2UFEbNhbk9GsxCigXPq3XI',
#   'uri': 'spotify:track:2UFEbNhbk9GsxCigXPq3XI',
#   'track_href': 'https://api.spotify.com/v1/tracks/2UFEbNhbk9GsxCigXPq3XI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UFEbNhbk9GsxCigXPq3XI',
#   'duration_ms': 308427,
#   'time_signature': 4},
#  {'danceability': 0.243,
#   'energy': 0.984,
#   'key': 10,
#   'loudness': -3.384,
#   'mode': 0,
#   'speechiness': 0.323,
#   'acousticness': 2.32e-05,
#   'instrumentalness': 0.00938,
#   'liveness': 0.131,
#   'valence': 0.239,
#   'tempo': 180.979,
#   'type': 'audio_features',
#   'id': '7IcXkPWjwqUCCkI2mUf02h',
#   'uri': 'spotify:track:7IcXkPWjwqUCCkI2mUf02h',
#   'track_href': 'https://api.spotify.com/v1/tracks/7IcXkPWjwqUCCkI2mUf02h',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7IcXkPWjwqUCCkI2mUf02h',
#   'duration_ms': 190333,
#   'time_signature': 4},
#  {'danceability': 0.548,
#   'energy': 0.816,
#   'key': 2,
#   'loudness': -4.478,
#   'mode': 1,
#   'speechiness': 0.0499,
#   'acousticness': 0.0104,
#   'instrumentalness': 0.0543,
#   'liveness': 0.152,
#   'valence': 0.857,
#   'tempo': 174.993,
#   'type': 'audio_features',
#   'id': '1595LW73XBxkRk2ciQOHfr',
#   'uri': 'spotify:track:1595LW73XBxkRk2ciQOHfr',
#   'track_href': 'https://api.spotify.com/v1/tracks/1595LW73XBxkRk2ciQOHfr',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1595LW73XBxkRk2ciQOHfr',
#   'duration_ms': 137760,
#   'time_signature': 4},
#  {'danceability': 0.159,
#   'energy': 0.23,
#   'key': 2,
#   'loudness': -15.441,
#   'mode': 0,
#   'speechiness': 0.033,
#   'acousticness': 0.672,
#   'instrumentalness': 0.848,
#   'liveness': 0.0951,
#   'valence': 0.0632,
#   'tempo': 84.933,
#   'type': 'audio_features',
#   'id': '2vEkF5UazjaBL6CpG2BZgq',
#   'uri': 'spotify:track:2vEkF5UazjaBL6CpG2BZgq',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vEkF5UazjaBL6CpG2BZgq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vEkF5UazjaBL6CpG2BZgq',
#   'duration_ms': 145293,
#   'time_signature': 4},
#  {'danceability': 0.154,
#   'energy': 0.972,
#   'key': 7,
#   'loudness': -3.626,
#   'mode': 1,
#   'speechiness': 0.111,
#   'acousticness': 0.000913,
#   'instrumentalness': 0.247,
#   'liveness': 0.368,
#   'valence': 0.213,
#   'tempo': 205.467,
#   'type': 'audio_features',
#   'id': '6GWS0Nb3ybf3tQXZ0FlfZf',
#   'uri': 'spotify:track:6GWS0Nb3ybf3tQXZ0FlfZf',
#   'track_href': 'https://api.spotify.com/v1/tracks/6GWS0Nb3ybf3tQXZ0FlfZf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GWS0Nb3ybf3tQXZ0FlfZf',
#   'duration_ms': 192920,
#   'time_signature': 4},
#  {'danceability': 0.725,
#   'energy': 0.774,
#   'key': 4,
#   'loudness': -6.402,
#   'mode': 0,
#   'speechiness': 0.174,
#   'acousticness': 0.135,
#   'instrumentalness': 0.126,
#   'liveness': 0.0844,
#   'valence': 0.72,
#   'tempo': 78.976,
#   'type': 'audio_features',
#   'id': '5FcjGGKpQx6dvuGcbAcFtC',
#   'uri': 'spotify:track:5FcjGGKpQx6dvuGcbAcFtC',
#   'track_href': 'https://api.spotify.com/v1/tracks/5FcjGGKpQx6dvuGcbAcFtC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5FcjGGKpQx6dvuGcbAcFtC',
#   'duration_ms': 194960,
#   'time_signature': 4},
#  {'danceability': 0.365,
#   'energy': 0.0299,
#   'key': 6,
#   'loudness': -20.546,
#   'mode': 1,
#   'speechiness': 0.0709,
#   'acousticness': 0.946,
#   'instrumentalness': 0.49,
#   'liveness': 0.111,
#   'valence': 0.255,
#   'tempo': 80.762,
#   'type': 'audio_features',
#   'id': '4YpfqCRwb3ttShlTNaB2jU',
#   'uri': 'spotify:track:4YpfqCRwb3ttShlTNaB2jU',
#   'track_href': 'https://api.spotify.com/v1/tracks/4YpfqCRwb3ttShlTNaB2jU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YpfqCRwb3ttShlTNaB2jU',
#   'duration_ms': 153693,
#   'time_signature': 4},
#  {'danceability': 0.488,
#   'energy': 0.341,
#   'key': 2,
#   'loudness': -11.907,
#   'mode': 1,
#   'speechiness': 0.0256,
#   'acousticness': 0.681,
#   'instrumentalness': 0,
#   'liveness': 0.0844,
#   'valence': 0.463,
#   'tempo': 79.377,
#   'type': 'audio_features',
#   'id': '00fyPXxe2SCBHnFwEO9Eh1',
#   'uri': 'spotify:track:00fyPXxe2SCBHnFwEO9Eh1',
#   'track_href': 'https://api.spotify.com/v1/tracks/00fyPXxe2SCBHnFwEO9Eh1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00fyPXxe2SCBHnFwEO9Eh1',
#   'duration_ms': 212120,
#   'time_signature': 4},
#  {'danceability': 0.461,
#   'energy': 0.575,
#   'key': 10,
#   'loudness': -10.709,
#   'mode': 1,
#   'speechiness': 0.0538,
#   'acousticness': 0.517,
#   'instrumentalness': 0,
#   'liveness': 0.138,
#   'valence': 0.549,
#   'tempo': 82.634,
#   'type': 'audio_features',
#   'id': '691jw4auDZjaTOwUJmtoSy',
#   'uri': 'spotify:track:691jw4auDZjaTOwUJmtoSy',
#   'track_href': 'https://api.spotify.com/v1/tracks/691jw4auDZjaTOwUJmtoSy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/691jw4auDZjaTOwUJmtoSy',
#   'duration_ms': 229173,
#   'time_signature': 4},
#  {'danceability': 0.257,
#   'energy': 0.412,
#   'key': 1,
#   'loudness': -11.788,
#   'mode': 1,
#   'speechiness': 0.0287,
#   'acousticness': 0.361,
#   'instrumentalness': 8.68e-05,
#   'liveness': 0.0702,
#   'valence': 0.858,
#   'tempo': 152.126,
#   'type': 'audio_features',
#   'id': '4dkoqJrP0L8FXftrMZongF',
#   'uri': 'spotify:track:4dkoqJrP0L8FXftrMZongF',
#   'track_href': 'https://api.spotify.com/v1/tracks/4dkoqJrP0L8FXftrMZongF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4dkoqJrP0L8FXftrMZongF',
#   'duration_ms': 228133,
#   'time_signature': 4},
#  {'danceability': 0.252,
#   'energy': 0.395,
#   'key': 1,
#   'loudness': -12.323,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.405,
#   'instrumentalness': 0.000119,
#   'liveness': 0.0635,
#   'valence': 0.84,
#   'tempo': 154.06,
#   'type': 'audio_features',
#   'id': '2Yh0H2OXI2UItG9GGfQzlK',
#   'uri': 'spotify:track:2Yh0H2OXI2UItG9GGfQzlK',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Yh0H2OXI2UItG9GGfQzlK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Yh0H2OXI2UItG9GGfQzlK',
#   'duration_ms': 229787,
#   'time_signature': 4},
#  {'danceability': 0.702,
#   'energy': 0.447,
#   'key': 7,
#   'loudness': -10.122,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.366,
#   'instrumentalness': 0,
#   'liveness': 0.153,
#   'valence': 0.944,
#   'tempo': 93.02,
#   'type': 'audio_features',
#   'id': '0IxxqsYBcCHEQ1HqLYJnwx',
#   'uri': 'spotify:track:0IxxqsYBcCHEQ1HqLYJnwx',
#   'track_href': 'https://api.spotify.com/v1/tracks/0IxxqsYBcCHEQ1HqLYJnwx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0IxxqsYBcCHEQ1HqLYJnwx',
#   'duration_ms': 150373,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.317,
#   'key': 0,
#   'loudness': -13.127,
#   'mode': 1,
#   'speechiness': 0.0551,
#   'acousticness': 0.956,
#   'instrumentalness': 0.499,
#   'liveness': 0.139,
#   'valence': 0.783,
#   'tempo': 108.165,
#   'type': 'audio_features',
#   'id': '1aQmitUScES0kpdge6BtF4',
#   'uri': 'spotify:track:1aQmitUScES0kpdge6BtF4',
#   'track_href': 'https://api.spotify.com/v1/tracks/1aQmitUScES0kpdge6BtF4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aQmitUScES0kpdge6BtF4',
#   'duration_ms': 354333,
#   'time_signature': 4},
#  {'danceability': 0.704,
#   'energy': 0.317,
#   'key': 0,
#   'loudness': -13.127,
#   'mode': 1,
#   'speechiness': 0.0551,
#   'acousticness': 0.956,
#   'instrumentalness': 0.499,
#   'liveness': 0.139,
#   'valence': 0.783,
#   'tempo': 108.165,
#   'type': 'audio_features',
#   'id': '1aQmitUScES0kpdge6BtF4',
#   'uri': 'spotify:track:1aQmitUScES0kpdge6BtF4',
#   'track_href': 'https://api.spotify.com/v1/tracks/1aQmitUScES0kpdge6BtF4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1aQmitUScES0kpdge6BtF4',
#   'duration_ms': 354333,
#   'time_signature': 4},
#  {'danceability': 0.786,
#   'energy': 0.846,
#   'key': 8,
#   'loudness': -3.752,
#   'mode': 1,
#   'speechiness': 0.0391,
#   'acousticness': 0.00144,
#   'instrumentalness': 0.0172,
#   'liveness': 0.101,
#   'valence': 0.695,
#   'tempo': 107.976,
#   'type': 'audio_features',
#   'id': '7or26qS3BfpTtWO3BFw5GE',
#   'uri': 'spotify:track:7or26qS3BfpTtWO3BFw5GE',
#   'track_href': 'https://api.spotify.com/v1/tracks/7or26qS3BfpTtWO3BFw5GE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or26qS3BfpTtWO3BFw5GE',
#   'duration_ms': 165120,
#   'time_signature': 4},
#  {'danceability': 0.327,
#   'energy': 0.948,
#   'key': 8,
#   'loudness': -4.355,
#   'mode': 1,
#   'speechiness': 0.0711,
#   'acousticness': 0.0355,
#   'instrumentalness': 0.515,
#   'liveness': 0.126,
#   'valence': 0.469,
#   'tempo': 177.328,
#   'type': 'audio_features',
#   'id': '22cDldSuj9rgIMXwn4Ofn0',
#   'uri': 'spotify:track:22cDldSuj9rgIMXwn4Ofn0',
#   'track_href': 'https://api.spotify.com/v1/tracks/22cDldSuj9rgIMXwn4Ofn0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22cDldSuj9rgIMXwn4Ofn0',
#   'duration_ms': 207640,
#   'time_signature': 4},
#  {'danceability': 0.353,
#   'energy': 0.547,
#   'key': 5,
#   'loudness': -9.793,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.126,
#   'instrumentalness': 0.116,
#   'liveness': 0.323,
#   'valence': 0.213,
#   'tempo': 146.043,
#   'type': 'audio_features',
#   'id': '5MbRyPfgokD3c6nxCV7TFG',
#   'uri': 'spotify:track:5MbRyPfgokD3c6nxCV7TFG',
#   'track_href': 'https://api.spotify.com/v1/tracks/5MbRyPfgokD3c6nxCV7TFG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5MbRyPfgokD3c6nxCV7TFG',
#   'duration_ms': 291440,
#   'time_signature': 3},
#  {'danceability': 0.624,
#   'energy': 0.911,
#   'key': 7,
#   'loudness': -7.482,
#   'mode': 1,
#   'speechiness': 0.0524,
#   'acousticness': 0.329,
#   'instrumentalness': 0.861,
#   'liveness': 0.0727,
#   'valence': 0.135,
#   'tempo': 122.902,
#   'type': 'audio_features',
#   'id': '3H3cOQ6LBLSvmcaV7QkZEu',
#   'uri': 'spotify:track:3H3cOQ6LBLSvmcaV7QkZEu',
#   'track_href': 'https://api.spotify.com/v1/tracks/3H3cOQ6LBLSvmcaV7QkZEu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3H3cOQ6LBLSvmcaV7QkZEu',
#   'duration_ms': 212547,
#   'time_signature': 4},
#  {'danceability': 0.251,
#   'energy': 0.00342,
#   'key': 9,
#   'loudness': -38.794,
#   'mode': 0,
#   'speechiness': 0.0433,
#   'acousticness': 0.919,
#   'instrumentalness': 0.0255,
#   'liveness': 0.117,
#   'valence': 0.0504,
#   'tempo': 119.997,
#   'type': 'audio_features',
#   'id': '3Vef8GlFWEzrP23UwHjWWl',
#   'uri': 'spotify:track:3Vef8GlFWEzrP23UwHjWWl',
#   'track_href': 'https://api.spotify.com/v1/tracks/3Vef8GlFWEzrP23UwHjWWl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Vef8GlFWEzrP23UwHjWWl',
#   'duration_ms': 152673,
#   'time_signature': 3},
#  {'danceability': 0.638,
#   'energy': 0.873,
#   'key': 11,
#   'loudness': -5.545,
#   'mode': 1,
#   'speechiness': 0.0363,
#   'acousticness': 0.0943,
#   'instrumentalness': 0.0395,
#   'liveness': 0.226,
#   'valence': 0.682,
#   'tempo': 115.95,
#   'type': 'audio_features',
#   'id': '6D43oUO6nImERk2psfXdNY',
#   'uri': 'spotify:track:6D43oUO6nImERk2psfXdNY',
#   'track_href': 'https://api.spotify.com/v1/tracks/6D43oUO6nImERk2psfXdNY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6D43oUO6nImERk2psfXdNY',
#   'duration_ms': 352755,
#   'time_signature': 4},
#  {'danceability': 0.161,
#   'energy': 0.176,
#   'key': 8,
#   'loudness': -14.604,
#   'mode': 1,
#   'speechiness': 0.0446,
#   'acousticness': 0.986,
#   'instrumentalness': 0.000232,
#   'liveness': 0.178,
#   'valence': 0.0808,
#   'tempo': 67.503,
#   'type': 'audio_features',
#   'id': '7H819kvtogxVpKDFplUFKc',
#   'uri': 'spotify:track:7H819kvtogxVpKDFplUFKc',
#   'track_href': 'https://api.spotify.com/v1/tracks/7H819kvtogxVpKDFplUFKc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7H819kvtogxVpKDFplUFKc',
#   'duration_ms': 161653,
#   'time_signature': 4},
#  {'danceability': 0.16,
#   'energy': 0.17,
#   'key': 8,
#   'loudness': -20.478,
#   'mode': 1,
#   'speechiness': 0.0376,
#   'acousticness': 0.994,
#   'instrumentalness': 0.763,
#   'liveness': 0.0941,
#   'valence': 0.0399,
#   'tempo': 134.526,
#   'type': 'audio_features',
#   'id': '67kwRadxmmURPuWIpEyymY',
#   'uri': 'spotify:track:67kwRadxmmURPuWIpEyymY',
#   'track_href': 'https://api.spotify.com/v1/tracks/67kwRadxmmURPuWIpEyymY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67kwRadxmmURPuWIpEyymY',
#   'duration_ms': 59880,
#   'time_signature': 4},
#  {'danceability': 0.296,
#   'energy': 0.164,
#   'key': 5,
#   'loudness': -12.602,
#   'mode': 0,
#   'speechiness': 0.0348,
#   'acousticness': 0.959,
#   'instrumentalness': 0,
#   'liveness': 0.201,
#   'valence': 0.253,
#   'tempo': 85.346,
#   'type': 'audio_features',
#   'id': '1FEYWXG23hr3m2vXHpbZeq',
#   'uri': 'spotify:track:1FEYWXG23hr3m2vXHpbZeq',
#   'track_href': 'https://api.spotify.com/v1/tracks/1FEYWXG23hr3m2vXHpbZeq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FEYWXG23hr3m2vXHpbZeq',
#   'duration_ms': 88800,
#   'time_signature': 4},
#  {'danceability': 0.639,
#   'energy': 0.908,
#   'key': 0,
#   'loudness': -5.575,
#   'mode': 1,
#   'speechiness': 0.138,
#   'acousticness': 0.0735,
#   'instrumentalness': 0,
#   'liveness': 0.553,
#   'valence': 0.926,
#   'tempo': 156.029,
#   'type': 'audio_features',
#   'id': '1SfOQKZv0c9FqNXd2Kjt6P',
#   'uri': 'spotify:track:1SfOQKZv0c9FqNXd2Kjt6P',
#   'track_href': 'https://api.spotify.com/v1/tracks/1SfOQKZv0c9FqNXd2Kjt6P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1SfOQKZv0c9FqNXd2Kjt6P',
#   'duration_ms': 175467,
#   'time_signature': 4},
#  {'danceability': 0.495,
#   'energy': 0.854,
#   'key': 4,
#   'loudness': -5.699,
#   'mode': 1,
#   'speechiness': 0.0434,
#   'acousticness': 0.208,
#   'instrumentalness': 0,
#   'liveness': 0.0371,
#   'valence': 0.819,
#   'tempo': 77.967,
#   'type': 'audio_features',
#   'id': '3OUpVpFeNx5jeInhHqiNfs',
#   'uri': 'spotify:track:3OUpVpFeNx5jeInhHqiNfs',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OUpVpFeNx5jeInhHqiNfs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OUpVpFeNx5jeInhHqiNfs',
#   'duration_ms': 133347,
#   'time_signature': 4},
#  {'danceability': 0.81,
#   'energy': 0.502,
#   'key': 4,
#   'loudness': -10.399,
#   'mode': 1,
#   'speechiness': 0.0541,
#   'acousticness': 0.0805,
#   'instrumentalness': 0.0564,
#   'liveness': 0.177,
#   'valence': 0.685,
#   'tempo': 121.466,
#   'type': 'audio_features',
#   'id': '2zsz6dip4W83IlAgp2zP4Y',
#   'uri': 'spotify:track:2zsz6dip4W83IlAgp2zP4Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zsz6dip4W83IlAgp2zP4Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zsz6dip4W83IlAgp2zP4Y',
#   'duration_ms': 128480,
#   'time_signature': 4},
#  {'danceability': 0.306,
#   'energy': 0.872,
#   'key': 2,
#   'loudness': -7.313,
#   'mode': 1,
#   'speechiness': 0.05,
#   'acousticness': 0.00792,
#   'instrumentalness': 0.8,
#   'liveness': 0.261,
#   'valence': 0.648,
#   'tempo': 167.946,
#   'type': 'audio_features',
#   'id': '3OsUjkcv1C1v5udFhgRSFg',
#   'uri': 'spotify:track:3OsUjkcv1C1v5udFhgRSFg',
#   'track_href': 'https://api.spotify.com/v1/tracks/3OsUjkcv1C1v5udFhgRSFg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OsUjkcv1C1v5udFhgRSFg',
#   'duration_ms': 287880,
#   'time_signature': 4},
#  None,
#  {'danceability': 0.314,
#   'energy': 0.874,
#   'key': 9,
#   'loudness': -6.33,
#   'mode': 1,
#   'speechiness': 0.0398,
#   'acousticness': 0.05,
#   'instrumentalness': 0.0784,
#   'liveness': 0.411,
#   'valence': 0.398,
#   'tempo': 159.829,
#   'type': 'audio_features',
#   'id': '2Ol6GoKiAvPOyk52QIQvf7',
#   'uri': 'spotify:track:2Ol6GoKiAvPOyk52QIQvf7',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Ol6GoKiAvPOyk52QIQvf7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Ol6GoKiAvPOyk52QIQvf7',
#   'duration_ms': 265573,
#   'time_signature': 4},
#  {'danceability': 0.216,
#   'energy': 0.517,
#   'key': 2,
#   'loudness': -8.211,
#   'mode': 0,
#   'speechiness': 0.0325,
#   'acousticness': 0.0366,
#   'instrumentalness': 0.318,
#   'liveness': 0.35,
#   'valence': 0.129,
#   'tempo': 99.434,
#   'type': 'audio_features',
#   'id': '1mYPdmzGjsYpWnFF2XO3MJ',
#   'uri': 'spotify:track:1mYPdmzGjsYpWnFF2XO3MJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1mYPdmzGjsYpWnFF2XO3MJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1mYPdmzGjsYpWnFF2XO3MJ',
#   'duration_ms': 322547,
#   'time_signature': 3},
#  {'danceability': 0.792,
#   'energy': 0.892,
#   'key': 7,
#   'loudness': -5.626,
#   'mode': 1,
#   'speechiness': 0.171,
#   'acousticness': 0.109,
#   'instrumentalness': 0,
#   'liveness': 0.0695,
#   'valence': 0.816,
#   'tempo': 108.305,
#   'type': 'audio_features',
#   'id': '4knSB7lhQAtO6UqUeaGox8',
#   'uri': 'spotify:track:4knSB7lhQAtO6UqUeaGox8',
#   'track_href': 'https://api.spotify.com/v1/tracks/4knSB7lhQAtO6UqUeaGox8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4knSB7lhQAtO6UqUeaGox8',
#   'duration_ms': 208787,
#   'time_signature': 4},
#  {'danceability': 0.426,
#   'energy': 0.502,
#   'key': 1,
#   'loudness': -11.085,
#   'mode': 0,
#   'speechiness': 0.0296,
#   'acousticness': 0.582,
#   'instrumentalness': 0.206,
#   'liveness': 0.123,
#   'valence': 0.153,
#   'tempo': 130.018,
#   'type': 'audio_features',
#   'id': '27U2Idl2Jl63dltNrgP6rm',
#   'uri': 'spotify:track:27U2Idl2Jl63dltNrgP6rm',
#   'track_href': 'https://api.spotify.com/v1/tracks/27U2Idl2Jl63dltNrgP6rm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/27U2Idl2Jl63dltNrgP6rm',
#   'duration_ms': 254852,
#   'time_signature': 3},
#  {'danceability': 0.723,
#   'energy': 0.716,
#   'key': 3,
#   'loudness': -6.407,
#   'mode': 0,
#   'speechiness': 0.0437,
#   'acousticness': 5.42e-05,
#   'instrumentalness': 0.905,
#   'liveness': 0.072,
#   'valence': 0.0748,
#   'tempo': 128.701,
#   'type': 'audio_features',
#   'id': '0HadrlP2mwJidGF3pyBX4H',
#   'uri': 'spotify:track:0HadrlP2mwJidGF3pyBX4H',
#   'track_href': 'https://api.spotify.com/v1/tracks/0HadrlP2mwJidGF3pyBX4H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HadrlP2mwJidGF3pyBX4H',
#   'duration_ms': 316253,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.716,
#   'key': 3,
#   'loudness': -6.407,
#   'mode': 0,
#   'speechiness': 0.0437,
#   'acousticness': 5.42e-05,
#   'instrumentalness': 0.905,
#   'liveness': 0.072,
#   'valence': 0.0748,
#   'tempo': 128.701,
#   'type': 'audio_features',
#   'id': '1PH5Es89c1cENU8WVuWwbp',
#   'uri': 'spotify:track:1PH5Es89c1cENU8WVuWwbp',
#   'track_href': 'https://api.spotify.com/v1/tracks/1PH5Es89c1cENU8WVuWwbp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PH5Es89c1cENU8WVuWwbp',
#   'duration_ms': 316253,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.767,
#   'key': 3,
#   'loudness': -6.809,
#   'mode': 0,
#   'speechiness': 0.0621,
#   'acousticness': 0.121,
#   'instrumentalness': 0.0294,
#   'liveness': 0.0839,
#   'valence': 0.748,
#   'tempo': 119.965,
#   'type': 'audio_features',
#   'id': '22ZIa4vKhUFzb4YZqp7g94',
#   'uri': 'spotify:track:22ZIa4vKhUFzb4YZqp7g94',
#   'track_href': 'https://api.spotify.com/v1/tracks/22ZIa4vKhUFzb4YZqp7g94',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22ZIa4vKhUFzb4YZqp7g94',
#   'duration_ms': 240360,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.796,
#   'key': 0,
#   'loudness': -9.39,
#   'mode': 1,
#   'speechiness': 0.0546,
#   'acousticness': 0.000613,
#   'instrumentalness': 1.79e-05,
#   'liveness': 0.239,
#   'valence': 0.183,
#   'tempo': 119.997,
#   'type': 'audio_features',
#   'id': '5GRhjCK4XgTajZvcP8FsRw',
#   'uri': 'spotify:track:5GRhjCK4XgTajZvcP8FsRw',
#   'track_href': 'https://api.spotify.com/v1/tracks/5GRhjCK4XgTajZvcP8FsRw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5GRhjCK4XgTajZvcP8FsRw',
#   'duration_ms': 216911,
#   'time_signature': 4},
#  {'danceability': 0.457,
#   'energy': 0.0952,
#   'key': 2,
#   'loudness': -15.476,
#   'mode': 1,
#   'speechiness': 0.0413,
#   'acousticness': 0.693,
#   'instrumentalness': 0.032,
#   'liveness': 0.113,
#   'valence': 0.138,
#   'tempo': 139.432,
#   'type': 'audio_features',
#   'id': '2hkfe7ug1Wabzapt5HQec4',
#   'uri': 'spotify:track:2hkfe7ug1Wabzapt5HQec4',
#   'track_href': 'https://api.spotify.com/v1/tracks/2hkfe7ug1Wabzapt5HQec4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2hkfe7ug1Wabzapt5HQec4',
#   'duration_ms': 199760,
#   'time_signature': 5},
#  {'danceability': 0.665,
#   'energy': 0.809,
#   'key': 9,
#   'loudness': -8.263,
#   'mode': 1,
#   'speechiness': 0.0391,
#   'acousticness': 0.0382,
#   'instrumentalness': 0.855,
#   'liveness': 0.378,
#   'valence': 0.472,
#   'tempo': 120.009,
#   'type': 'audio_features',
#   'id': '1Lwux3cAXrUG3UWjUEGteT',
#   'uri': 'spotify:track:1Lwux3cAXrUG3UWjUEGteT',
#   'track_href': 'https://api.spotify.com/v1/tracks/1Lwux3cAXrUG3UWjUEGteT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Lwux3cAXrUG3UWjUEGteT',
#   'duration_ms': 482223,
#   'time_signature': 4},
#  {'danceability': 0.518,
#   'energy': 0.624,
#   'key': 0,
#   'loudness': -6.134,
#   'mode': 1,
#   'speechiness': 0.0256,
#   'acousticness': 0.0312,
#   'instrumentalness': 0.000171,
#   'liveness': 0.131,
#   'valence': 0.241,
#   'tempo': 87.565,
#   'type': 'audio_features',
#   'id': '62nFeTispaiYq1KzGrONsl',
#   'uri': 'spotify:track:62nFeTispaiYq1KzGrONsl',
#   'track_href': 'https://api.spotify.com/v1/tracks/62nFeTispaiYq1KzGrONsl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62nFeTispaiYq1KzGrONsl',
#   'duration_ms': 216880,
#   'time_signature': 4},
#  {'danceability': 0.668,
#   'energy': 0.477,
#   'key': 4,
#   'loudness': -8.709,
#   'mode': 0,
#   'speechiness': 0.0358,
#   'acousticness': 0.517,
#   'instrumentalness': 0.446,
#   'liveness': 0.139,
#   'valence': 0.0966,
#   'tempo': 88.005,
#   'type': 'audio_features',
#   'id': '51ygW389BW4Dut3B69pSwc',
#   'uri': 'spotify:track:51ygW389BW4Dut3B69pSwc',
#   'track_href': 'https://api.spotify.com/v1/tracks/51ygW389BW4Dut3B69pSwc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51ygW389BW4Dut3B69pSwc',
#   'duration_ms': 228747,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.203,
#   'key': 5,
#   'loudness': -11.059,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.706,
#   'instrumentalness': 0.221,
#   'liveness': 0.107,
#   'valence': 0.265,
#   'tempo': 125.864,
#   'type': 'audio_features',
#   'id': '0MOMLuhHqNgJ7uAceOPmfj',
#   'uri': 'spotify:track:0MOMLuhHqNgJ7uAceOPmfj',
#   'track_href': 'https://api.spotify.com/v1/tracks/0MOMLuhHqNgJ7uAceOPmfj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0MOMLuhHqNgJ7uAceOPmfj',
#   'duration_ms': 375973,
#   'time_signature': 4},
#  {'danceability': 0.49,
#   'energy': 0.579,
#   'key': 1,
#   'loudness': -10.301,
#   'mode': 0,
#   'speechiness': 0.0344,
#   'acousticness': 0.217,
#   'instrumentalness': 0,
#   'liveness': 0.0644,
#   'valence': 0.879,
#   'tempo': 119.403,
#   'type': 'audio_features',
#   'id': '5tztLBvTlNC15Np2tnQ5Ll',
#   'uri': 'spotify:track:5tztLBvTlNC15Np2tnQ5Ll',
#   'track_href': 'https://api.spotify.com/v1/tracks/5tztLBvTlNC15Np2tnQ5Ll',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5tztLBvTlNC15Np2tnQ5Ll',
#   'duration_ms': 122573,
#   'time_signature': 4},
#  {'danceability': 0.481,
#   'energy': 0.49,
#   'key': 6,
#   'loudness': -10.098,
#   'mode': 1,
#   'speechiness': 0.0271,
#   'acousticness': 0.0536,
#   'instrumentalness': 0.123,
#   'liveness': 0.0915,
#   'valence': 0.0378,
#   'tempo': 152.04,
#   'type': 'audio_features',
#   'id': '3rrtbnOBDzKQfyYKTezEFe',
#   'uri': 'spotify:track:3rrtbnOBDzKQfyYKTezEFe',
#   'track_href': 'https://api.spotify.com/v1/tracks/3rrtbnOBDzKQfyYKTezEFe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3rrtbnOBDzKQfyYKTezEFe',
#   'duration_ms': 287000,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.182,
#   'key': 2,
#   'loudness': -17.068,
#   'mode': 1,
#   'speechiness': 0.0381,
#   'acousticness': 0.835,
#   'instrumentalness': 0.0276,
#   'liveness': 0.109,
#   'valence': 0.125,
#   'tempo': 117.885,
#   'type': 'audio_features',
#   'id': '5dIZa3pwSn1vDenZpSBEFO',
#   'uri': 'spotify:track:5dIZa3pwSn1vDenZpSBEFO',
#   'track_href': 'https://api.spotify.com/v1/tracks/5dIZa3pwSn1vDenZpSBEFO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5dIZa3pwSn1vDenZpSBEFO',
#   'duration_ms': 185733,
#   'time_signature': 4},
#  {'danceability': 0.261,
#   'energy': 0.805,
#   'key': 0,
#   'loudness': -5.722,
#   'mode': 0,
#   'speechiness': 0.0408,
#   'acousticness': 0.0436,
#   'instrumentalness': 0,
#   'liveness': 0.375,
#   'valence': 0.858,
#   'tempo': 155.586,
#   'type': 'audio_features',
#   'id': '2vCsB0tzKlAtsSwB4NBprX',
#   'uri': 'spotify:track:2vCsB0tzKlAtsSwB4NBprX',
#   'track_href': 'https://api.spotify.com/v1/tracks/2vCsB0tzKlAtsSwB4NBprX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2vCsB0tzKlAtsSwB4NBprX',
#   'duration_ms': 139333,
#   'time_signature': 4},
#  {'danceability': 0.203,
#   'energy': 0.663,
#   'key': 1,
#   'loudness': -8.037,
#   'mode': 0,
#   'speechiness': 0.0349,
#   'acousticness': 0.0203,
#   'instrumentalness': 0,
#   'liveness': 0.899,
#   'valence': 0.725,
#   'tempo': 169.994,
#   'type': 'audio_features',
#   'id': '7j021TxcicWprdXpCcMBeH',
#   'uri': 'spotify:track:7j021TxcicWprdXpCcMBeH',
#   'track_href': 'https://api.spotify.com/v1/tracks/7j021TxcicWprdXpCcMBeH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7j021TxcicWprdXpCcMBeH',
#   'duration_ms': 135253,
#   'time_signature': 5},
#  {'danceability': 0.416,
#   'energy': 0.563,
#   'key': 1,
#   'loudness': -8.724,
#   'mode': 0,
#   'speechiness': 0.0298,
#   'acousticness': 0.207,
#   'instrumentalness': 0,
#   'liveness': 0.343,
#   'valence': 0.9,
#   'tempo': 77.56,
#   'type': 'audio_features',
#   'id': '4joiWvli4qJVEW6qZV2i2J',
#   'uri': 'spotify:track:4joiWvli4qJVEW6qZV2i2J',
#   'track_href': 'https://api.spotify.com/v1/tracks/4joiWvli4qJVEW6qZV2i2J',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4joiWvli4qJVEW6qZV2i2J',
#   'duration_ms': 127853,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.829,
#   'key': 5,
#   'loudness': -4.982,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.0971,
#   'valence': 0.438,
#   'tempo': 130.915,
#   'type': 'audio_features',
#   'id': '2NsQgzcCEy9hZbHaBG4Xfy',
#   'uri': 'spotify:track:2NsQgzcCEy9hZbHaBG4Xfy',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NsQgzcCEy9hZbHaBG4Xfy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NsQgzcCEy9hZbHaBG4Xfy',
#   'duration_ms': 227067,
#   'time_signature': 4},
#  {'danceability': 0.652,
#   'energy': 0.829,
#   'key': 5,
#   'loudness': -4.982,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.141,
#   'instrumentalness': 0,
#   'liveness': 0.0971,
#   'valence': 0.438,
#   'tempo': 130.915,
#   'type': 'audio_features',
#   'id': '2NsQgzcCEy9hZbHaBG4Xfy',
#   'uri': 'spotify:track:2NsQgzcCEy9hZbHaBG4Xfy',
#   'track_href': 'https://api.spotify.com/v1/tracks/2NsQgzcCEy9hZbHaBG4Xfy',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NsQgzcCEy9hZbHaBG4Xfy',
#   'duration_ms': 227067,
#   'time_signature': 4},
#  {'danceability': 0.739,
#   'energy': 0.576,
#   'key': 1,
#   'loudness': -12.024,
#   'mode': 1,
#   'speechiness': 0.0472,
#   'acousticness': 0.122,
#   'instrumentalness': 0.00206,
#   'liveness': 0.0482,
#   'valence': 0.78,
#   'tempo': 108.81,
#   'type': 'audio_features',
#   'id': '2Wb9ejnmy27DUTUe9YF5Ew',
#   'uri': 'spotify:track:2Wb9ejnmy27DUTUe9YF5Ew',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Wb9ejnmy27DUTUe9YF5Ew',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wb9ejnmy27DUTUe9YF5Ew',
#   'duration_ms': 260427,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.751,
#   'key': 11,
#   'loudness': -7.818,
#   'mode': 0,
#   'speechiness': 0.0754,
#   'acousticness': 0.225,
#   'instrumentalness': 0.345,
#   'liveness': 0.133,
#   'valence': 0.347,
#   'tempo': 144.296,
#   'type': 'audio_features',
#   'id': '1zwB5h9WqvAlOTOUapSNSe',
#   'uri': 'spotify:track:1zwB5h9WqvAlOTOUapSNSe',
#   'track_href': 'https://api.spotify.com/v1/tracks/1zwB5h9WqvAlOTOUapSNSe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zwB5h9WqvAlOTOUapSNSe',
#   'duration_ms': 219618,
#   'time_signature': 4},
#  {'danceability': 0.607,
#   'energy': 0.811,
#   'key': 0,
#   'loudness': -6.618,
#   'mode': 1,
#   'speechiness': 0.0443,
#   'acousticness': 0.033,
#   'instrumentalness': 0.354,
#   'liveness': 0.376,
#   'valence': 0.339,
#   'tempo': 118.987,
#   'type': 'audio_features',
#   'id': '6g4jkJItHpKs8Ljwt0EEMx',
#   'uri': 'spotify:track:6g4jkJItHpKs8Ljwt0EEMx',
#   'track_href': 'https://api.spotify.com/v1/tracks/6g4jkJItHpKs8Ljwt0EEMx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6g4jkJItHpKs8Ljwt0EEMx',
#   'duration_ms': 331507,
#   'time_signature': 4},
#  {'danceability': 0.711,
#   'energy': 0.468,
#   'key': 4,
#   'loudness': -4.797,
#   'mode': 0,
#   'speechiness': 0.0515,
#   'acousticness': 0.63,
#   'instrumentalness': 0.00427,
#   'liveness': 0.087,
#   'valence': 0.533,
#   'tempo': 127.458,
#   'type': 'audio_features',
#   'id': '40WXqoyOLAAugGmJWZU1FY',
#   'uri': 'spotify:track:40WXqoyOLAAugGmJWZU1FY',
#   'track_href': 'https://api.spotify.com/v1/tracks/40WXqoyOLAAugGmJWZU1FY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/40WXqoyOLAAugGmJWZU1FY',
#   'duration_ms': 234973,
#   'time_signature': 4},
#  {'danceability': 0.403,
#   'energy': 0.883,
#   'key': 2,
#   'loudness': -6.054,
#   'mode': 1,
#   'speechiness': 0.0745,
#   'acousticness': 8.44e-05,
#   'instrumentalness': 0.65,
#   'liveness': 0.126,
#   'valence': 0.078,
#   'tempo': 141.945,
#   'type': 'audio_features',
#   'id': '7uFZNMEZzAGOwQ6EZID1K4',
#   'uri': 'spotify:track:7uFZNMEZzAGOwQ6EZID1K4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7uFZNMEZzAGOwQ6EZID1K4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uFZNMEZzAGOwQ6EZID1K4',
#   'duration_ms': 181373,
#   'time_signature': 4},
#  {'danceability': 0.632,
#   'energy': 0.225,
#   'key': 4,
#   'loudness': -13.423,
#   'mode': 1,
#   'speechiness': 0.0296,
#   'acousticness': 0.984,
#   'instrumentalness': 0.74,
#   'liveness': 0.112,
#   'valence': 0.683,
#   'tempo': 144.641,
#   'type': 'audio_features',
#   'id': '5OojmQ36TXkfL2JfoFJcaq',
#   'uri': 'spotify:track:5OojmQ36TXkfL2JfoFJcaq',
#   'track_href': 'https://api.spotify.com/v1/tracks/5OojmQ36TXkfL2JfoFJcaq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OojmQ36TXkfL2JfoFJcaq',
#   'duration_ms': 254053,
#   'time_signature': 4},
#  {'danceability': 0.557,
#   'energy': 0.728,
#   'key': 6,
#   'loudness': -6.181,
#   'mode': 1,
#   'speechiness': 0.0405,
#   'acousticness': 0.00156,
#   'instrumentalness': 5.13e-06,
#   'liveness': 0.118,
#   'valence': 0.216,
#   'tempo': 118.241,
#   'type': 'audio_features',
#   'id': '0kYUrLVQOfx21xuXu7OGrT',
#   'uri': 'spotify:track:0kYUrLVQOfx21xuXu7OGrT',
#   'track_href': 'https://api.spotify.com/v1/tracks/0kYUrLVQOfx21xuXu7OGrT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0kYUrLVQOfx21xuXu7OGrT',
#   'duration_ms': 301573,
#   'time_signature': 4},
#  {'danceability': 0.492,
#   'energy': 0.231,
#   'key': 9,
#   'loudness': -13.476,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.972,
#   'instrumentalness': 6.16e-06,
#   'liveness': 0.229,
#   'valence': 0.61,
#   'tempo': 93.232,
#   'type': 'audio_features',
#   'id': '25RYJGPnetSkV8le7TeJnR',
#   'uri': 'spotify:track:25RYJGPnetSkV8le7TeJnR',
#   'track_href': 'https://api.spotify.com/v1/tracks/25RYJGPnetSkV8le7TeJnR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/25RYJGPnetSkV8le7TeJnR',
#   'duration_ms': 184987,
#   'time_signature': 3},
#  {'danceability': 0.378,
#   'energy': 0.254,
#   'key': 7,
#   'loudness': -12.694,
#   'mode': 1,
#   'speechiness': 0.0399,
#   'acousticness': 0.891,
#   'instrumentalness': 0.00489,
#   'liveness': 0.109,
#   'valence': 0.19,
#   'tempo': 123.885,
#   'type': 'audio_features',
#   'id': '7hneDPwMWHSDxFZTaiGbaT',
#   'uri': 'spotify:track:7hneDPwMWHSDxFZTaiGbaT',
#   'track_href': 'https://api.spotify.com/v1/tracks/7hneDPwMWHSDxFZTaiGbaT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7hneDPwMWHSDxFZTaiGbaT',
#   'duration_ms': 249320,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.431,
#   'key': 2,
#   'loudness': -9.495,
#   'mode': 1,
#   'speechiness': 0.0686,
#   'acousticness': 0.0722,
#   'instrumentalness': 0,
#   'liveness': 0.561,
#   'valence': 0.778,
#   'tempo': 95.937,
#   'type': 'audio_features',
#   'id': '2ck8lFrYAch2GPtdhpTHe3',
#   'uri': 'spotify:track:2ck8lFrYAch2GPtdhpTHe3',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ck8lFrYAch2GPtdhpTHe3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ck8lFrYAch2GPtdhpTHe3',
#   'duration_ms': 130893,
#   'time_signature': 4},
#  {'danceability': 0.126,
#   'energy': 0.277,
#   'key': 1,
#   'loudness': -12.954,
#   'mode': 0,
#   'speechiness': 0.0304,
#   'acousticness': 0.936,
#   'instrumentalness': 0.00212,
#   'liveness': 0.345,
#   'valence': 0.0688,
#   'tempo': 88.611,
#   'type': 'audio_features',
#   'id': '6ZMu3XuSt70jbJa7OfHN7X',
#   'uri': 'spotify:track:6ZMu3XuSt70jbJa7OfHN7X',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ZMu3XuSt70jbJa7OfHN7X',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZMu3XuSt70jbJa7OfHN7X',
#   'duration_ms': 130200,
#   'time_signature': 4},
#  {'danceability': 0.613,
#   'energy': 0.821,
#   'key': 0,
#   'loudness': -8.534,
#   'mode': 1,
#   'speechiness': 0.0344,
#   'acousticness': 0.00855,
#   'instrumentalness': 0.783,
#   'liveness': 0.0869,
#   'valence': 0.46,
#   'tempo': 101.99,
#   'type': 'audio_features',
#   'id': '7BYRb9EJ90vcBmTHMvmQvm',
#   'uri': 'spotify:track:7BYRb9EJ90vcBmTHMvmQvm',
#   'track_href': 'https://api.spotify.com/v1/tracks/7BYRb9EJ90vcBmTHMvmQvm',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BYRb9EJ90vcBmTHMvmQvm',
#   'duration_ms': 226640,
#   'time_signature': 4},
#  {'danceability': 0.372,
#   'energy': 0.532,
#   'key': 7,
#   'loudness': -7.968,
#   'mode': 1,
#   'speechiness': 0.0314,
#   'acousticness': 0.232,
#   'instrumentalness': 0,
#   'liveness': 0.0951,
#   'valence': 0.727,
#   'tempo': 102.627,
#   'type': 'audio_features',
#   'id': '3oGGipilQmZTol8qFTR6u1',
#   'uri': 'spotify:track:3oGGipilQmZTol8qFTR6u1',
# ...
#   'loudness': -8.247,
#   'mode': 1,
#   'speechiness': 0.053,
#   'acousticness': 0.0547,
#   'instrumentalness': 0.591,
#   'liveness': 0.0804,
#   'valence': 0.894,
#   'tempo': 140.618,
#   'type': 'audio_features',
#   'id': '1IhEDFWcRLtgaC7ib9zaZ5',
#   'uri': 'spotify:track:1IhEDFWcRLtgaC7ib9zaZ5',
#   'track_href': 'https://api.spotify.com/v1/tracks/1IhEDFWcRLtgaC7ib9zaZ5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1IhEDFWcRLtgaC7ib9zaZ5',
#   'duration_ms': 192373,
#   'time_signature': 4},
#  {'danceability': 0.468,
#   'energy': 0.692,
#   'key': 2,
#   'loudness': -4.015,
#   'mode': 1,
#   'speechiness': 0.0295,
#   'acousticness': 0.0202,
#   'instrumentalness': 2.39e-06,
#   'liveness': 0.523,
#   'valence': 0.561,
#   'tempo': 78.009,
#   'type': 'audio_features',
#   'id': '2ZE6D6ySdIjWpb6GObprV8',
#   'uri': 'spotify:track:2ZE6D6ySdIjWpb6GObprV8',
#   'track_href': 'https://api.spotify.com/v1/tracks/2ZE6D6ySdIjWpb6GObprV8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ZE6D6ySdIjWpb6GObprV8',
#   'duration_ms': 200360,
#   'time_signature': 4},
#  {'danceability': 0,
#   'energy': 0.223,
#   'key': 6,
#   'loudness': -18.325,
#   'mode': 1,
#   'speechiness': 0,
#   'acousticness': 0.995,
#   'instrumentalness': 0.0103,
#   'liveness': 0,
#   'valence': 0,
#   'tempo': 0,
#   'type': 'audio_features',
#   'id': '2PRmNoN16eUer6bJomStcf',
#   'uri': 'spotify:track:2PRmNoN16eUer6bJomStcf',
#   'track_href': 'https://api.spotify.com/v1/tracks/2PRmNoN16eUer6bJomStcf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2PRmNoN16eUer6bJomStcf',
#   'duration_ms': 7240,
#   'time_signature': 0},
#  {'danceability': 0.639,
#   'energy': 0.894,
#   'key': 0,
#   'loudness': -7.184,
#   'mode': 1,
#   'speechiness': 0.142,
#   'acousticness': 0.313,
#   'instrumentalness': 4.3e-06,
#   'liveness': 0.168,
#   'valence': 0.39,
#   'tempo': 116.009,
#   'type': 'audio_features',
#   'id': '6OFKVE2HZdK3n2tbTDMhn3',
#   'uri': 'spotify:track:6OFKVE2HZdK3n2tbTDMhn3',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OFKVE2HZdK3n2tbTDMhn3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OFKVE2HZdK3n2tbTDMhn3',
#   'duration_ms': 224627,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.391,
#   'key': 9,
#   'loudness': -14.99,
#   'mode': 1,
#   'speechiness': 0.242,
#   'acousticness': 0.813,
#   'instrumentalness': 0.00363,
#   'liveness': 0.155,
#   'valence': 0.744,
#   'tempo': 123.538,
#   'type': 'audio_features',
#   'id': '53aFGAl0Vebwp2bo8wtdWR',
#   'uri': 'spotify:track:53aFGAl0Vebwp2bo8wtdWR',
#   'track_href': 'https://api.spotify.com/v1/tracks/53aFGAl0Vebwp2bo8wtdWR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/53aFGAl0Vebwp2bo8wtdWR',
#   'duration_ms': 117333,
#   'time_signature': 4},
#  {'danceability': 0.584,
#   'energy': 0.594,
#   'key': 9,
#   'loudness': -6.935,
#   'mode': 1,
#   'speechiness': 0.0487,
#   'acousticness': 0.142,
#   'instrumentalness': 0.00117,
#   'liveness': 0.105,
#   'valence': 0.36,
#   'tempo': 143.935,
#   'type': 'audio_features',
#   'id': '7DdXf9x75iEVCHWfoRwRuR',
#   'uri': 'spotify:track:7DdXf9x75iEVCHWfoRwRuR',
#   'track_href': 'https://api.spotify.com/v1/tracks/7DdXf9x75iEVCHWfoRwRuR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DdXf9x75iEVCHWfoRwRuR',
#   'duration_ms': 219400,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.825,
#   'key': 11,
#   'loudness': -8.302,
#   'mode': 0,
#   'speechiness': 0.0507,
#   'acousticness': 0.0388,
#   'instrumentalness': 0.00101,
#   'liveness': 0.26,
#   'valence': 0.378,
#   'tempo': 143.958,
#   'type': 'audio_features',
#   'id': '3v9fhN8ttoeH9AvpCi3IVM',
#   'uri': 'spotify:track:3v9fhN8ttoeH9AvpCi3IVM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3v9fhN8ttoeH9AvpCi3IVM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v9fhN8ttoeH9AvpCi3IVM',
#   'duration_ms': 198210,
#   'time_signature': 4},
#  {'danceability': 0.646,
#   'energy': 0.825,
#   'key': 11,
#   'loudness': -8.302,
#   'mode': 0,
#   'speechiness': 0.0507,
#   'acousticness': 0.0388,
#   'instrumentalness': 0.00101,
#   'liveness': 0.26,
#   'valence': 0.378,
#   'tempo': 143.958,
#   'type': 'audio_features',
#   'id': '3v9fhN8ttoeH9AvpCi3IVM',
#   'uri': 'spotify:track:3v9fhN8ttoeH9AvpCi3IVM',
#   'track_href': 'https://api.spotify.com/v1/tracks/3v9fhN8ttoeH9AvpCi3IVM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3v9fhN8ttoeH9AvpCi3IVM',
#   'duration_ms': 198210,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.585,
#   'key': 11,
#   'loudness': -8.861,
#   'mode': 0,
#   'speechiness': 0.033,
#   'acousticness': 0.00775,
#   'instrumentalness': 0.00294,
#   'liveness': 0.101,
#   'valence': 0.533,
#   'tempo': 152.458,
#   'type': 'audio_features',
#   'id': '7or8ysyNfJIDsr0vC7aqpQ',
#   'uri': 'spotify:track:7or8ysyNfJIDsr0vC7aqpQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7or8ysyNfJIDsr0vC7aqpQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or8ysyNfJIDsr0vC7aqpQ',
#   'duration_ms': 260215,
#   'time_signature': 4},
#  {'danceability': 0.432,
#   'energy': 0.585,
#   'key': 11,
#   'loudness': -8.861,
#   'mode': 0,
#   'speechiness': 0.033,
#   'acousticness': 0.00775,
#   'instrumentalness': 0.00294,
#   'liveness': 0.101,
#   'valence': 0.533,
#   'tempo': 152.458,
#   'type': 'audio_features',
#   'id': '7or8ysyNfJIDsr0vC7aqpQ',
#   'uri': 'spotify:track:7or8ysyNfJIDsr0vC7aqpQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/7or8ysyNfJIDsr0vC7aqpQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7or8ysyNfJIDsr0vC7aqpQ',
#   'duration_ms': 260215,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.729,
#   'key': 9,
#   'loudness': -4.862,
#   'mode': 1,
#   'speechiness': 0.0373,
#   'acousticness': 0.0785,
#   'instrumentalness': 0.00121,
#   'liveness': 0.728,
#   'valence': 0.534,
#   'tempo': 144.043,
#   'type': 'audio_features',
#   'id': '4S1rRmc82hWL9C5VBtxMKA',
#   'uri': 'spotify:track:4S1rRmc82hWL9C5VBtxMKA',
#   'track_href': 'https://api.spotify.com/v1/tracks/4S1rRmc82hWL9C5VBtxMKA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4S1rRmc82hWL9C5VBtxMKA',
#   'duration_ms': 215670,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.831,
#   'key': 11,
#   'loudness': -7.169,
#   'mode': 0,
#   'speechiness': 0.0291,
#   'acousticness': 0.0034,
#   'instrumentalness': 0.0273,
#   'liveness': 0.125,
#   'valence': 0.249,
#   'tempo': 136.993,
#   'type': 'audio_features',
#   'id': '0Na10nHw7B30hmjkxNK9WB',
#   'uri': 'spotify:track:0Na10nHw7B30hmjkxNK9WB',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Na10nHw7B30hmjkxNK9WB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Na10nHw7B30hmjkxNK9WB',
#   'duration_ms': 270571,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.831,
#   'key': 11,
#   'loudness': -7.169,
#   'mode': 0,
#   'speechiness': 0.0291,
#   'acousticness': 0.0034,
#   'instrumentalness': 0.0273,
#   'liveness': 0.125,
#   'valence': 0.249,
#   'tempo': 136.993,
#   'type': 'audio_features',
#   'id': '0Na10nHw7B30hmjkxNK9WB',
#   'uri': 'spotify:track:0Na10nHw7B30hmjkxNK9WB',
#   'track_href': 'https://api.spotify.com/v1/tracks/0Na10nHw7B30hmjkxNK9WB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Na10nHw7B30hmjkxNK9WB',
#   'duration_ms': 270571,
#   'time_signature': 4},
#  {'danceability': 0.775,
#   'energy': 0.395,
#   'key': 0,
#   'loudness': -11.636,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'acousticness': 0.714,
#   'instrumentalness': 0.939,
#   'liveness': 0.0778,
#   'valence': 0.707,
#   'tempo': 104.486,
#   'type': 'audio_features',
#   'id': '7vJvU9djy2i1lJOqMvj1fb',
#   'uri': 'spotify:track:7vJvU9djy2i1lJOqMvj1fb',
#   'track_href': 'https://api.spotify.com/v1/tracks/7vJvU9djy2i1lJOqMvj1fb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7vJvU9djy2i1lJOqMvj1fb',
#   'duration_ms': 209640,
#   'time_signature': 3},
#  {'danceability': 0.469,
#   'energy': 0.507,
#   'key': 0,
#   'loudness': -8.917,
#   'mode': 0,
#   'speechiness': 0.0451,
#   'acousticness': 0.382,
#   'instrumentalness': 0,
#   'liveness': 0.0783,
#   'valence': 0.619,
#   'tempo': 112.984,
#   'type': 'audio_features',
#   'id': '3pKKxkeB1pOUMHwWBmKc3Y',
#   'uri': 'spotify:track:3pKKxkeB1pOUMHwWBmKc3Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/3pKKxkeB1pOUMHwWBmKc3Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pKKxkeB1pOUMHwWBmKc3Y',
#   'duration_ms': 156827,
#   'time_signature': 4},
#  {'danceability': 0.75,
#   'energy': 0.319,
#   'key': 0,
#   'loudness': -12.141,
#   'mode': 1,
#   'speechiness': 0.0357,
#   'acousticness': 0.861,
#   'instrumentalness': 0.0254,
#   'liveness': 0.0615,
#   'valence': 0.275,
#   'tempo': 117.085,
#   'type': 'audio_features',
#   'id': '4WBpJC6ByANHehsZUW07Vd',
#   'uri': 'spotify:track:4WBpJC6ByANHehsZUW07Vd',
#   'track_href': 'https://api.spotify.com/v1/tracks/4WBpJC6ByANHehsZUW07Vd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WBpJC6ByANHehsZUW07Vd',
#   'duration_ms': 195160,
#   'time_signature': 4},
#  {'danceability': 0.452,
#   'energy': 0.915,
#   'key': 7,
#   'loudness': -6.516,
#   'mode': 1,
#   'speechiness': 0.0701,
#   'acousticness': 0.00201,
#   'instrumentalness': 0.126,
#   'liveness': 0.704,
#   'valence': 0.8,
#   'tempo': 171.37,
#   'type': 'audio_features',
#   'id': '3raHRmDxUhjQo0EKrWFTV0',
#   'uri': 'spotify:track:3raHRmDxUhjQo0EKrWFTV0',
#   'track_href': 'https://api.spotify.com/v1/tracks/3raHRmDxUhjQo0EKrWFTV0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3raHRmDxUhjQo0EKrWFTV0',
#   'duration_ms': 162203,
#   'time_signature': 4},
#  {'danceability': 0.701,
#   'energy': 0.306,
#   'key': 11,
#   'loudness': -16.647,
#   'mode': 1,
#   'speechiness': 0.0519,
#   'acousticness': 0.987,
#   'instrumentalness': 0.939,
#   'liveness': 0.111,
#   'valence': 0.325,
#   'tempo': 118.002,
#   'type': 'audio_features',
#   'id': '61cKlqGQuuk9tqvfTD2t39',
#   'uri': 'spotify:track:61cKlqGQuuk9tqvfTD2t39',
#   'track_href': 'https://api.spotify.com/v1/tracks/61cKlqGQuuk9tqvfTD2t39',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61cKlqGQuuk9tqvfTD2t39',
#   'duration_ms': 243667,
#   'time_signature': 4},
#  {'danceability': 0.839,
#   'energy': 0.84,
#   'key': 11,
#   'loudness': -8.721,
#   'mode': 1,
#   'speechiness': 0.0474,
#   'acousticness': 0.389,
#   'instrumentalness': 0.0319,
#   'liveness': 0.114,
#   'valence': 0.904,
#   'tempo': 117.98,
#   'type': 'audio_features',
#   'id': '5mpLcXEsk3jjzLFGuNKk5I',
#   'uri': 'spotify:track:5mpLcXEsk3jjzLFGuNKk5I',
#   'track_href': 'https://api.spotify.com/v1/tracks/5mpLcXEsk3jjzLFGuNKk5I',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mpLcXEsk3jjzLFGuNKk5I',
#   'duration_ms': 262000,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.662,
#   'key': 11,
#   'loudness': -12.919,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.564,
#   'instrumentalness': 0.000651,
#   'liveness': 0.686,
#   'valence': 0.803,
#   'tempo': 118.014,
#   'type': 'audio_features',
#   'id': '7b829PewSJYvL0MaUoNfNY',
#   'uri': 'spotify:track:7b829PewSJYvL0MaUoNfNY',
#   'track_href': 'https://api.spotify.com/v1/tracks/7b829PewSJYvL0MaUoNfNY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7b829PewSJYvL0MaUoNfNY',
#   'duration_ms': 267776,
#   'time_signature': 4},
#  {'danceability': 0.728,
#   'energy': 0.659,
#   'key': 11,
#   'loudness': -12.919,
#   'mode': 1,
#   'speechiness': 0.059,
#   'acousticness': 0.563,
#   'instrumentalness': 0.000504,
#   'liveness': 0.687,
#   'valence': 0.821,
#   'tempo': 118.015,
#   'type': 'audio_features',
#   'id': '07yKQCRBUdUTSv6y3mbZ1e',
#   'uri': 'spotify:track:07yKQCRBUdUTSv6y3mbZ1e',
#   'track_href': 'https://api.spotify.com/v1/tracks/07yKQCRBUdUTSv6y3mbZ1e',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07yKQCRBUdUTSv6y3mbZ1e',
#   'duration_ms': 267776,
#   'time_signature': 4},
#  {'danceability': 0.64,
#   'energy': 0.728,
#   'key': 2,
#   'loudness': -6.189,
#   'mode': 1,
#   'speechiness': 0.0758,
#   'acousticness': 0.0561,
#   'instrumentalness': 6.73e-05,
#   'liveness': 0.174,
#   'valence': 0.52,
#   'tempo': 141.953,
#   'type': 'audio_features',
#   'id': '6SszAhtfZZ0iY8Od3YHxhX',
#   'uri': 'spotify:track:6SszAhtfZZ0iY8Od3YHxhX',
#   'track_href': 'https://api.spotify.com/v1/tracks/6SszAhtfZZ0iY8Od3YHxhX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SszAhtfZZ0iY8Od3YHxhX',
#   'duration_ms': 187095,
#   'time_signature': 4},
#  {'danceability': 0.664,
#   'energy': 0.525,
#   'key': 0,
#   'loudness': -8.448,
#   'mode': 0,
#   'speechiness': 0.0309,
#   'acousticness': 0.0917,
#   'instrumentalness': 0.526,
#   'liveness': 0.162,
#   'valence': 0.503,
#   'tempo': 120.068,
#   'type': 'audio_features',
#   'id': '55TrsYFuwiFsdrgchaeXW7',
#   'uri': 'spotify:track:55TrsYFuwiFsdrgchaeXW7',
#   'track_href': 'https://api.spotify.com/v1/tracks/55TrsYFuwiFsdrgchaeXW7',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/55TrsYFuwiFsdrgchaeXW7',
#   'duration_ms': 177000,
#   'time_signature': 4},
#  {'danceability': 0.438,
#   'energy': 0.462,
#   'key': 3,
#   'loudness': -13.638,
#   'mode': 1,
#   'speechiness': 0.033,
#   'acousticness': 0.869,
#   'instrumentalness': 0.915,
#   'liveness': 0.0968,
#   'valence': 0.452,
#   'tempo': 144.025,
#   'type': 'audio_features',
#   'id': '4C7F5zCFfppYauKHjKpC34',
#   'uri': 'spotify:track:4C7F5zCFfppYauKHjKpC34',
#   'track_href': 'https://api.spotify.com/v1/tracks/4C7F5zCFfppYauKHjKpC34',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4C7F5zCFfppYauKHjKpC34',
#   'duration_ms': 194693,
#   'time_signature': 4},
#  {'danceability': 0.44,
#   'energy': 0.63,
#   'key': 7,
#   'loudness': -8.319,
#   'mode': 1,
#   'speechiness': 0.0512,
#   'acousticness': 0.241,
#   'instrumentalness': 7.95e-05,
#   'liveness': 0.137,
#   'valence': 0.0387,
#   'tempo': 125.557,
#   'type': 'audio_features',
#   'id': '6ZlolHAQKomJuKg4n5qOAP',
#   'uri': 'spotify:track:6ZlolHAQKomJuKg4n5qOAP',
#   'track_href': 'https://api.spotify.com/v1/tracks/6ZlolHAQKomJuKg4n5qOAP',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ZlolHAQKomJuKg4n5qOAP',
#   'duration_ms': 463520,
#   'time_signature': 4},
#  {'danceability': 0.591,
#   'energy': 0.622,
#   'key': 7,
#   'loudness': -7.454,
#   'mode': 0,
#   'speechiness': 0.0258,
#   'acousticness': 0.107,
#   'instrumentalness': 0.00174,
#   'liveness': 0.101,
#   'valence': 0.728,
#   'tempo': 112.519,
#   'type': 'audio_features',
#   'id': '4Rctx86F2SvaL2LgQRz1ww',
#   'uri': 'spotify:track:4Rctx86F2SvaL2LgQRz1ww',
#   'track_href': 'https://api.spotify.com/v1/tracks/4Rctx86F2SvaL2LgQRz1ww',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Rctx86F2SvaL2LgQRz1ww',
#   'duration_ms': 184192,
#   'time_signature': 4},
#  {'danceability': 0.561,
#   'energy': 0.688,
#   'key': 9,
#   'loudness': -5.625,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.638,
#   'instrumentalness': 0,
#   'liveness': 0.2,
#   'valence': 0.747,
#   'tempo': 75.307,
#   'type': 'audio_features',
#   'id': '1s0uk3LmYulYhdiLlpxqzF',
#   'uri': 'spotify:track:1s0uk3LmYulYhdiLlpxqzF',
#   'track_href': 'https://api.spotify.com/v1/tracks/1s0uk3LmYulYhdiLlpxqzF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1s0uk3LmYulYhdiLlpxqzF',
#   'duration_ms': 176880,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.61,
#   'key': 7,
#   'loudness': -10.067,
#   'mode': 1,
#   'speechiness': 0.0317,
#   'acousticness': 0.737,
#   'instrumentalness': 5.12e-05,
#   'liveness': 0.233,
#   'valence': 0.578,
#   'tempo': 127.435,
#   'type': 'audio_features',
#   'id': '1bbX8eMgNGKtE9hDUmC35Y',
#   'uri': 'spotify:track:1bbX8eMgNGKtE9hDUmC35Y',
#   'track_href': 'https://api.spotify.com/v1/tracks/1bbX8eMgNGKtE9hDUmC35Y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1bbX8eMgNGKtE9hDUmC35Y',
#   'duration_ms': 110653,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.56,
#   'key': 6,
#   'loudness': -12.642,
#   'mode': 1,
#   'speechiness': 0.1,
#   'acousticness': 0.642,
#   'instrumentalness': 0,
#   'liveness': 0.038,
#   'valence': 0.945,
#   'tempo': 196.051,
#   'type': 'audio_features',
#   'id': '6oIOkcU6u5iPlQBHXGJwzN',
#   'uri': 'spotify:track:6oIOkcU6u5iPlQBHXGJwzN',
#   'track_href': 'https://api.spotify.com/v1/tracks/6oIOkcU6u5iPlQBHXGJwzN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6oIOkcU6u5iPlQBHXGJwzN',
#   'duration_ms': 143560,
#   'time_signature': 4},
#  ...]

# %%
 audio_df= pd.json_normalize(audio_f2)

# %%
audio_df
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.310   0.445  7.0   -13.355   0.0       0.0863       0.09400
# 1             0.419   0.565  5.0   -11.565   1.0       0.0347       0.13700
# 2             0.354   0.302  9.0   -13.078   1.0       0.0326       0.59000
# 3             0.727   0.785  5.0    -6.707   0.0       0.0603       0.32500
# 4             0.571   0.724  0.0    -5.967   1.0       0.0260       0.02310
# ...             ...     ...  ...       ...   ...          ...           ...
# 11822         0.651   0.801  0.0    -7.340   1.0       0.0514       0.12300
# 11823         0.811   0.647  0.0   -10.989   1.0       0.0498       0.08230
# 11824         0.686   0.610  7.0    -5.902   1.0       0.0262       0.19000
# 11825         0.711   0.718  6.0    -5.739   1.0       0.0380       0.00824
# 11826         0.323   0.997  1.0    -3.440   1.0       0.2640       0.00767
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.067800    0.1130    0.122   95.360  audio_features
# 1              0.337000    0.1280    0.648  151.277  audio_features
# 2              0.070900    0.1110    0.223  123.753  audio_features
# 3              0.126000    0.3100    0.960  129.649  audio_features
# 4              0.003110    0.0919    0.385  116.755  audio_features
# ...                 ...       ...      ...      ...             ...
# 11822          0.000000    0.0825    0.776  133.769  audio_features
# 11823          0.681000    0.0572    0.990  139.787  audio_features
# 11824          0.000931    0.0710    0.766   80.567  audio_features
# 11825          0.002080    0.0732    0.688  117.071  audio_features
# 11826          0.110000    0.9480    0.315  199.962  audio_features
#
#                            id                                   uri  \
# 0      33xMbeHzmWd6Od0BmLZEUs  spotify:track:33xMbeHzmWd6Od0BmLZEUs
# 1      3UnyplmZaq547hwsfOR5yy  spotify:track:3UnyplmZaq547hwsfOR5yy
# 2      1w8QCSDH4QobcQeT4uMKLm  spotify:track:1w8QCSDH4QobcQeT4uMKLm
# 3      7J9mBHG4J2eIfDAv5BehKA  spotify:track:7J9mBHG4J2eIfDAv5BehKA
# 4      1VZedwJj1gyi88WFRhfThb  spotify:track:1VZedwJj1gyi88WFRhfThb
# ...                       ...                                   ...
# 11822  5jzma6gCzYtKB1DbEwFZKH  spotify:track:5jzma6gCzYtKB1DbEwFZKH
# 11823  2fmMPJb5EzZCx8BcNJvVk4  spotify:track:2fmMPJb5EzZCx8BcNJvVk4
# 11824  60rIdEPDrzyLiLC0icp3xz  spotify:track:60rIdEPDrzyLiLC0icp3xz
# 11825  0sEm1ld0V8YTCPcjPVfIsc  spotify:track:0sEm1ld0V8YTCPcjPVfIsc
# 11826  4JPE3Q7vuFa6UFoduMgZm2  spotify:track:4JPE3Q7vuFa6UFoduMgZm2
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/33xMbeHzmWd6...
# 1      https://api.spotify.com/v1/tracks/3UnyplmZaq54...
# 2      https://api.spotify.com/v1/tracks/1w8QCSDH4Qob...
# 3      https://api.spotify.com/v1/tracks/7J9mBHG4J2eI...
# 4      https://api.spotify.com/v1/tracks/1VZedwJj1gyi...
# ...                                                  ...
# 11822  https://api.spotify.com/v1/tracks/5jzma6gCzYtK...
# 11823  https://api.spotify.com/v1/tracks/2fmMPJb5EzZC...
# 11824  https://api.spotify.com/v1/tracks/60rIdEPDrzyL...
# 11825  https://api.spotify.com/v1/tracks/0sEm1ld0V8YT...
# 11826  https://api.spotify.com/v1/tracks/4JPE3Q7vuFa6...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/33xM...     152560.0
# 1      https://api.spotify.com/v1/audio-analysis/3Uny...     197707.0
# 2      https://api.spotify.com/v1/audio-analysis/1w8Q...     244285.0
# 3      https://api.spotify.com/v1/audio-analysis/7J9m...     249940.0
# 4      https://api.spotify.com/v1/audio-analysis/1VZe...     278320.0
# ...                                                  ...          ...
# 11822  https://api.spotify.com/v1/audio-analysis/5jzm...     200480.0
# 11823  https://api.spotify.com/v1/audio-analysis/2fmM...     191560.0
# 11824  https://api.spotify.com/v1/audio-analysis/60rI...     206293.0
# 11825  https://api.spotify.com/v1/audio-analysis/0sEm...     200293.0
# 11826  https://api.spotify.com/v1/audio-analysis/4JPE...     409013.0
#
#        time_signature
# 0                 3.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 11822             4.0
# 11823             4.0
# 11824             4.0
# 11825             4.0
# 11826             4.0
#
# [11827 rows x 18 columns]

# %%
data = pd.concat([playlist1, audio_df ], axis=1)

# %%
data= data.dropna()

# %%
data= data.drop_duplicates(subset= 'track_name' , keep='first', inplace=False, ignore_index=False)

# %%
data.shape
# Out:
# (8701, 21)

# %%
data.to_csv('C:/Users/Yuga 14/Ih-Labs/lab-bash/lab-web-scraping-single-page/data2.csv', index=False)
