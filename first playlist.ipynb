# %%
secrets_file = open("privateinfo.txt","r")

# %%
string = secrets_file.read()

# %%
string
# Out:
# 'cid:5d4f33bfe3ba4a30a9f258f3f2566c74\ncsecret:65fa69bb28ee457e9a3f5cb31de31d05'

# %%
string.split('\n')
# Out:
# ['cid:5d4f33bfe3ba4a30a9f258f3f2566c74',
#  'csecret:65fa69bb28ee457e9a3f5cb31de31d05']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': '5d4f33bfe3ba4a30a9f258f3f2566c74',
#  'csecret': '65fa69bb28ee457e9a3f5cb31de31d05'}

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],
                                                           client_secret=secrets_dict['csecret']))

# %%
# Reusable functions
def get_name_artists_from_track(track):
    return [(track["name"],artist["name"], track["uri"]) for artist in track["artists"]]
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

#first we need to get a list of individual tracks from the playlist
def get_name_artist_from_playlist_item(playlist_item):
    return get_name_artists_from_track(playlist_item['track'])

def get_name_artists_from_playlist_items(playlist_items):
    return flatten(list(map(get_name_artist_from_playlist_item,playlist_items)))

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks =  results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3000/1000))
    return tracks

# %%
 all_tracks = get_playlist_tracks("5pehZoVMAXO3qA2W2F07cy")

# %%
my_data = get_name_artists_from_playlist_items(all_tracks)

# %%
#my_data ##in order to be convenient and readable for TAs

# %%
 all_tracks[0]['track']['name']
# Out:
# 'Sueño en Paraguay - El Búho Remix'

# %%
import pandas as pd

playlist1 = pd.DataFrame(my_data, columns = ['track_name', 'artist_name', 'uri'])
print(playlist1.shape)
playlist1.head(10)
# Out:
# (254, 3)
#                           track_name             artist_name  \
# 0  Sueño en Paraguay - El Búho Remix    Chancha Via Circuito
# 1  Sueño en Paraguay - El Búho Remix                 El Búho
# 2                Guacamayo Ara Macao  La Gallera Social Club
# 3                            Quincha                 Montoya
# 4                              Rabia                   Umoja
# 5                           Mi Sueño                Populous
# 6                         Qhapaq Ñan           Frente Tunupa
# 7                             Ototoa                Malphino
# 8                  Raíces Profundas                 Temoaya
# 9                          Tecolotin                 El Búho
#
#                                     uri
# 0  spotify:track:24Ppb6GaBRREID9uMlTTSg
# 1  spotify:track:24Ppb6GaBRREID9uMlTTSg
# 2  spotify:track:3dTjTtdewJ6T1Q8VjRibZh
# 3  spotify:track:1ktwwtPkM8yY0LYKRER84S
# 4  spotify:track:3t0jdtXL8Ya9gNaCDPWTjK
# 5  spotify:track:2zvSh7tUDjh574V4U74qMU
# 6  spotify:track:57m2EdFh6QMSOyRxBqV7lU
# 7  spotify:track:4SEy3HRvR2fB0WvFZzKQpB
# 8  spotify:track:7r5txKc3Ljy1nToNmicID2
# 9  spotify:track:09KSKjuieY3ekdNN2H1jrC

# %%
audio_f = []

for x in playlist1['uri']:
    audio_f.append(sp.audio_features(x))

# %%
# audio_f  ##in order to be convenient and readable for TAs

# %%
audio_f1 = flatten(audio_f)
audio_f1= pd.DataFrame(audio_f1)

# %%
audio_f1
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.663   0.799    8    -5.992     0       0.0352       0.07220
# 1           0.663   0.799    8    -5.992     0       0.0352       0.07220
# 2           0.803   0.584   11    -8.563     0       0.1230       0.02410
# 3           0.702   0.593    5    -9.750     1       0.0415       0.01770
# 4           0.807   0.538    8    -9.415     0       0.0938       0.00498
# ..            ...     ...  ...       ...   ...          ...           ...
# 249         0.755   0.698    5    -6.541     0       0.0444       0.12900
# 250         0.755   0.698    5    -6.541     0       0.0444       0.12900
# 251         0.755   0.698    5    -6.541     0       0.0444       0.12900
# 252         0.953   0.597    1    -6.302     1       0.1580       0.13700
# 253         0.953   0.597    1    -6.302     1       0.1580       0.13700
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0              0.9000    0.1030    0.300   90.792  audio_features
# 1              0.9000    0.1030    0.300   90.792  audio_features
# 2              0.5740    0.0847    0.713   95.002  audio_features
# 3              0.7440    0.1130    0.623  119.981  audio_features
# 4              0.7860    0.0793    0.559   89.995  audio_features
# ..                ...       ...      ...      ...             ...
# 249            0.2180    0.0948    0.276  101.996  audio_features
# 250            0.2180    0.0948    0.276  101.996  audio_features
# 251            0.2180    0.0948    0.276  101.996  audio_features
# 252            0.0282    0.1030    0.843  128.016  audio_features
# 253            0.0282    0.1030    0.843  128.016  audio_features
#
#                          id                                   uri  \
# 0    24Ppb6GaBRREID9uMlTTSg  spotify:track:24Ppb6GaBRREID9uMlTTSg
# 1    24Ppb6GaBRREID9uMlTTSg  spotify:track:24Ppb6GaBRREID9uMlTTSg
# 2    3dTjTtdewJ6T1Q8VjRibZh  spotify:track:3dTjTtdewJ6T1Q8VjRibZh
# 3    1ktwwtPkM8yY0LYKRER84S  spotify:track:1ktwwtPkM8yY0LYKRER84S
# 4    3t0jdtXL8Ya9gNaCDPWTjK  spotify:track:3t0jdtXL8Ya9gNaCDPWTjK
# ..                      ...                                   ...
# 249  20nb4i2WWyPDXhiQTZqlrV  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 250  20nb4i2WWyPDXhiQTZqlrV  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 251  20nb4i2WWyPDXhiQTZqlrV  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 252  2mkaIpJfNqzFzVUVQ0tSMc  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc
# 253  2mkaIpJfNqzFzVUVQ0tSMc  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/24Ppb6GaBRRE...
# 1    https://api.spotify.com/v1/tracks/24Ppb6GaBRRE...
# 2    https://api.spotify.com/v1/tracks/3dTjTtdewJ6T...
# 3    https://api.spotify.com/v1/tracks/1ktwwtPkM8yY...
# 4    https://api.spotify.com/v1/tracks/3t0jdtXL8Ya9...
# ..                                                 ...
# 249  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 250  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 251  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 252  https://api.spotify.com/v1/tracks/2mkaIpJfNqzF...
# 253  https://api.spotify.com/v1/tracks/2mkaIpJfNqzF...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/24Pp...       239417
# 1    https://api.spotify.com/v1/audio-analysis/24Pp...       239417
# 2    https://api.spotify.com/v1/audio-analysis/3dTj...       346107
# 3    https://api.spotify.com/v1/audio-analysis/1ktw...       393000
# 4    https://api.spotify.com/v1/audio-analysis/3t0j...       224000
# ..                                                 ...          ...
# 249  https://api.spotify.com/v1/audio-analysis/20nb...       256471
# 250  https://api.spotify.com/v1/audio-analysis/20nb...       256471
# 251  https://api.spotify.com/v1/audio-analysis/20nb...       256471
# 252  https://api.spotify.com/v1/audio-analysis/2mka...       195469
# 253  https://api.spotify.com/v1/audio-analysis/2mka...       195469
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 249               4
# 250               4
# 251               4
# 252               4
# 253               4
#
# [254 rows x 18 columns]

# %%
data = pd.concat([playlist1, audio_f1 ], axis=1)

# %%
data
# Out:
#                             track_name             artist_name  \
# 0    Sueño en Paraguay - El Búho Remix    Chancha Via Circuito
# 1    Sueño en Paraguay - El Búho Remix                 El Búho
# 2                  Guacamayo Ara Macao  La Gallera Social Club
# 3                              Quincha                 Montoya
# 4                                Rabia                   Umoja
# ..                                 ...                     ...
# 249                        It's a Joke               YoSoyMatt
# 250                        It's a Joke              Altriparty
# 251                        It's a Joke                Hypsidia
# 252                            Mi Poni          Captain Planet
# 253                            Mi Poni         Zuzuka Poderosa
#
#                                       uri  danceability  energy  key  \
# 0    spotify:track:24Ppb6GaBRREID9uMlTTSg         0.663   0.799    8
# 1    spotify:track:24Ppb6GaBRREID9uMlTTSg         0.663   0.799    8
# 2    spotify:track:3dTjTtdewJ6T1Q8VjRibZh         0.803   0.584   11
# 3    spotify:track:1ktwwtPkM8yY0LYKRER84S         0.702   0.593    5
# 4    spotify:track:3t0jdtXL8Ya9gNaCDPWTjK         0.807   0.538    8
# ..                                    ...           ...     ...  ...
# 249  spotify:track:20nb4i2WWyPDXhiQTZqlrV         0.755   0.698    5
# 250  spotify:track:20nb4i2WWyPDXhiQTZqlrV         0.755   0.698    5
# 251  spotify:track:20nb4i2WWyPDXhiQTZqlrV         0.755   0.698    5
# 252  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc         0.953   0.597    1
# 253  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc         0.953   0.597    1
#
#      loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0      -5.992     0       0.0352       0.07220  ...    0.1030    0.300
# 1      -5.992     0       0.0352       0.07220  ...    0.1030    0.300
# 2      -8.563     0       0.1230       0.02410  ...    0.0847    0.713
# 3      -9.750     1       0.0415       0.01770  ...    0.1130    0.623
# 4      -9.415     0       0.0938       0.00498  ...    0.0793    0.559
# ..        ...   ...          ...           ...  ...       ...      ...
# 249    -6.541     0       0.0444       0.12900  ...    0.0948    0.276
# 250    -6.541     0       0.0444       0.12900  ...    0.0948    0.276
# 251    -6.541     0       0.0444       0.12900  ...    0.0948    0.276
# 252    -6.302     1       0.1580       0.13700  ...    0.1030    0.843
# 253    -6.302     1       0.1580       0.13700  ...    0.1030    0.843
#
#        tempo            type                      id  \
# 0     90.792  audio_features  24Ppb6GaBRREID9uMlTTSg
# 1     90.792  audio_features  24Ppb6GaBRREID9uMlTTSg
# 2     95.002  audio_features  3dTjTtdewJ6T1Q8VjRibZh
# 3    119.981  audio_features  1ktwwtPkM8yY0LYKRER84S
# 4     89.995  audio_features  3t0jdtXL8Ya9gNaCDPWTjK
# ..       ...             ...                     ...
# 249  101.996  audio_features  20nb4i2WWyPDXhiQTZqlrV
# 250  101.996  audio_features  20nb4i2WWyPDXhiQTZqlrV
# 251  101.996  audio_features  20nb4i2WWyPDXhiQTZqlrV
# 252  128.016  audio_features  2mkaIpJfNqzFzVUVQ0tSMc
# 253  128.016  audio_features  2mkaIpJfNqzFzVUVQ0tSMc
#
#                                       uri  \
# 0    spotify:track:24Ppb6GaBRREID9uMlTTSg
# 1    spotify:track:24Ppb6GaBRREID9uMlTTSg
# 2    spotify:track:3dTjTtdewJ6T1Q8VjRibZh
# 3    spotify:track:1ktwwtPkM8yY0LYKRER84S
# 4    spotify:track:3t0jdtXL8Ya9gNaCDPWTjK
# ..                                    ...
# 249  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 250  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 251  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 252  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc
# 253  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/24Ppb6GaBRRE...
# 1    https://api.spotify.com/v1/tracks/24Ppb6GaBRRE...
# 2    https://api.spotify.com/v1/tracks/3dTjTtdewJ6T...
# 3    https://api.spotify.com/v1/tracks/1ktwwtPkM8yY...
# 4    https://api.spotify.com/v1/tracks/3t0jdtXL8Ya9...
# ..                                                 ...
# 249  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 250  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 251  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 252  https://api.spotify.com/v1/tracks/2mkaIpJfNqzF...
# 253  https://api.spotify.com/v1/tracks/2mkaIpJfNqzF...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/24Pp...      239417
# 1    https://api.spotify.com/v1/audio-analysis/24Pp...      239417
# 2    https://api.spotify.com/v1/audio-analysis/3dTj...      346107
# 3    https://api.spotify.com/v1/audio-analysis/1ktw...      393000
# 4    https://api.spotify.com/v1/audio-analysis/3t0j...      224000
# ..                                                 ...         ...
# 249  https://api.spotify.com/v1/audio-analysis/20nb...      256471
# 250  https://api.spotify.com/v1/audio-analysis/20nb...      256471
# 251  https://api.spotify.com/v1/audio-analysis/20nb...      256471
# 252  https://api.spotify.com/v1/audio-analysis/2mka...      195469
# 253  https://api.spotify.com/v1/audio-analysis/2mka...      195469
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 249               4
# 250               4
# 251               4
# 252               4
# 253               4
#
# [254 rows x 21 columns]

# %%
data.drop_duplicates(subset='track_name' , keep='first', inplace=False, ignore_index=False)
# Out:
#                               track_name             artist_name  \
# 0      Sueño en Paraguay - El Búho Remix    Chancha Via Circuito
# 2                    Guacamayo Ara Macao  La Gallera Social Club
# 3                                Quincha                 Montoya
# 4                                  Rabia                   Umoja
# 5                               Mi Sueño                Populous
# ..                                   ...                     ...
# 241  La Luna Llena (feat. Mercedes Sosa)           Gianni Romano
# 244                          Darte de Mí         Sandra Bernardo
# 246                     Quién Me Escucha         Sandra Bernardo
# 249                          It's a Joke               YoSoyMatt
# 252                              Mi Poni          Captain Planet
#
#                                       uri  danceability  energy  key  \
# 0    spotify:track:24Ppb6GaBRREID9uMlTTSg         0.663   0.799    8
# 2    spotify:track:3dTjTtdewJ6T1Q8VjRibZh         0.803   0.584   11
# 3    spotify:track:1ktwwtPkM8yY0LYKRER84S         0.702   0.593    5
# 4    spotify:track:3t0jdtXL8Ya9gNaCDPWTjK         0.807   0.538    8
# 5    spotify:track:2zvSh7tUDjh574V4U74qMU         0.868   0.652    9
# ..                                    ...           ...     ...  ...
# 241  spotify:track:0Jk07UgVM6CRdHpIeUeiEX         0.781   0.707    4
# 244  spotify:track:2zlJxIp4qlsCsjUatScArP         0.616   0.737    4
# 246  spotify:track:19e0zVRwZdpid0bGdYXxGi         0.746   0.530   11
# 249  spotify:track:20nb4i2WWyPDXhiQTZqlrV         0.755   0.698    5
# 252  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc         0.953   0.597    1
#
#      loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0      -5.992     0       0.0352       0.07220  ...    0.1030    0.300
# 2      -8.563     0       0.1230       0.02410  ...    0.0847    0.713
# 3      -9.750     1       0.0415       0.01770  ...    0.1130    0.623
# 4      -9.415     0       0.0938       0.00498  ...    0.0793    0.559
# 5      -6.460     0       0.0489       0.15500  ...    0.0850    0.601
# ..        ...   ...          ...           ...  ...       ...      ...
# 241    -9.196     0       0.0403       0.02040  ...    0.3350    0.402
# 244    -6.640     0       0.0366       0.48100  ...    0.1180    0.758
# 246   -10.645     0       0.2720       0.24900  ...    0.0773    0.574
# 249    -6.541     0       0.0444       0.12900  ...    0.0948    0.276
# 252    -6.302     1       0.1580       0.13700  ...    0.1030    0.843
#
#        tempo            type                      id  \
# 0     90.792  audio_features  24Ppb6GaBRREID9uMlTTSg
# 2     95.002  audio_features  3dTjTtdewJ6T1Q8VjRibZh
# 3    119.981  audio_features  1ktwwtPkM8yY0LYKRER84S
# 4     89.995  audio_features  3t0jdtXL8Ya9gNaCDPWTjK
# 5    118.032  audio_features  2zvSh7tUDjh574V4U74qMU
# ..       ...             ...                     ...
# 241  112.049  audio_features  0Jk07UgVM6CRdHpIeUeiEX
# 244   79.985  audio_features  2zlJxIp4qlsCsjUatScArP
# 246  182.020  audio_features  19e0zVRwZdpid0bGdYXxGi
# 249  101.996  audio_features  20nb4i2WWyPDXhiQTZqlrV
# 252  128.016  audio_features  2mkaIpJfNqzFzVUVQ0tSMc
#
#                                       uri  \
# 0    spotify:track:24Ppb6GaBRREID9uMlTTSg
# 2    spotify:track:3dTjTtdewJ6T1Q8VjRibZh
# 3    spotify:track:1ktwwtPkM8yY0LYKRER84S
# 4    spotify:track:3t0jdtXL8Ya9gNaCDPWTjK
# 5    spotify:track:2zvSh7tUDjh574V4U74qMU
# ..                                    ...
# 241  spotify:track:0Jk07UgVM6CRdHpIeUeiEX
# 244  spotify:track:2zlJxIp4qlsCsjUatScArP
# 246  spotify:track:19e0zVRwZdpid0bGdYXxGi
# 249  spotify:track:20nb4i2WWyPDXhiQTZqlrV
# 252  spotify:track:2mkaIpJfNqzFzVUVQ0tSMc
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/24Ppb6GaBRRE...
# 2    https://api.spotify.com/v1/tracks/3dTjTtdewJ6T...
# 3    https://api.spotify.com/v1/tracks/1ktwwtPkM8yY...
# 4    https://api.spotify.com/v1/tracks/3t0jdtXL8Ya9...
# 5    https://api.spotify.com/v1/tracks/2zvSh7tUDjh5...
# ..                                                 ...
# 241  https://api.spotify.com/v1/tracks/0Jk07UgVM6CR...
# 244  https://api.spotify.com/v1/tracks/2zlJxIp4qlsC...
# 246  https://api.spotify.com/v1/tracks/19e0zVRwZdpi...
# 249  https://api.spotify.com/v1/tracks/20nb4i2WWyPD...
# 252  https://api.spotify.com/v1/tracks/2mkaIpJfNqzF...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/24Pp...      239417
# 2    https://api.spotify.com/v1/audio-analysis/3dTj...      346107
# 3    https://api.spotify.com/v1/audio-analysis/1ktw...      393000
# 4    https://api.spotify.com/v1/audio-analysis/3t0j...      224000
# 5    https://api.spotify.com/v1/audio-analysis/2zvS...      273966
# ..                                                 ...         ...
# 241  https://api.spotify.com/v1/audio-analysis/0Jk0...      244821
# 244  https://api.spotify.com/v1/audio-analysis/2zlJ...      211743
# 246  https://api.spotify.com/v1/audio-analysis/19e0...      198150
# 249  https://api.spotify.com/v1/audio-analysis/20nb...      256471
# 252  https://api.spotify.com/v1/audio-analysis/2mka...      195469
#
#      time_signature
# 0                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# ..              ...
# 241               4
# 244               4
# 246               4
# 249               4
# 252               4
#
# [165 rows x 21 columns]

# %%
data.to_csv('C:/Users/Yuga 14/Ih-Labs/lab-bash/lab-web-scraping-single-page/data3.csv', index=False)
